# %% [markdown]
# # Team Allocation Simulator #
# by Ewen, Wei Hao, Zerius, Youde, Shawn

# %% [markdown]
# ## Resources provided ##
# We have received a CSV file 'records.csv', which have given us the following information of each of the 6000 students
# 1. The students' name
# 2. The students' ID
# 3. The students' tutorial group
# 4. The students' gender
# 5. The students' school affiliation
# 6. The students' current CGPA

# %% [markdown]
# ## Requirements ##
# We are to develop an application that does the following
# 1. Organize students into teams of five
# 2. Team members should be in the same tutorial group
# 3. No team should have a majority of students from the same school
# 4. No team should have a majority of students of the same gender
# 5. No team should not consist predominantly of students with very high or very low CGPAs

# %% [markdown]
# ## Thought Process for Team Allocation Simulator ##
#
# To develop a robust and efficient Team Allocation Simulator, we adopted the cornerstones of Critical Thinking for Computing. This approach provided a structured guide for analyzing the problem and creating an effective solution.
#
# ### Decomposition ###
# The first step was to decompose the complex problem into manageable sub-tasks. Considering the various requirements for team formation, we evaluated different approaches for grouping students and identified the following optimal process:
#
# - Split the students by tutorial groups.
# - Within each tutorial group, split the students by gender.
# - Sort students within each gender group by CGPA.
# - Select students according to the determined selection strategy.
#
# By breaking the problem into these steps, we were able to develop a clear path for implementation, ensuring each requirement is addressed methodically.
#
# ### Abstraction ###
# To simplify the extraction and management of student information, we chose to represent each student’s data as a dictionary. These dictionaries are stored within lists to facilitate sequential, mutable data access. This decision was based on the need for flexible data structures that allow easy data manipulation and retrieval.
#
# ### Patterns ###
# We anticipated that the student selection process would be the most sophisticated part of the algorithm. Thus, we analyzed the potential patterns within this procedure to simplify and optimize it.
#
# Methodology for Student Selection:
#
# 1. Start by selecting the student with the lowest CGPA from the gender group with more students.
# 2. Alternate by choosing the student with the highest CGPA from the opposite gender.
# 3. Continue with the student who has the median CGPA from the initial gender group.
# 4. Repeat the process, ensuring a 3:2 gender ratio and varied school affiliations.
# 5. This approach ensures that each group has balanced CGPA levels, gender diversity, and students from different schools. The team composition pattern follows the order:
#
# ```
# [LowestFemale, HighestMale, MedianFemale, LowestMale, HighestFemale]
# ```
# Handling School Affiliation Duplicates: If a selected student shares the same school affiliation as another team member, the algorithm selects the next-best candidate (e.g., the second lowest/highest CGPA). This adjustment continues until a suitable candidate is found.
#
# Indexing Pattern:
#
# The indexes used for selection are [0, -1, len(sorted_student[gender_index]) // 2], corresponding to the lowest, highest, and median positions in the gender group.
# Changes in the index are tracked using index_changes = [+1, -1, +1], and a variable cycles through the indexes to maintain the selection pattern.
#
# ### Algorithms ###
# To build the Team Allocation Simulator, we outlined the following procedural steps:
#
# Develop a CSV reading function: Extract and organize student data from the CSV file into dictionaries within lists.
# Create a function to sort students by tutorial group: This ensures that students are initially grouped according to their assigned tutorial.
# Develop a team allocation function: This function distributes students into balanced teams while considering gender ratio, CGPA distribution, and school diversity.
# Implement a sorting function by gender and CGPA: This function organizes students within their tutorial groups into separate lists based on gender and then sorts them by CGPA.
# This structured workflow is designed to meet all project requirements and maintain efficiency in forming teams.
#
# Conclusion
# By following these steps, we believe our approach effectively balances the criteria of CGPA, gender, and school diversity in each team. The use of dictionaries and lists simplifies data handling, while the patterned selection process ensures a logical and fair distribution of students. The thought process outlined above demonstrates how decomposition, abstraction, pattern recognition, and algorithmic planning were integral to our project’s development.

# %% [markdown]
# ## Function to Read CSV File ##
# We will first create a function to read the CSV. It will then add each student's information (those listed above) into a dictionary. The dictionaries of the students' details will be stored in a list.

# %% [markdown]
# ### Pseudocode for read_student_data ###
#
# <font color='32CD32'>FUNCTION</font> read_student_data(file_path):
# <br>&emsp;<font color='32CD32'>INITIALISE</font> students_list as an empty list
# <br>
# <br>&emsp;<font color='32CD32'>OPEN</font> file at file_path in read mode AS file
# <br>&emsp;&emsp;<font color='32CD32'>READ</font> the first line and <font color='32CD32'>SPLIT</font> it by commas, <font color='32CD32'>ASSIGN</font> it to headers
# <br>
# <br>&emsp;&emsp;<font color='32CD32'>FOR EACH</font> line <font color ='32CD32'>IN</font> file:
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>INITIALISE</font> student as an empty dictionary
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>SPLIT</font> line by commas, <font color='32CD32'>ASSIGN</font> it to values
# <br>
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>FOR EACH</font> index i and header IN headers:
# <br>&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>SET</font> student[header] to values[i]
# <br>&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>IF</font> header is equal to "CGPA":
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>CONVERT</font> class of value to float
# <br>
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> student to students_list
# <br>
# <br>&emsp;<font color='32CD32'>RETURN</font> students_list

# %%
from IPython import display
display.Image("assets/Flowchart_read student data.png")

# %% [markdown]
# ## Function to Sort Students By Tutorial Groups ##
# Since the members of each group should be in the same tutorial group, we decided that it would be more efficient to meet this requirement first. In this function, we have split the dictionaries of each student to lists of their own respective tutorial groups.

# %% [markdown]
# ### Pseudocode for Function, pick_student ###
#
# <font color='32CD32'>FUNCTION</font> pick_student(all_students, tut_grp):
# <br>&emsp;<font color='32CD32'>INITIALISE</font> students_list as an empty list
# <br>
# <br>&emsp;<font color='32CD32'>FOR EACH</font> student <font color='32CD32'>IN</font> all_students
# <br>&emsp;&emsp;<font color='32CD32'>IF</font> student's 'Tutorial Group' is equal to 'G-{tut_grp}'
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> student to students_list
# <br>
# <br>&emsp;<font color='32CD32'>RETURN</font> students_list

# %%
display.Image("assets/Flowchart_pick_student.png")

# %% [markdown]
# ## Function to form a team of 5 students ##
# We will now design a function to form a team of 5 students. This function will have 2 parameters, a list with male students with their CGPA sorted, as well as a list with female students with their CGPA sorted. We will implement another function later for the sorting of gender and CGPA.
#
# For this function, we will be primarily be focussing on how we would ensure teams would have students with different school affliations, and how we would balance out the CGPA and gender in each group. We would heavily use pattern recognition to build this function.
#
# We will first pick a student with the lowest CGPA amongst gender X, where gender X has more students. We will then select a student of opposite gender with the highest CGPA. The next student selected would have the median CGPA amongst gender X. The first step repeats again. This effectively allows for a good mix of CGPA in a group, while ensuring there will be a 3:2 ratio for the gender and that students have different school affiliations. The team composition will look something like this:
# ```
# LowestFemale, HighestMale, MedianFemale, LowestMale, HighestFemale
# ```
#
# In the event where the student selected has the same school affliation as another student already in the group, the function will choose the next best alternative
# > If the next female student with the lowest CGPA has the same school affiliation with another student in the group, the second lowest CGPA female student will be selected instead. If the second lowest CGPA female student also has same school affilation with another student in the group, the third lowest CGPA female student will be selected, and so on.
#
# However, to ensure that the mean of CGPA does not differ alot between teams, we would stop the changing of index after it increases by 5. This also ensures that the mixture of CGPA will not affect other teams as well.
#
# Most tutorial groups will not be in a perfect 3:2 gender ratio for us to distribute them evenly. Hence, we have devised a way to ensure that 4:1 teams will be formed instead until the 3:2 ratio in the tutorial groups is formed. The remaining students will then be able to form 3:2 teams.
# > If there are 35 female and 15 male students in the tutorial group, 5 4:1 teams will be formed first. the remaining 5 teams will have a ratio of 3:2.

# %% [markdown]
# ### Pseudocode for Function ###
# <font color='32CD32'>FUNCTION</font> diverse_team(sorted_student_more, sorted_student_less)<br>
# &emsp;<font color='32CD32'>INITIALISE</font> team <font color='32CD32'>AS</font> an empty list<br>
# &emsp;<font color='32CD32'>SET</font> i <font color='32CD32'>TO</font> 0<br>
# &emsp;<font color='32CD32'>INITIALISE</font> sorted_student <font color='32CD32'>AS</font> a list containing sorted_student_more and sorted_student_less<br>
#
# &emsp;<font color='32CD32'>SET</font> gender_run_two_time <font color='32CD32'>TO</font> FALSE<br>
# &emsp;<font color='32CD32'>SET</font> next_gender_same <font color='32CD32'>TO</font> FALSE<br>
# &emsp;<font color='32CD32'>IF</font> (length of sorted_student_more - length of sorted_student_less >= 10-team_index) <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;<font color='32CD32'>SET</font> gender_run_two_time <font color='32CD32'>TO</font> TRUE
#
# &emsp;<font color='32CD32'>SET</font> gender_index <font color='32CD32'>TO</font> 0<br>
#
# &emsp;<font color='32CD32'>WHILE</font> (length of team < 5) <font color='32CD32'>AND</font> (sorted_student[0] <font color='32CD32'>OR</font> sorted_student[1])<br>
# &emsp;&emsp;<font color='32CD32'>WHILE</font> index_changes <font color='32CD32'>TO</font> [+1, -1, +1]<br>
# &emsp;&emsp;<font color='32CD32'>SET</font> pick_index <font color='32CD32'>TO</font> [0, -1, length of sorted_student[gender_index] // 2]<br>
#
# &emsp;&emsp;<font color='32CD32'>WHILE</font> TRUE<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>IF</font> sorted_student[gender_index] is empty <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>BREAK</font><br>
#
# &emsp;&emsp;&emsp;<font color='32CD32'>IF</font> (index_changes[i] >= 0) <font color='32CD32'>AND</font> (pick_index[i] + index_changes[i] < length of sorted_student[gender_index]) <font color='32CD32'>AND</font> index_changes[i] <= 5 <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>IF</font> sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] <font color='32CD32'>NOT</font> <font color='32CD32'>IN</font> student['School'] <font color='32CD32'>FOR</font> student <font color='32CD32'>IN</font> team] <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> sorted_student[gender_index].<font color='32CD32'>POP</font>(pick_index[i] + index_changes[i]) <font color='32CD32'>TO</font> team<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>BREAK</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>ELSE</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>INCREMENT</font> index_changes[i] <font color='32CD32'>BY</font> 1<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>ELSE IF</font> (index_changes[i] < 0) <font color='32CD32'>AND</font> (ABS(pick_index[i] + index_changes[i]) <= length of sorted_student[gender_index]) <font color='32CD32'>AND</font> (ABS(index_changes[i]) <= 5) <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>IF</font> (sorted_student[gender_index][pick_index[i] + index_changes[i]]['School']) <font color='32CD32'>NOT</font> <font color='32CD32'>IN</font> [student['School'] <font color='32CD32'>FOR</font> student <font color='32CD32'>IN</font> team] <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> sorted_student[gender_index].<font color='32CD32'>POP</font>(pick_index[i] + index_changes[i]) <font color='32CD32'>TO</font> team<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>BREAK</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>ELSE</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>DECREMENT</font> index_changes[i] <font color='32CD32'>BY</font> 1<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>ELSE</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> sorted_student[gender_index].<font color='32CD32'>POP</font>(pick_index[i]) <font color='32CD32'>TO</font> team<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;BREAK<br>
#
# &emsp;&emsp;<font color='32CD32'>INCREMENT</font> i <font color='32CD32'>BY</font> 1
#
# &emsp;&emsp;<font color='32CD32'>IF</font> <font color='32CD32'>NOT</font> next_gender_same <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>INCREMENT</font> gender_index <font color='32CD32'>BY</font> 1
#
# &emsp;&emsp;<font color='32CD32'>ELSE IF</font> next_gender_same <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> next_gender_same <font color='32CD32'>TO</font> FALSE
#
# &emsp;&emsp;<font color='32CD32'>IF</font> i is greater than 2 <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> i <font color='32CD32'>TO</font> 0
#
# &emsp;&emsp;<font color='32CD32'>IF</font> gender_index is greater than 1 <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> gender_index <font color='32CD32'>TO</font> 0
#
# &emsp;&emsp;<font color='32CD32'>IF</font> gender_run_two_time <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> gender_index <font color='32CD32'>TO</font> 0<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> gender_run_two_time <font color='32CD32'>TO</font> TRUE<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> next_gender_same <font color='32CD32'>TO</font> TRUE
#
# &emsp;<font color='32CD32'>RETURN</font> team<br>

# %%
display.Image("assets/Flowchart_diverse_teams.png")

# %% [markdown]
# ## Function to Sort by Gender and CGPA (Division into team) ##
# This function would split students by their gender into 2 lists. Each list will then be sorted by CGPA. The function will determine whether the tutorial group has more males or femeles, and the lists produced will then be used as diverse_team parameters.
# The function will return the groups formed in lists, nested in a whole list.

# %% [markdown]
# ### Pseudocode for division_into_team ###
#
# <font color='32CD32'>FUNCTION</font> division_into_team(students_list):
# <br>&emsp;<font color='32CD32'>INITIALISE</font> male_students as list of students from students_list where 'Gender' is 'Male'
# <br>&emsp;<font color='32CD32'>INITIALISE</font> female_students as list of students from students_list where 'Gender' is 'Female'
# <br>&emsp;<font color='32CD32'>INITIALISE</font> teams as a list of empty lists, with one list for every 5 students in students_list
# <br>&emsp;<font color='32CD32'>INITIALISE</font> team_index to 0
#
# <br>&emsp;<font color='32CD32'>SORT</font> male_students by 'CGPA' in ascending order, <font color='32CD32'>ASSIGN</font> to male_sorted_students
# <br>&emsp;<font color='32CD32'>SORT</font> female_students by 'CGPA' in ascending order, <font color='32CD32'>ASSIGN</font> to female_sorted_students
#
# <br>&emsp;<font color='32CD32'>WHILE</font> team_index < length of teams:
# <br>&emsp;&emsp;<font color='32CD32'>IF</font> length of male_sorted_students >= length of female_sorted_students:
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>SET</font> teams[team_index] to result of calling diverse_team with male_sorted_students, female_sorted_students, and team_index
# <br>&emsp;&emsp;<font color='32CD32'>ELSE</font>:
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>SET</font> teams[team_index] to result of calling diverse_team with female_sorted_students, male_sorted_students, and team_index
#
# <br>&emsp;&emsp;<font color='32CD32'>INCREMENT</font> team_index by 1
#
# <br><font color='32CD32'>RETURN</font> teams

# %%
display.Image("assets/Flowchart_division into team.png")

# %% [markdown]
# ## Main Code ##

# %% [markdown]
# ### Pseudocode for the Main ###
# <br><font color='32CD32'>INITIALISE</font> students, by reading student data from 'records.csv'
# <br><font color='32CD32'>INITIALISE</font> group_division, as an empty list
# <br><font color='32CD32'>INITIALISE</font> tutorial_grp, to 1 (starting tutorial group)
#
# <br><font color='32CD32'>WHILE</font> (tutorial_grp) is less than or equal to 120
# <br>&emsp;&emsp;<font color='32CD32'>CALL</font> pick_student(students, tutorial_grp)
# <br>&emsp;&emsp;<font color='32CD32'>CALL</font> division_into_team with the picked students
# <br>&emsp;&emsp;<font color='32CD32'>EXTEND</font> group_division with the resulting teams
# <br>&emsp;&emsp;<font color='32CD32'>INCREMENT</font> tutorial_grp by 1
#
# <br><font color='32CD32'>WITH </font>open file "FCEB_Team2_EWEN.csv" in **write** mode as variable 'f'.
# <br><font color='32CD32'>FOR EACH</font> 'i, x' in group_division (where 'i' is the group index and 'x' is the group list):
# <br>&emsp;&emsp;<font color='32CD32'>Write</font> "Group {i}" to the file.
# <br><font color='32CD32'>FOR EACH</font> 'j' in x (where 'j' is each student in the group):
# <br>&emsp;&emsp;<font color='32CD32'>Create</font> string 'l' with 'Student ID', 'School', 'CGPA', and 'Gender' of the student, followed by a newline.
# <br>&emsp;&emsp;<font color='32CD32'>Write</font> 'l' to the file.
# <br><font color='32CD32'>Close</font> the file. (Automatically closed due to 'with'.)

# %%
display.Image("assets/Flowchart_Main Code.png")

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # Visualisation of code #

# %%
from IPython import display
display.Image("assets/dataset_school.jpg")

# %% [markdown]
# ### School Representation ###

# %%
display.Image("assets/school_representation.png")

# %% [markdown]
# ### Gender Representation ###

# %%
display.Image("assets/dataset_gender.jpg")

# %%
display.Image("assets/gender_representation.png")

# %% [markdown]
# ### Histogram for Mean CGPA Per Team ###

# %%
display.Image("assets/Histogram_for_Mean_CGPA_Per_Team.png")

# %% [markdown]
# ### Histogram_for_Standard_Deviation_Per_Team.png ###

# %%
display.Image("assets/Histogram_for_Standard_Deviation_Per_Team.png")

# %% [markdown]
# ### Histogram_of_Z-Scores_for_Mean_CGPA_per_Team ###

# %%
display.Image("assets/Histogram_of_Z-Scores_for_Mean_CGPA_per_Team.png")

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # Code #
# We had code 2 version, one is the basic code, another one is the advanced code where user can choose number of student in a group

# %% [markdown]
# ## Basic Code

# %%
def read_student_data(file_path):
    """Read data from csv file and return"""
    students_list = []
    with open(file_path, mode='r') as file:
        headers = file.readline().strip().split(",")
        for line in file:
            student = {}
            values = line.strip().split(",")
            for i, header in enumerate(headers):
                student[header.strip()] = values[i].strip()
                if header.strip() == "CGPA":
                    student[header.strip()] = float(student[header.strip()])

            students_list.append(student)

    return students_list


def pick_student(all_students, tut_grp):
    """pick student out from the tutorial group"""
    students_list = []

    for student in all_students:
        if student['Tutorial Group'] == f'G-{tut_grp}':
            students_list.append(student)

    return students_list


def diverse_team(sorted_student_more, sorted_student_less, team_index):  # index(0,-1,or middle)
    team = []
    i = 0  # round
    sorted_student = [sorted_student_more, sorted_student_less]

    gender_run_two_time = False
    next_gender_same = False
    if len(sorted_student_more) - len(sorted_student_less) >= 10-team_index:
        gender_run_two_time = True

    gender_index = 0

    while len(team) < 5 and (sorted_student[0] or sorted_student[1]):  # add student into team when teams is not full
        index_changes = [+1, -1, +1]
        pick_index = [0, -1, len(sorted_student[gender_index]) // 2]
        while True:
            if not sorted_student[gender_index]:
                break
            elif index_changes[i] >= 0 and pick_index[i] + index_changes[i] < len(sorted_student[gender_index]) and index_changes[
                i] <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] += 1
            elif index_changes[i] < 0 and abs(pick_index[i] + index_changes[i]) <= len(sorted_student[gender_index]) and abs(
                    index_changes[i]) <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] -= 1
            else:
                # If the index exceeds the list length, reset index_changes or break
                team.append(sorted_student[gender_index].pop(pick_index[i]))
                break

        i += 1
        if not next_gender_same:
            gender_index += 1
        elif next_gender_same:
            next_gender_same = False
        if i > 2:
            i = 0
        if gender_index > 1:
            gender_index = 0

        if gender_run_two_time:
            gender_index = 0
            gender_run_two_time = False
            next_gender_same = True

    return team


def division_into_team(students_list):
    """Divides student from student_list into group of 5 with balance of cgpa and gender, and diverse of school"""
    # Separate male and female students into two lists
    male_students = [student for student in students_list if student['Gender'] == 'Male']
    female_students = [student for student in students_list if student['Gender'] == 'Female']

    # Sort the male and female students by CGPA
    male_sorted_students = sorted(male_students, key=lambda student: student['CGPA'])
    female_sorted_students = sorted(female_students, key=lambda student: student['CGPA'])

    teams = [[] for _ in range(len(students_list) // 5)]
    team_index = 0

    while team_index < len(teams):  # while haven't added student into all teams
        if len(male_sorted_students) >= len(female_sorted_students):  # if remain male student more than remain female student
            teams[team_index] = diverse_team(male_sorted_students, female_sorted_students, team_index)

        else:  # if remain male student less than remain female student
            teams[team_index] = diverse_team(female_sorted_students, male_sorted_students, team_index)

        team_index += 1

    return teams


students = read_student_data('records.csv')
group_division = []
tutorial_grp = 1

while tutorial_grp <= 120:
    group_division.extend(division_into_team(pick_student(students, tutorial_grp)))
    tutorial_grp += 1
    
with open("group_division.csv", mode="w") as f:
    f.write("Tutorial Group,Group Number,Student ID,School,Name,Gender,CGPA\n")

    for group_num, group in enumerate(group_division,start=1):
        for student in group:
            l = f"{student['Tutorial Group']},{group_num},{student['Student ID']},{student['School']},{student['Name']},{student['Gender']},{student['CGPA']}\n"
            f.write(l)

# %% [markdown]
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Advanced Code ##

# %%
from ipywidgets import IntSlider, interact


def read_student_data(file_path):
    """Read data from csv file and return"""
    students_list = []
    with open(file_path, mode='r') as file:
        headers = file.readline().strip().split(",")
        for line in file:
            student = {}
            values = line.strip().split(",")
            for i, header in enumerate(headers):
                student[header.strip()] = values[i].strip()
                if header.strip() == "CGPA":
                    student[header.strip()] = float(student[header.strip()])

            students_list.append(student)

    return students_list


def pick_student(all_students, tut_grp):
    """pick student out from the tutorial group"""
    students_list = []

    for student in all_students:
        if student['Tutorial Group'] == f'G-{tut_grp}':
            students_list.append(student)

    return students_list


def diverse_team(size_team, sorted_student_more, sorted_student_less,team_index,len_team):  # size of team, index(0,-1,or middle)
    team = []
    i = 0  # round
    sorted_student = [sorted_student_more, sorted_student_less]

    gender_run_two_time = False
    next_gender_same = False
    if (size_team%2 == 0) or len(sorted_student_more) - len(sorted_student_less) >= ((((size_team//2)+1)*len_team) -((size_team//2)*len_team))-team_index:
        gender_run_two_time = True

    gender_index = 0

    while len(team) < size_team and (sorted_student[0] or sorted_student[1]):  # add student into team when teams is not full
        index_changes = [+1, -1, +1]
        pick_index = [0, -1, len(sorted_student[gender_index]) // 2]
        while True:
            if not sorted_student[gender_index]:
                break
            elif index_changes[i] >= 0 and pick_index[i] + index_changes[i] < len(sorted_student[gender_index]) and index_changes[
                i] <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] += 1
            elif index_changes[i] < 0 and abs(pick_index[i] + index_changes[i]) <= len(sorted_student[gender_index]) and abs(
                    index_changes[i]) <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] -= 1
            else:
                # If the index exceeds the list length, reset index_changes or break
                team.append(sorted_student[gender_index].pop(pick_index[i]))
                break

        i += 1
        if not next_gender_same:
            gender_index += 1
        elif next_gender_same:
            next_gender_same = False
        if i > 2:
            i = 0
        if gender_index > 1:
            gender_index = 0

        if gender_run_two_time:
            gender_index = 0
            gender_run_two_time = False
            next_gender_same = True

    return team


def division_into_team(students_list, size):
    """Divides student from student_list into group of size with balance of cgpa and gender, and diverse of school"""
    # Separate male and female students into two lists
    male_students = [student for student in students_list if student['Gender'] == 'Male']
    female_students = [student for student in students_list if student['Gender'] == 'Female']

    # Sort the male and female students by CGPA
    male_sorted_students = sorted(male_students, key=lambda student: student['CGPA'])
    female_sorted_students = sorted(female_students, key=lambda student: student['CGPA'])

    teams = [[] for _ in range(len(students_list) // size)]
    team_index = 0

    while team_index < len(teams):  # while haven't added student into all teams
        if len(male_sorted_students) >= len(female_sorted_students):  # if remain male student more than remain female student
            teams[team_index] = diverse_team(size, male_sorted_students, female_sorted_students,team_index,len(teams))

        else:  # if remain male student less than remain female student
            teams[team_index] = diverse_team(size, female_sorted_students, male_sorted_students,team_index,len(teams))

        team_index += 1

    first_run = True
    while male_sorted_students or female_sorted_students:
        for team in teams:
            male = sum(1 for student in team if student['Gender'] == 'Male')
            female = sum(1 for student in team if student['Gender'] == 'Female')

            # Handle male students first
            if male_sorted_students:
                if male > female:
                    continue
                elif female > male:
                    team.append(male_sorted_students.pop(0))
                    continue
                elif not first_run and male - female < 2:
                    team.append(male_sorted_students.pop(0))
                    continue

            # Handle female students
            if female_sorted_students:
                if male > female:
                    team.append(female_sorted_students.pop(0))
                    continue
                elif female > male:
                    continue
                elif not first_run and female - male < 2:
                    team.append(female_sorted_students.pop(0))
                    continue

        if not first_run:
            break

        # Mark the first run complete
        first_run = False

    return teams


def main(team_size):
    global group_division
    students = read_student_data('records.csv')
    group_division = []
    tutorial_grp = 1

    while tutorial_grp <= 120:
        group_division.extend(division_into_team(pick_student(students, tutorial_grp), team_size))
        tutorial_grp += 1

    with open("group_division.csv", mode="w") as f:
        f.write("Tutorial Group,Group Number,Student ID,School,Name,Gender,CGPA\n")
    
        for group_num, group in enumerate(group_division,start=1):
            for student in group:
                l = f"{student['Tutorial Group']},{group_num},{student['Student ID']},{student['School']},{student['Name']},{student['Gender']},{student['CGPA']}\n"
                f.write(l)
        
team_size_slider = IntSlider(value=5,min=4,max=10,step=1,description="Team Size")

interact(main,team_size = team_size_slider)
# Out:
# interactive(children=(IntSlider(value=5, description='Team Size', max=10, min=4), Output()), _dom_classes=('wi…
# <function __main__.main(team_size)>

# %% [markdown]
# <br><br><br><br><br><br>

# %% [markdown]
# # Matplotlib Part to Visualise Code #

# %%
import matplotlib.pyplot as plt
import os


def visualize_data(group_division):
    all_sd = []
    all_mean = []
    compiled_z_score = []
    compiled_gender = []
    unique_school_counts = []

    for i, x in enumerate(group_division):
        print(f"Team {i}")
        total_cgpa = 0
        ind_cgpa = []
        ind_gender = []
        ind_school = []
        for j in x:
            total_cgpa += j["CGPA"]
            ind_cgpa.append(j["CGPA"])
            ind_gender.append(j["Gender"])
            ind_school.append(j["School"])

        # for categorisation of gender
        compiled_gender.append(ind_gender)

        # for categorisation for diverse sch representation
        schools_in_team = set(sch for sch in ind_school)  # Use a set to get unique schools
        unique_school_counts.append(len(schools_in_team))  # Count of unique schools

        # for categorisation for CGPA
        ind_mean = total_cgpa / len(ind_cgpa)  # individual group mean CGPA
        deviations = [(each - ind_mean) ** 2 for each in ind_cgpa]
        variance = sum(deviations) / len(ind_cgpa)
        sd = variance ** 0.5
        all_sd.append(sd)
        all_mean.append(ind_mean)

        # printing of cgPA values for each group
        print(f"The mean CGPA of team {i}  is {ind_mean:.2f}")
        print(f"The variance of team {i}  is {variance:.5f}")
        print(f"The standard deviation of team {i}  is {sd:.5f}")
        print()

    # comparing individual team's mean, sd to observe the disparity in CGPA between each team and the population
    total_mean = sum(all_mean) / len(all_mean)
    population_deviations = [(each - total_mean) ** 2 for each in all_mean]
    population_sd = (sum(population_deviations) / len(all_mean)) ** 0.5

    # calculate z-score of every team
    for i in all_mean:
        z_score = (i - total_mean) / population_sd  # calculate z-score for each team and ammend to list for display
        compiled_z_score.append(z_score)

    # printing of the cohort's average cGPA, SD and zScore.
    print(f"The mean of the population is {total_mean:.2f}")
    print(f"The standard deviation of the population is {population_sd:.5f}")

    #for base.py only
    # dictionary to hold self-defined variable for gender categorisation and its count per category
    #count_gender = {'m5f0': 0, 'm4f1': 0, 'm3f2': 0, 'm2f3': 0, 'm1f4': 0, 'm0f5': 0}
    #for teamg in compiled_gender:
    #    count = sum(1 for gender in teamg if gender == "Male")
    #    if count > 5:
    #        count = 5
    #    count_gender[f'm{count}f{5 - count}'] += 1
    #print(f"Gender count {count_gender}")

    count_gender = {}

    for team_number, teamgender in enumerate(compiled_gender, start=1):
        male_count = sum(1 for gender in teamgender if gender == "Male")
        female_count = len(teamgender) - male_count  # female count is total team size - male count

        # Print the team number with male and female counts
        #print(f"Team {team_number}: {male_count} males, {female_count} females")

        # Create the key based on the number of males and females
        gender_key = f'm{male_count}f{female_count}'  # Key in the form of mXfY

        if gender_key not in count_gender:
            count_gender[gender_key] = 0
    
        # Update the count for the given key
        count_gender[gender_key] += 1

    # Output the final result
    print(count_gender)

    # Visualisation
    os.makedirs("assets", exist_ok=True)  # make assets folder if it doesnt exist

    show_graph_gender(count_gender)  # bar graph for count_gender dict
    show_graph_school(unique_school_counts)  # bar graph for sch repre
    # show_graph_CGPA(related_list,title,window_title,xlabel,ylabel,color_for_bins):
    show_graph_cgpa(all_mean, "Histogram of Mean CGPA per Team",
                    "Histogram_for_Mean_CGPA_Per_Team",
                    "Mean cGPA",
                    "Frequency",
                    "red")

    show_graph_cgpa(all_sd, "Histogram of Standard Deviation per Team",
                    "Histogram_for_Standard_Deviation_Per_Team",
                    "Standard Deviation",
                    "Frequency",
                    "blue")
    show_graph_cgpa(compiled_z_score, "Histogram of Z-Scores for Mean CGPA per Team",
                    "Histogram_of_Z-Scores_for_Mean_CGPA_per_Team",
                    "Z-Score",
                    "Frequency",
                    "green")

def show_graph_school(unique_school_counts):
    fig = plt.figure(figsize=(10, 6))
    fig.canvas.manager.set_window_title("Bar Graph for School Representation")
    counts, bins, patches = plt.hist(unique_school_counts, bins=range(1, max(unique_school_counts) + 2),
                                     color='skyblue', edgecolor='black', align='left')

    plt.xticks(range(1, max(unique_school_counts) + 1))  # Set x-ticks
    plt.xlabel("Number of Unique Schools per Team")
    plt.ylabel("Number of Teams")
    plt.title("Distribution of Unique Schools in Teams")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Adding labels on top of each bar
    for count, x in zip(counts, bins):
        if count > 0:  # Only label if there's a bar
            plt.text(x, count, int(count), ha='center', va='bottom')

    plt.show()
    fig.savefig("assets/school_representation.png")

def show_graph_gender(count_gender):
    # Data for the bar chart (this to visualize the count_gender dict)
    labels = list(count_gender.keys())  # Category labels using count_gender dictionary
    frequencies = list(count_gender.values())  # Count from dictionary for each category

    # Plotting the bar chart
    fig, ax = plt.subplots(figsize=(10, 6))
    fig.canvas.manager.set_window_title("Bar Graph for Gender Representation")

    # Create the bar chart
    bars = ax.bar(labels, frequencies, color='skyblue')

    # Adding titles and labels
    ax.set_title("Frequency of Gender in Teams")
    ax.set_xlabel("Gender Composition , m5f0 means 5 males, 0 females)")
    ax.set_ylabel("Number of Teams")

    # Adding frequency labels on top of each bar
    for bar in bars:
        yval = bar.get_height()  # Get the height of each bar
        ax.text(bar.get_x() + bar.get_width() / 2, yval, int(yval), ha='center', va='bottom')

    # Display the chart
    plt.xticks(rotation=45)
    plt.show()
    fig.savefig("assets/gender_representation.png")

def show_graph_cgpa(related_list, title, window_title, xlabel, ylabel, color_for_bins):
    fig = plt.figure(figsize=(10, 6))
    fig.canvas.manager.set_window_title(window_title)
    counts, bins, patches = plt.hist(related_list, bins=10, color=color_for_bins, edgecolor='black', alpha=0.7)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Add frequency labels on top of each bar
    for count, bin_edge in zip(counts, bins):
        if count > 0:
            plt.text(bin_edge + (bins[1] - bins[0]) / 2, count, int(count), ha='center', va='bottom')

    plt.show()
    fig.savefig("assets/" + window_title + ".png")
    
visualize_data(group_division)
# Out:
# Team 0
# The mean CGPA of team 0  is 4.10
# The variance of team 0  is 0.02796
# The standard deviation of team 0  is 0.16722
#
# Team 1
# The mean CGPA of team 1  is 4.08
# The variance of team 1  is 0.01322
# The standard deviation of team 1  is 0.11498
#
# Team 2
# The mean CGPA of team 2  is 4.09
# The variance of team 2  is 0.00434
# The standard deviation of team 2  is 0.06589
#
# Team 3
# The mean CGPA of team 3  is 4.14
# The variance of team 3  is 0.01946
# The standard deviation of team 3  is 0.13951
#
# Team 4
# The mean CGPA of team 4  is 4.06
# The variance of team 4  is 0.00685
# The standard deviation of team 4  is 0.08273
#
# Team 5
# The mean CGPA of team 5  is 4.08
# The variance of team 5  is 0.01111
# The standard deviation of team 5  is 0.10540
#
# Team 6
# The mean CGPA of team 6  is 4.10
# The variance of team 6  is 0.00498
# The standard deviation of team 6  is 0.07060
#
# Team 7
# The mean CGPA of team 7  is 4.11
# The variance of team 7  is 0.00459
# The standard deviation of team 7  is 0.06774
#
# Team 8
# The mean CGPA of team 8  is 4.08
# The variance of team 8  is 0.00448
# The standard deviation of team 8  is 0.06696
#
# Team 9
# The mean CGPA of team 9  is 4.08
# The variance of team 9  is 0.00875
# The standard deviation of team 9  is 0.09351
#
# Team 10
# The mean CGPA of team 10  is 4.14
# The variance of team 10  is 0.05544
# The standard deviation of team 10  is 0.23546
#
# Team 11
# The mean CGPA of team 11  is 4.08
# The variance of team 11  is 0.01032
# The standard deviation of team 11  is 0.10159
#
# Team 12
# The mean CGPA of team 12  is 4.09
# The variance of team 12  is 0.00522
# The standard deviation of team 12  is 0.07222
#
# Team 13
# The mean CGPA of team 13  is 4.14
# The variance of team 13  is 0.08078
# The standard deviation of team 13  is 0.28422
#
# Team 14
# The mean CGPA of team 14  is 4.08
# The variance of team 14  is 0.00955
# The standard deviation of team 14  is 0.09772
#
# Team 15
# The mean CGPA of team 15  is 4.08
# The variance of team 15  is 0.00988
# The standard deviation of team 15  is 0.09940
#
# Team 16
# The mean CGPA of team 16  is 4.07
# The variance of team 16  is 0.01116
# The standard deviation of team 16  is 0.10565
#
# Team 17
# The mean CGPA of team 17  is 4.09
# The variance of team 17  is 0.00556
# The standard deviation of team 17  is 0.07457
#
# Team 18
# The mean CGPA of team 18  is 4.08
# The variance of team 18  is 0.00928
# The standard deviation of team 18  is 0.09631
#
# Team 19
# The mean CGPA of team 19  is 4.07
# The variance of team 19  is 0.01060
# The standard deviation of team 19  is 0.10296
#
# Team 20
# The mean CGPA of team 20  is 4.07
# The variance of team 20  is 0.01758
# The standard deviation of team 20  is 0.13257
#
# Team 21
# The mean CGPA of team 21  is 4.09
# The variance of team 21  is 0.00962
# The standard deviation of team 21  is 0.09810
#
# Team 22
# The mean CGPA of team 22  is 4.09
# The variance of team 22  is 0.02841
# The standard deviation of team 22  is 0.16855
#
# Team 23
# The mean CGPA of team 23  is 4.07
# The variance of team 23  is 0.01097
# The standard deviation of team 23  is 0.10473
#
# Team 24
# The mean CGPA of team 24  is 4.07
# The variance of team 24  is 0.01476
# The standard deviation of team 24  is 0.12149
#
# Team 25
# The mean CGPA of team 25  is 4.09
# The variance of team 25  is 0.01382
# The standard deviation of team 25  is 0.11756
#
# Team 26
# The mean CGPA of team 26  is 4.09
# The variance of team 26  is 0.01132
# The standard deviation of team 26  is 0.10640
#
# Team 27
# The mean CGPA of team 27  is 4.09
# The variance of team 27  is 0.00697
# The standard deviation of team 27  is 0.08346
#
# Team 28
# The mean CGPA of team 28  is 4.18
# The variance of team 28  is 0.05145
# The standard deviation of team 28  is 0.22682
#
# Team 29
# The mean CGPA of team 29  is 4.04
# The variance of team 29  is 0.00732
# The standard deviation of team 29  is 0.08558
#
# Team 30
# The mean CGPA of team 30  is 4.09
# The variance of team 30  is 0.02421
# The standard deviation of team 30  is 0.15559
#
# Team 31
# The mean CGPA of team 31  is 4.09
# The variance of team 31  is 0.01227
# The standard deviation of team 31  is 0.11075
#
# Team 32
# The mean CGPA of team 32  is 4.09
# The variance of team 32  is 0.00850
# The standard deviation of team 32  is 0.09217
#
# Team 33
# The mean CGPA of team 33  is 4.06
# The variance of team 33  is 0.00828
# The standard deviation of team 33  is 0.09102
#
# Team 34
# The mean CGPA of team 34  is 4.13
# The variance of team 34  is 0.02714
# The standard deviation of team 34  is 0.16473
#
# Team 35
# The mean CGPA of team 35  is 4.07
# The variance of team 35  is 0.01026
# The standard deviation of team 35  is 0.10130
#
# Team 36
# The mean CGPA of team 36  is 4.05
# The variance of team 36  is 0.01106
# The standard deviation of team 36  is 0.10519
#
# Team 37
# The mean CGPA of team 37  is 4.11
# The variance of team 37  is 0.00380
# The standard deviation of team 37  is 0.06168
#
# Team 38
# The mean CGPA of team 38  is 4.11
# The variance of team 38  is 0.00274
# The standard deviation of team 38  is 0.05235
#
# Team 39
# The mean CGPA of team 39  is 4.11
# The variance of team 39  is 0.02470
# The standard deviation of team 39  is 0.15717
#
# Team 40
# The mean CGPA of team 40  is 4.07
# The variance of team 40  is 0.01639
# The standard deviation of team 40  is 0.12802
#
# Team 41
# The mean CGPA of team 41  is 4.11
# The variance of team 41  is 0.02337
# The standard deviation of team 41  is 0.15286
#
# Team 42
# The mean CGPA of team 42  is 4.09
# The variance of team 42  is 0.00433
# The standard deviation of team 42  is 0.06580
#
# Team 43
# The mean CGPA of team 43  is 4.08
# The variance of team 43  is 0.00746
# The standard deviation of team 43  is 0.08638
#
# Team 44
# The mean CGPA of team 44  is 4.06
# The variance of team 44  is 0.00513
# The standard deviation of team 44  is 0.07162
#
# Team 45
# The mean CGPA of team 45  is 4.10
# The variance of team 45  is 0.01456
# The standard deviation of team 45  is 0.12068
#
# Team 46
# The mean CGPA of team 46  is 4.11
# The variance of team 46  is 0.00442
# The standard deviation of team 46  is 0.06651
#
# Team 47
# The mean CGPA of team 47  is 4.16
# The variance of team 47  is 0.01954
# The standard deviation of team 47  is 0.13979
#
# Team 48
# The mean CGPA of team 48  is 4.15
# The variance of team 48  is 0.01854
# The standard deviation of team 48  is 0.13618
#
# Team 49
# The mean CGPA of team 49  is 4.08
# The variance of team 49  is 0.01312
# The standard deviation of team 49  is 0.11455
#
# Team 50
# The mean CGPA of team 50  is 4.08
# The variance of team 50  is 0.01591
# The standard deviation of team 50  is 0.12613
#
# Team 51
# The mean CGPA of team 51  is 4.08
# The variance of team 51  is 0.00898
# The standard deviation of team 51  is 0.09474
#
# Team 52
# The mean CGPA of team 52  is 4.07
# The variance of team 52  is 0.01294
# The standard deviation of team 52  is 0.11374
#
# Team 53
# The mean CGPA of team 53  is 4.07
# The variance of team 53  is 0.02534
# The standard deviation of team 53  is 0.15919
#
# Team 54
# The mean CGPA of team 54  is 4.06
# The variance of team 54  is 0.00380
# The standard deviation of team 54  is 0.06161
#
# Team 55
# The mean CGPA of team 55  is 4.10
# The variance of team 55  is 0.01905
# The standard deviation of team 55  is 0.13802
#
# Team 56
# The mean CGPA of team 56  is 4.12
# The variance of team 56  is 0.01119
# The standard deviation of team 56  is 0.10578
#
# Team 57
# The mean CGPA of team 57  is 4.11
# The variance of team 57  is 0.00746
# The standard deviation of team 57  is 0.08635
#
# Team 58
# The mean CGPA of team 58  is 4.14
# The variance of team 58  is 0.02002
# The standard deviation of team 58  is 0.14148
#
# Team 59
# The mean CGPA of team 59  is 4.12
# The variance of team 59  is 0.03150
# The standard deviation of team 59  is 0.17749
#
# Team 60
# The mean CGPA of team 60  is 4.06
# The variance of team 60  is 0.02116
# The standard deviation of team 60  is 0.14547
#
# Team 61
# The mean CGPA of team 61  is 4.05
# The variance of team 61  is 0.01272
# The standard deviation of team 61  is 0.11280
#
# Team 62
# The mean CGPA of team 62  is 4.09
# The variance of team 62  is 0.01222
# The standard deviation of team 62  is 0.11055
#
# Team 63
# The mean CGPA of team 63  is 4.05
# The variance of team 63  is 0.00842
# The standard deviation of team 63  is 0.09179
#
# Team 64
# The mean CGPA of team 64  is 4.05
# The variance of team 64  is 0.00698
# The standard deviation of team 64  is 0.08352
#
# Team 65
# The mean CGPA of team 65  is 4.06
# The variance of team 65  is 0.01686
# The standard deviation of team 65  is 0.12983
#
# Team 66
# The mean CGPA of team 66  is 4.05
# The variance of team 66  is 0.01231
# The standard deviation of team 66  is 0.11093
#
# Team 67
# The mean CGPA of team 67  is 4.09
# The variance of team 67  is 0.00846
# The standard deviation of team 67  is 0.09196
#
# Team 68
# The mean CGPA of team 68  is 4.14
# The variance of team 68  is 0.02236
# The standard deviation of team 68  is 0.14954
#
# Team 69
# The mean CGPA of team 69  is 4.04
# The variance of team 69  is 0.01796
# The standard deviation of team 69  is 0.13402
#
# Team 70
# The mean CGPA of team 70  is 4.05
# The variance of team 70  is 0.01476
# The standard deviation of team 70  is 0.12147
#
# Team 71
# The mean CGPA of team 71  is 4.05
# The variance of team 71  is 0.01096
# The standard deviation of team 71  is 0.10471
#
# Team 72
# The mean CGPA of team 72  is 4.08
# The variance of team 72  is 0.01026
# The standard deviation of team 72  is 0.10127
#
# Team 73
# The mean CGPA of team 73  is 4.09
# The variance of team 73  is 0.00304
# The standard deviation of team 73  is 0.05517
#
# Team 74
# The mean CGPA of team 74  is 4.02
# The variance of team 74  is 0.00756
# The standard deviation of team 74  is 0.08697
#
# Team 75
# The mean CGPA of team 75  is 4.06
# The variance of team 75  is 0.01459
# The standard deviation of team 75  is 0.12078
#
# Team 76
# The mean CGPA of team 76  is 4.08
# The variance of team 76  is 0.00868
# The standard deviation of team 76  is 0.09315
#
# Team 77
# The mean CGPA of team 77  is 4.08
# The variance of team 77  is 0.00391
# The standard deviation of team 77  is 0.06249
#
# Team 78
# The mean CGPA of team 78  is 4.05
# The variance of team 78  is 0.00610
# The standard deviation of team 78  is 0.07808
#
# Team 79
# The mean CGPA of team 79  is 4.11
# The variance of team 79  is 0.02390
# The standard deviation of team 79  is 0.15460
#
# Team 80
# The mean CGPA of team 80  is 4.09
# The variance of team 80  is 0.01782
# The standard deviation of team 80  is 0.13351
#
# Team 81
# The mean CGPA of team 81  is 4.06
# The variance of team 81  is 0.01346
# The standard deviation of team 81  is 0.11602
#
# Team 82
# The mean CGPA of team 82  is 4.09
# The variance of team 82  is 0.00460
# The standard deviation of team 82  is 0.06779
#
# Team 83
# The mean CGPA of team 83  is 4.08
# The variance of team 83  is 0.00664
# The standard deviation of team 83  is 0.08149
#
# Team 84
# The mean CGPA of team 84  is 4.12
# The variance of team 84  is 0.02658
# The standard deviation of team 84  is 0.16303
#
# Team 85
# The mean CGPA of team 85  is 4.04
# The variance of team 85  is 0.01626
# The standard deviation of team 85  is 0.12753
#
# Team 86
# The mean CGPA of team 86  is 4.06
# The variance of team 86  is 0.01259
# The standard deviation of team 86  is 0.11220
#
# Team 87
# The mean CGPA of team 87  is 4.09
# The variance of team 87  is 0.00560
# The standard deviation of team 87  is 0.07481
#
# Team 88
# The mean CGPA of team 88  is 4.11
# The variance of team 88  is 0.00615
# The standard deviation of team 88  is 0.07842
#
# Team 89
# The mean CGPA of team 89  is 4.05
# The variance of team 89  is 0.00966
# The standard deviation of team 89  is 0.09829
#
# Team 90
# The mean CGPA of team 90  is 4.06
# The variance of team 90  is 0.01067
# The standard deviation of team 90  is 0.10329
#
# Team 91
# The mean CGPA of team 91  is 4.09
# The variance of team 91  is 0.00518
# The standard deviation of team 91  is 0.07200
#
# Team 92
# The mean CGPA of team 92  is 4.07
# The variance of team 92  is 0.00430
# The standard deviation of team 92  is 0.06558
#
# Team 93
# The mean CGPA of team 93  is 4.09
# The variance of team 93  is 0.00798
# The standard deviation of team 93  is 0.08935
#
# Team 94
# The mean CGPA of team 94  is 4.06
# The variance of team 94  is 0.01052
# The standard deviation of team 94  is 0.10259
#
# Team 95
# The mean CGPA of team 95  is 4.06
# The variance of team 95  is 0.02206
# The standard deviation of team 95  is 0.14851
#
# Team 96
# The mean CGPA of team 96  is 4.08
# The variance of team 96  is 0.00720
# The standard deviation of team 96  is 0.08488
#
# Team 97
# The mean CGPA of team 97  is 4.13
# The variance of team 97  is 0.02202
# The standard deviation of team 97  is 0.14838
#
# Team 98
# The mean CGPA of team 98  is 4.06
# The variance of team 98  is 0.00406
# The standard deviation of team 98  is 0.06373
#
# Team 99
# The mean CGPA of team 99  is 4.08
# The variance of team 99  is 0.01028
# The standard deviation of team 99  is 0.10140
#
# Team 100
# The mean CGPA of team 100  is 4.05
# The variance of team 100  is 0.01630
# The standard deviation of team 100  is 0.12769
#
# Team 101
# The mean CGPA of team 101  is 4.08
# The variance of team 101  is 0.01161
# The standard deviation of team 101  is 0.10773
#
# Team 102
# The mean CGPA of team 102  is 4.08
# The variance of team 102  is 0.00869
# The standard deviation of team 102  is 0.09321
#
# Team 103
# The mean CGPA of team 103  is 4.08
# The variance of team 103  is 0.00503
# The standard deviation of team 103  is 0.07092
#
# Team 104
# The mean CGPA of team 104  is 4.07
# The variance of team 104  is 0.01088
# The standard deviation of team 104  is 0.10431
#
# Team 105
# The mean CGPA of team 105  is 4.09
# The variance of team 105  is 0.01194
# The standard deviation of team 105  is 0.10927
#
# Team 106
# The mean CGPA of team 106  is 4.08
# The variance of team 106  is 0.00785
# The standard deviation of team 106  is 0.08859
#
# Team 107
# The mean CGPA of team 107  is 4.09
# The variance of team 107  is 0.01184
# The standard deviation of team 107  is 0.10881
#
# Team 108
# The mean CGPA of team 108  is 4.06
# The variance of team 108  is 0.00974
# The standard deviation of team 108  is 0.09871
#
# Team 109
# The mean CGPA of team 109  is 4.09
# The variance of team 109  is 0.00576
# The standard deviation of team 109  is 0.07587
#
# Team 110
# The mean CGPA of team 110  is 4.05
# The variance of team 110  is 0.02448
# The standard deviation of team 110  is 0.15646
#
# Team 111
# The mean CGPA of team 111  is 4.08
# The variance of team 111  is 0.00944
# The standard deviation of team 111  is 0.09718
#
# Team 112
# The mean CGPA of team 112  is 4.06
# The variance of team 112  is 0.01320
# The standard deviation of team 112  is 0.11490
#
# Team 113
# The mean CGPA of team 113  is 4.10
# The variance of team 113  is 0.04930
# The standard deviation of team 113  is 0.22203
#
# Team 114
# The mean CGPA of team 114  is 4.09
# The variance of team 114  is 0.02248
# The standard deviation of team 114  is 0.14995
#
# Team 115
# The mean CGPA of team 115  is 4.02
# The variance of team 115  is 0.01706
# The standard deviation of team 115  is 0.13063
#
# Team 116
# The mean CGPA of team 116  is 4.06
# The variance of team 116  is 0.01051
# The standard deviation of team 116  is 0.10251
#
# Team 117
# The mean CGPA of team 117  is 4.08
# The variance of team 117  is 0.00734
# The standard deviation of team 117  is 0.08568
#
# Team 118
# The mean CGPA of team 118  is 4.09
# The variance of team 118  is 0.00575
# The standard deviation of team 118  is 0.07582
#
# Team 119
# The mean CGPA of team 119  is 4.03
# The variance of team 119  is 0.00393
# The standard deviation of team 119  is 0.06268
#
# Team 120
# The mean CGPA of team 120  is 4.08
# The variance of team 120  is 0.01396
# The standard deviation of team 120  is 0.11814
#
# Team 121
# The mean CGPA of team 121  is 4.08
# The variance of team 121  is 0.00676
# The standard deviation of team 121  is 0.08222
#
# Team 122
# The mean CGPA of team 122  is 4.07
# The variance of team 122  is 0.01422
# The standard deviation of team 122  is 0.11926
#
# Team 123
# The mean CGPA of team 123  is 4.09
# The variance of team 123  is 0.00416
# The standard deviation of team 123  is 0.06450
#
# Team 124
# The mean CGPA of team 124  is 4.14
# The variance of team 124  is 0.04388
# The standard deviation of team 124  is 0.20948
#
# Team 125
# The mean CGPA of team 125  is 4.08
# The variance of team 125  is 0.01661
# The standard deviation of team 125  is 0.12888
#
# Team 126
# The mean CGPA of team 126  is 4.10
# The variance of team 126  is 0.01172
# The standard deviation of team 126  is 0.10826
#
# Team 127
# The mean CGPA of team 127  is 4.07
# The variance of team 127  is 0.01366
# The standard deviation of team 127  is 0.11686
#
# Team 128
# The mean CGPA of team 128  is 4.09
# The variance of team 128  is 0.01212
# The standard deviation of team 128  is 0.11007
#
# Team 129
# The mean CGPA of team 129  is 4.06
# The variance of team 129  is 0.00753
# The standard deviation of team 129  is 0.08677
#
# Team 130
# The mean CGPA of team 130  is 4.07
# The variance of team 130  is 0.01778
# The standard deviation of team 130  is 0.13336
#
# Team 131
# The mean CGPA of team 131  is 4.05
# The variance of team 131  is 0.01194
# The standard deviation of team 131  is 0.10929
#
# Team 132
# The mean CGPA of team 132  is 4.08
# The variance of team 132  is 0.01532
# The standard deviation of team 132  is 0.12378
#
# Team 133
# The mean CGPA of team 133  is 4.08
# The variance of team 133  is 0.00406
# The standard deviation of team 133  is 0.06376
#
# Team 134
# The mean CGPA of team 134  is 4.10
# The variance of team 134  is 0.03890
# The standard deviation of team 134  is 0.19724
#
# Team 135
# The mean CGPA of team 135  is 4.08
# The variance of team 135  is 0.01374
# The standard deviation of team 135  is 0.11723
#
# Team 136
# The mean CGPA of team 136  is 4.06
# The variance of team 136  is 0.01527
# The standard deviation of team 136  is 0.12357
#
# Team 137
# The mean CGPA of team 137  is 4.11
# The variance of team 137  is 0.00630
# The standard deviation of team 137  is 0.07937
#
# Team 138
# The mean CGPA of team 138  is 4.04
# The variance of team 138  is 0.00844
# The standard deviation of team 138  is 0.09189
#
# Team 139
# The mean CGPA of team 139  is 4.09
# The variance of team 139  is 0.00337
# The standard deviation of team 139  is 0.05801
#
# Team 140
# The mean CGPA of team 140  is 4.07
# The variance of team 140  is 0.01624
# The standard deviation of team 140  is 0.12742
#
# Team 141
# The mean CGPA of team 141  is 4.10
# The variance of team 141  is 0.00932
# The standard deviation of team 141  is 0.09656
#
# Team 142
# The mean CGPA of team 142  is 4.07
# The variance of team 142  is 0.00321
# The standard deviation of team 142  is 0.05665
#
# Team 143
# The mean CGPA of team 143  is 4.08
# The variance of team 143  is 0.03279
# The standard deviation of team 143  is 0.18108
#
# Team 144
# The mean CGPA of team 144  is 4.10
# The variance of team 144  is 0.00317
# The standard deviation of team 144  is 0.05629
#
# Team 145
# The mean CGPA of team 145  is 4.07
# The variance of team 145  is 0.01814
# The standard deviation of team 145  is 0.13467
#
# Team 146
# The mean CGPA of team 146  is 4.09
# The variance of team 146  is 0.01634
# The standard deviation of team 146  is 0.12783
#
# Team 147
# The mean CGPA of team 147  is 4.08
# The variance of team 147  is 0.01160
# The standard deviation of team 147  is 0.10768
#
# Team 148
# The mean CGPA of team 148  is 4.14
# The variance of team 148  is 0.02038
# The standard deviation of team 148  is 0.14278
#
# Team 149
# The mean CGPA of team 149  is 4.10
# The variance of team 149  is 0.00610
# The standard deviation of team 149  is 0.07810
#
# Team 150
# The mean CGPA of team 150  is 4.11
# The variance of team 150  is 0.06632
# The standard deviation of team 150  is 0.25753
#
# Team 151
# The mean CGPA of team 151  is 4.09
# The variance of team 151  is 0.01678
# The standard deviation of team 151  is 0.12954
#
# Team 152
# The mean CGPA of team 152  is 4.09
# The variance of team 152  is 0.00999
# The standard deviation of team 152  is 0.09994
#
# Team 153
# The mean CGPA of team 153  is 4.11
# The variance of team 153  is 0.00746
# The standard deviation of team 153  is 0.08635
#
# Team 154
# The mean CGPA of team 154  is 4.12
# The variance of team 154  is 0.00790
# The standard deviation of team 154  is 0.08889
#
# Team 155
# The mean CGPA of team 155  is 4.08
# The variance of team 155  is 0.01283
# The standard deviation of team 155  is 0.11327
#
# Team 156
# The mean CGPA of team 156  is 4.07
# The variance of team 156  is 0.01161
# The standard deviation of team 156  is 0.10775
#
# Team 157
# The mean CGPA of team 157  is 4.09
# The variance of team 157  is 0.00419
# The standard deviation of team 157  is 0.06472
#
# Team 158
# The mean CGPA of team 158  is 4.08
# The variance of team 158  is 0.00272
# The standard deviation of team 158  is 0.05216
#
# Team 159
# The mean CGPA of team 159  is 4.10
# The variance of team 159  is 0.01550
# The standard deviation of team 159  is 0.12450
#
# Team 160
# The mean CGPA of team 160  is 4.13
# The variance of team 160  is 0.02738
# The standard deviation of team 160  is 0.16548
#
# Team 161
# The mean CGPA of team 161  is 4.10
# The variance of team 161  is 0.00846
# The standard deviation of team 161  is 0.09198
#
# Team 162
# The mean CGPA of team 162  is 4.11
# The variance of team 162  is 0.00607
# The standard deviation of team 162  is 0.07788
#
# Team 163
# The mean CGPA of team 163  is 4.10
# The variance of team 163  is 0.00942
# The standard deviation of team 163  is 0.09708
#
# Team 164
# The mean CGPA of team 164  is 4.10
# The variance of team 164  is 0.02672
# The standard deviation of team 164  is 0.16345
#
# Team 165
# The mean CGPA of team 165  is 4.08
# The variance of team 165  is 0.01766
# The standard deviation of team 165  is 0.13289
#
# Team 166
# The mean CGPA of team 166  is 4.08
# The variance of team 166  is 0.01358
# The standard deviation of team 166  is 0.11653
#
# Team 167
# The mean CGPA of team 167  is 4.10
# The variance of team 167  is 0.00706
# The standard deviation of team 167  is 0.08405
#
# Team 168
# The mean CGPA of team 168  is 4.10
# The variance of team 168  is 0.00488
# The standard deviation of team 168  is 0.06983
#
# Team 169
# The mean CGPA of team 169  is 4.08
# The variance of team 169  is 0.01847
# The standard deviation of team 169  is 0.13590
#
# Team 170
# The mean CGPA of team 170  is 4.09
# The variance of team 170  is 0.01407
# The standard deviation of team 170  is 0.11861
#
# Team 171
# The mean CGPA of team 171  is 4.13
# The variance of team 171  is 0.00613
# The standard deviation of team 171  is 0.07829
#
# Team 172
# The mean CGPA of team 172  is 4.12
# The variance of team 172  is 0.00456
# The standard deviation of team 172  is 0.06756
#
# Team 173
# The mean CGPA of team 173  is 4.09
# The variance of team 173  is 0.00796
# The standard deviation of team 173  is 0.08922
#
# Team 174
# The mean CGPA of team 174  is 4.12
# The variance of team 174  is 0.01216
# The standard deviation of team 174  is 0.11028
#
# Team 175
# The mean CGPA of team 175  is 4.07
# The variance of team 175  is 0.02102
# The standard deviation of team 175  is 0.14499
#
# Team 176
# The mean CGPA of team 176  is 4.07
# The variance of team 176  is 0.01638
# The standard deviation of team 176  is 0.12799
#
# Team 177
# The mean CGPA of team 177  is 4.10
# The variance of team 177  is 0.00988
# The standard deviation of team 177  is 0.09942
#
# Team 178
# The mean CGPA of team 178  is 4.07
# The variance of team 178  is 0.00560
# The standard deviation of team 178  is 0.07484
#
# Team 179
# The mean CGPA of team 179  is 4.07
# The variance of team 179  is 0.00885
# The standard deviation of team 179  is 0.09407
#
# Team 180
# The mean CGPA of team 180  is 4.13
# The variance of team 180  is 0.03177
# The standard deviation of team 180  is 0.17824
#
# Team 181
# The mean CGPA of team 181  is 4.10
# The variance of team 181  is 0.01125
# The standard deviation of team 181  is 0.10606
#
# Team 182
# The mean CGPA of team 182  is 4.08
# The variance of team 182  is 0.00842
# The standard deviation of team 182  is 0.09178
#
# Team 183
# The mean CGPA of team 183  is 4.20
# The variance of team 183  is 0.06911
# The standard deviation of team 183  is 0.26289
#
# Team 184
# The mean CGPA of team 184  is 4.13
# The variance of team 184  is 0.01989
# The standard deviation of team 184  is 0.14103
#
# Team 185
# The mean CGPA of team 185  is 4.05
# The variance of team 185  is 0.02134
# The standard deviation of team 185  is 0.14607
#
# Team 186
# The mean CGPA of team 186  is 4.13
# The variance of team 186  is 0.02869
# The standard deviation of team 186  is 0.16938
#
# Team 187
# The mean CGPA of team 187  is 4.10
# The variance of team 187  is 0.00976
# The standard deviation of team 187  is 0.09881
#
# Team 188
# The mean CGPA of team 188  is 4.07
# The variance of team 188  is 0.01092
# The standard deviation of team 188  is 0.10450
#
# Team 189
# The mean CGPA of team 189  is 4.09
# The variance of team 189  is 0.00968
# The standard deviation of team 189  is 0.09839
#
# Team 190
# The mean CGPA of team 190  is 4.07
# The variance of team 190  is 0.01230
# The standard deviation of team 190  is 0.11092
#
# Team 191
# The mean CGPA of team 191  is 4.09
# The variance of team 191  is 0.00552
# The standard deviation of team 191  is 0.07427
#
# Team 192
# The mean CGPA of team 192  is 4.09
# The variance of team 192  is 0.00391
# The standard deviation of team 192  is 0.06252
#
# Team 193
# The mean CGPA of team 193  is 4.06
# The variance of team 193  is 0.01080
# The standard deviation of team 193  is 0.10394
#
# Team 194
# The mean CGPA of team 194  is 4.08
# The variance of team 194  is 0.01356
# The standard deviation of team 194  is 0.11646
#
# Team 195
# The mean CGPA of team 195  is 4.11
# The variance of team 195  is 0.03286
# The standard deviation of team 195  is 0.18126
#
# Team 196
# The mean CGPA of team 196  is 4.07
# The variance of team 196  is 0.00996
# The standard deviation of team 196  is 0.09978
#
# Team 197
# The mean CGPA of team 197  is 4.09
# The variance of team 197  is 0.00404
# The standard deviation of team 197  is 0.06353
#
# Team 198
# The mean CGPA of team 198  is 4.10
# The variance of team 198  is 0.00710
# The standard deviation of team 198  is 0.08427
#
# Team 199
# The mean CGPA of team 199  is 4.15
# The variance of team 199  is 0.03888
# The standard deviation of team 199  is 0.19717
#
# Team 200
# The mean CGPA of team 200  is 4.07
# The variance of team 200  is 0.01893
# The standard deviation of team 200  is 0.13758
#
# Team 201
# The mean CGPA of team 201  is 4.09
# The variance of team 201  is 0.01133
# The standard deviation of team 201  is 0.10644
#
# Team 202
# The mean CGPA of team 202  is 4.12
# The variance of team 202  is 0.00528
# The standard deviation of team 202  is 0.07267
#
# Team 203
# The mean CGPA of team 203  is 4.12
# The variance of team 203  is 0.01105
# The standard deviation of team 203  is 0.10511
#
# Team 204
# The mean CGPA of team 204  is 4.08
# The variance of team 204  is 0.00806
# The standard deviation of team 204  is 0.08978
#
# Team 205
# The mean CGPA of team 205  is 4.10
# The variance of team 205  is 0.03592
# The standard deviation of team 205  is 0.18952
#
# Team 206
# The mean CGPA of team 206  is 4.07
# The variance of team 206  is 0.01436
# The standard deviation of team 206  is 0.11984
#
# Team 207
# The mean CGPA of team 207  is 4.13
# The variance of team 207  is 0.03039
# The standard deviation of team 207  is 0.17432
#
# Team 208
# The mean CGPA of team 208  is 4.10
# The variance of team 208  is 0.02810
# The standard deviation of team 208  is 0.16763
#
# Team 209
# The mean CGPA of team 209  is 4.09
# The variance of team 209  is 0.00699
# The standard deviation of team 209  is 0.08360
#
# Team 210
# The mean CGPA of team 210  is 4.08
# The variance of team 210  is 0.01124
# The standard deviation of team 210  is 0.10602
#
# Team 211
# The mean CGPA of team 211  is 4.08
# The variance of team 211  is 0.00392
# The standard deviation of team 211  is 0.06262
#
# Team 212
# The mean CGPA of team 212  is 4.07
# The variance of team 212  is 0.00262
# The standard deviation of team 212  is 0.05122
#
# Team 213
# The mean CGPA of team 213  is 4.09
# The variance of team 213  is 0.00306
# The standard deviation of team 213  is 0.05528
#
# Team 214
# The mean CGPA of team 214  is 4.08
# The variance of team 214  is 0.01005
# The standard deviation of team 214  is 0.10024
#
# Team 215
# The mean CGPA of team 215  is 4.07
# The variance of team 215  is 0.01292
# The standard deviation of team 215  is 0.11367
#
# Team 216
# The mean CGPA of team 216  is 4.11
# The variance of team 216  is 0.00828
# The standard deviation of team 216  is 0.09097
#
# Team 217
# The mean CGPA of team 217  is 4.11
# The variance of team 217  is 0.00408
# The standard deviation of team 217  is 0.06384
#
# Team 218
# The mean CGPA of team 218  is 4.10
# The variance of team 218  is 0.00429
# The standard deviation of team 218  is 0.06549
#
# Team 219
# The mean CGPA of team 219  is 4.14
# The variance of team 219  is 0.02220
# The standard deviation of team 219  is 0.14900
#
# Team 220
# The mean CGPA of team 220  is 4.06
# The variance of team 220  is 0.01760
# The standard deviation of team 220  is 0.13267
#
# Team 221
# The mean CGPA of team 221  is 4.07
# The variance of team 221  is 0.01380
# The standard deviation of team 221  is 0.11749
#
# Team 222
# The mean CGPA of team 222  is 4.07
# The variance of team 222  is 0.00390
# The standard deviation of team 222  is 0.06248
#
# Team 223
# The mean CGPA of team 223  is 4.06
# The variance of team 223  is 0.01877
# The standard deviation of team 223  is 0.13700
#
# Team 224
# The mean CGPA of team 224  is 4.06
# The variance of team 224  is 0.00692
# The standard deviation of team 224  is 0.08319
#
# Team 225
# The mean CGPA of team 225  is 4.03
# The variance of team 225  is 0.01709
# The standard deviation of team 225  is 0.13072
#
# Team 226
# The mean CGPA of team 226  is 4.06
# The variance of team 226  is 0.01870
# The standard deviation of team 226  is 0.13676
#
# Team 227
# The mean CGPA of team 227  is 4.04
# The variance of team 227  is 0.00915
# The standard deviation of team 227  is 0.09565
#
# Team 228
# The mean CGPA of team 228  is 4.14
# The variance of team 228  is 0.08204
# The standard deviation of team 228  is 0.28643
#
# Team 229
# The mean CGPA of team 229  is 4.03
# The variance of team 229  is 0.00910
# The standard deviation of team 229  is 0.09537
#
# Team 230
# The mean CGPA of team 230  is 4.06
# The variance of team 230  is 0.01488
# The standard deviation of team 230  is 0.12200
#
# Team 231
# The mean CGPA of team 231  is 4.05
# The variance of team 231  is 0.01112
# The standard deviation of team 231  is 0.10546
#
# Team 232
# The mean CGPA of team 232  is 4.06
# The variance of team 232  is 0.00726
# The standard deviation of team 232  is 0.08521
#
# Team 233
# The mean CGPA of team 233  is 4.09
# The variance of team 233  is 0.00560
# The standard deviation of team 233  is 0.07486
#
# Team 234
# The mean CGPA of team 234  is 4.04
# The variance of team 234  is 0.01267
# The standard deviation of team 234  is 0.11256
#
# Team 235
# The mean CGPA of team 235  is 4.08
# The variance of team 235  is 0.01328
# The standard deviation of team 235  is 0.11526
#
# Team 236
# The mean CGPA of team 236  is 4.11
# The variance of team 236  is 0.01274
# The standard deviation of team 236  is 0.11288
#
# Team 237
# The mean CGPA of team 237  is 4.10
# The variance of team 237  is 0.00418
# The standard deviation of team 237  is 0.06466
#
# Team 238
# The mean CGPA of team 238  is 4.15
# The variance of team 238  is 0.05564
# The standard deviation of team 238  is 0.23589
#
# Team 239
# The mean CGPA of team 239  is 4.13
# The variance of team 239  is 0.00381
# The standard deviation of team 239  is 0.06172
#
# Team 240
# The mean CGPA of team 240  is 4.06
# The variance of team 240  is 0.01364
# The standard deviation of team 240  is 0.11679
#
# Team 241
# The mean CGPA of team 241  is 4.11
# The variance of team 241  is 0.00722
# The standard deviation of team 241  is 0.08495
#
# Team 242
# The mean CGPA of team 242  is 4.07
# The variance of team 242  is 0.00406
# The standard deviation of team 242  is 0.06375
#
# Team 243
# The mean CGPA of team 243  is 4.09
# The variance of team 243  is 0.01166
# The standard deviation of team 243  is 0.10800
#
# Team 244
# The mean CGPA of team 244  is 4.08
# The variance of team 244  is 0.00958
# The standard deviation of team 244  is 0.09786
#
# Team 245
# The mean CGPA of team 245  is 4.09
# The variance of team 245  is 0.01196
# The standard deviation of team 245  is 0.10937
#
# Team 246
# The mean CGPA of team 246  is 4.11
# The variance of team 246  is 0.00584
# The standard deviation of team 246  is 0.07645
#
# Team 247
# The mean CGPA of team 247  is 4.11
# The variance of team 247  is 0.01094
# The standard deviation of team 247  is 0.10460
#
# Team 248
# The mean CGPA of team 248  is 4.09
# The variance of team 248  is 0.00348
# The standard deviation of team 248  is 0.05896
#
# Team 249
# The mean CGPA of team 249  is 4.15
# The variance of team 249  is 0.06316
# The standard deviation of team 249  is 0.25131
#
# Team 250
# The mean CGPA of team 250  is 4.08
# The variance of team 250  is 0.01196
# The standard deviation of team 250  is 0.10934
#
# Team 251
# The mean CGPA of team 251  is 4.12
# The variance of team 251  is 0.02369
# The standard deviation of team 251  is 0.15391
#
# Team 252
# The mean CGPA of team 252  is 4.07
# The variance of team 252  is 0.00834
# The standard deviation of team 252  is 0.09130
#
# Team 253
# The mean CGPA of team 253  is 4.11
# The variance of team 253  is 0.02268
# The standard deviation of team 253  is 0.15060
#
# Team 254
# The mean CGPA of team 254  is 4.13
# The variance of team 254  is 0.04841
# The standard deviation of team 254  is 0.22002
#
# Team 255
# The mean CGPA of team 255  is 4.05
# The variance of team 255  is 0.01636
# The standard deviation of team 255  is 0.12792
#
# Team 256
# The mean CGPA of team 256  is 4.07
# The variance of team 256  is 0.00936
# The standard deviation of team 256  is 0.09675
#
# Team 257
# The mean CGPA of team 257  is 4.05
# The variance of team 257  is 0.01190
# The standard deviation of team 257  is 0.10907
#
# Team 258
# The mean CGPA of team 258  is 4.05
# The variance of team 258  is 0.00286
# The standard deviation of team 258  is 0.05349
#
# Team 259
# The mean CGPA of team 259  is 4.12
# The variance of team 259  is 0.02878
# The standard deviation of team 259  is 0.16965
#
# Team 260
# The mean CGPA of team 260  is 4.06
# The variance of team 260  is 0.01363
# The standard deviation of team 260  is 0.11674
#
# Team 261
# The mean CGPA of team 261  is 4.09
# The variance of team 261  is 0.00692
# The standard deviation of team 261  is 0.08319
#
# Team 262
# The mean CGPA of team 262  is 4.10
# The variance of team 262  is 0.00485
# The standard deviation of team 262  is 0.06963
#
# Team 263
# The mean CGPA of team 263  is 4.04
# The variance of team 263  is 0.01090
# The standard deviation of team 263  is 0.10441
#
# Team 264
# The mean CGPA of team 264  is 4.10
# The variance of team 264  is 0.00365
# The standard deviation of team 264  is 0.06041
#
# Team 265
# The mean CGPA of team 265  is 4.10
# The variance of team 265  is 0.01673
# The standard deviation of team 265  is 0.12934
#
# Team 266
# The mean CGPA of team 266  is 4.11
# The variance of team 266  is 0.00825
# The standard deviation of team 266  is 0.09082
#
# Team 267
# The mean CGPA of team 267  is 4.16
# The variance of team 267  is 0.04096
# The standard deviation of team 267  is 0.20240
#
# Team 268
# The mean CGPA of team 268  is 4.12
# The variance of team 268  is 0.00639
# The standard deviation of team 268  is 0.07991
#
# Team 269
# The mean CGPA of team 269  is 4.10
# The variance of team 269  is 0.00834
# The standard deviation of team 269  is 0.09135
#
# Team 270
# The mean CGPA of team 270  is 4.08
# The variance of team 270  is 0.01485
# The standard deviation of team 270  is 0.12186
#
# Team 271
# The mean CGPA of team 271  is 4.10
# The variance of team 271  is 0.00641
# The standard deviation of team 271  is 0.08003
#
# Team 272
# The mean CGPA of team 272  is 4.12
# The variance of team 272  is 0.00471
# The standard deviation of team 272  is 0.06859
#
# Team 273
# The mean CGPA of team 273  is 4.08
# The variance of team 273  is 0.00995
# The standard deviation of team 273  is 0.09974
#
# Team 274
# The mean CGPA of team 274  is 4.09
# The variance of team 274  is 0.00460
# The standard deviation of team 274  is 0.06785
#
# Team 275
# The mean CGPA of team 275  is 4.05
# The variance of team 275  is 0.01477
# The standard deviation of team 275  is 0.12153
#
# Team 276
# The mean CGPA of team 276  is 4.07
# The variance of team 276  is 0.00850
# The standard deviation of team 276  is 0.09217
#
# Team 277
# The mean CGPA of team 277  is 4.07
# The variance of team 277  is 0.00714
# The standard deviation of team 277  is 0.08447
#
# Team 278
# The mean CGPA of team 278  is 4.07
# The variance of team 278  is 0.00882
# The standard deviation of team 278  is 0.09392
#
# Team 279
# The mean CGPA of team 279  is 4.07
# The variance of team 279  is 0.00920
# The standard deviation of team 279  is 0.09594
#
# Team 280
# The mean CGPA of team 280  is 4.04
# The variance of team 280  is 0.01204
# The standard deviation of team 280  is 0.10973
#
# Team 281
# The mean CGPA of team 281  is 4.06
# The variance of team 281  is 0.00685
# The standard deviation of team 281  is 0.08273
#
# Team 282
# The mean CGPA of team 282  is 4.08
# The variance of team 282  is 0.00710
# The standard deviation of team 282  is 0.08424
#
# Team 283
# The mean CGPA of team 283  is 4.01
# The variance of team 283  is 0.00474
# The standard deviation of team 283  is 0.06882
#
# Team 284
# The mean CGPA of team 284  is 4.07
# The variance of team 284  is 0.00254
# The standard deviation of team 284  is 0.05040
#
# Team 285
# The mean CGPA of team 285  is 4.09
# The variance of team 285  is 0.01637
# The standard deviation of team 285  is 0.12794
#
# Team 286
# The mean CGPA of team 286  is 4.09
# The variance of team 286  is 0.00971
# The standard deviation of team 286  is 0.09851
#
# Team 287
# The mean CGPA of team 287  is 4.11
# The variance of team 287  is 0.03503
# The standard deviation of team 287  is 0.18716
#
# Team 288
# The mean CGPA of team 288  is 4.14
# The variance of team 288  is 0.02052
# The standard deviation of team 288  is 0.14323
#
# Team 289
# The mean CGPA of team 289  is 4.10
# The variance of team 289  is 0.00418
# The standard deviation of team 289  is 0.06466
#
# Team 290
# The mean CGPA of team 290  is 4.09
# The variance of team 290  is 0.03030
# The standard deviation of team 290  is 0.17408
#
# Team 291
# The mean CGPA of team 291  is 4.06
# The variance of team 291  is 0.01817
# The standard deviation of team 291  is 0.13479
#
# Team 292
# The mean CGPA of team 292  is 4.12
# The variance of team 292  is 0.04966
# The standard deviation of team 292  is 0.22285
#
# Team 293
# The mean CGPA of team 293  is 4.06
# The variance of team 293  is 0.00404
# The standard deviation of team 293  is 0.06357
#
# Team 294
# The mean CGPA of team 294  is 4.04
# The variance of team 294  is 0.01000
# The standard deviation of team 294  is 0.10002
#
# Team 295
# The mean CGPA of team 295  is 4.07
# The variance of team 295  is 0.01306
# The standard deviation of team 295  is 0.11428
#
# Team 296
# The mean CGPA of team 296  is 4.12
# The variance of team 296  is 0.00470
# The standard deviation of team 296  is 0.06859
#
# Team 297
# The mean CGPA of team 297  is 4.10
# The variance of team 297  is 0.00413
# The standard deviation of team 297  is 0.06426
#
# Team 298
# The mean CGPA of team 298  is 4.10
# The variance of team 298  is 0.00272
# The standard deviation of team 298  is 0.05219
#
# Team 299
# The mean CGPA of team 299  is 4.11
# The variance of team 299  is 0.02672
# The standard deviation of team 299  is 0.16346
#
# Team 300
# The mean CGPA of team 300  is 4.08
# The variance of team 300  is 0.01984
# The standard deviation of team 300  is 0.14086
#
# Team 301
# The mean CGPA of team 301  is 4.07
# The variance of team 301  is 0.01616
# The standard deviation of team 301  is 0.12711
#
# Team 302
# The mean CGPA of team 302  is 4.08
# The variance of team 302  is 0.00740
# The standard deviation of team 302  is 0.08603
#
# Team 303
# The mean CGPA of team 303  is 4.07
# The variance of team 303  is 0.01248
# The standard deviation of team 303  is 0.11173
#
# Team 304
# The mean CGPA of team 304  is 4.07
# The variance of team 304  is 0.00662
# The standard deviation of team 304  is 0.08134
#
# Team 305
# The mean CGPA of team 305  is 4.06
# The variance of team 305  is 0.01412
# The standard deviation of team 305  is 0.11881
#
# Team 306
# The mean CGPA of team 306  is 4.06
# The variance of team 306  is 0.00988
# The standard deviation of team 306  is 0.09940
#
# Team 307
# The mean CGPA of team 307  is 4.08
# The variance of team 307  is 0.00732
# The standard deviation of team 307  is 0.08556
#
# Team 308
# The mean CGPA of team 308  is 4.03
# The variance of team 308  is 0.01207
# The standard deviation of team 308  is 0.10986
#
# Team 309
# The mean CGPA of team 309  is 4.08
# The variance of team 309  is 0.00676
# The standard deviation of team 309  is 0.08222
#
# Team 310
# The mean CGPA of team 310  is 4.06
# The variance of team 310  is 0.01722
# The standard deviation of team 310  is 0.13121
#
# Team 311
# The mean CGPA of team 311  is 4.08
# The variance of team 311  is 0.00568
# The standard deviation of team 311  is 0.07537
#
# Team 312
# The mean CGPA of team 312  is 4.05
# The variance of team 312  is 0.00814
# The standard deviation of team 312  is 0.09020
#
# Team 313
# The mean CGPA of team 313  is 4.11
# The variance of team 313  is 0.01319
# The standard deviation of team 313  is 0.11484
#
# Team 314
# The mean CGPA of team 314  is 4.08
# The variance of team 314  is 0.00374
# The standard deviation of team 314  is 0.06119
#
# Team 315
# The mean CGPA of team 315  is 4.08
# The variance of team 315  is 0.01742
# The standard deviation of team 315  is 0.13200
#
# Team 316
# The mean CGPA of team 316  is 4.10
# The variance of team 316  is 0.00863
# The standard deviation of team 316  is 0.09289
#
# Team 317
# The mean CGPA of team 317  is 4.09
# The variance of team 317  is 0.01912
# The standard deviation of team 317  is 0.13829
#
# Team 318
# The mean CGPA of team 318  is 4.11
# The variance of team 318  is 0.00268
# The standard deviation of team 318  is 0.05181
#
# Team 319
# The mean CGPA of team 319  is 4.10
# The variance of team 319  is 0.01134
# The standard deviation of team 319  is 0.10649
#
# Team 320
# The mean CGPA of team 320  is 4.09
# The variance of team 320  is 0.01235
# The standard deviation of team 320  is 0.11113
#
# Team 321
# The mean CGPA of team 321  is 4.08
# The variance of team 321  is 0.00884
# The standard deviation of team 321  is 0.09400
#
# Team 322
# The mean CGPA of team 322  is 4.08
# The variance of team 322  is 0.01256
# The standard deviation of team 322  is 0.11207
#
# Team 323
# The mean CGPA of team 323  is 4.12
# The variance of team 323  is 0.00333
# The standard deviation of team 323  is 0.05766
#
# Team 324
# The mean CGPA of team 324  is 4.09
# The variance of team 324  is 0.00858
# The standard deviation of team 324  is 0.09263
#
# Team 325
# The mean CGPA of team 325  is 4.10
# The variance of team 325  is 0.01632
# The standard deviation of team 325  is 0.12777
#
# Team 326
# The mean CGPA of team 326  is 4.10
# The variance of team 326  is 0.01255
# The standard deviation of team 326  is 0.11202
#
# Team 327
# The mean CGPA of team 327  is 4.15
# The variance of team 327  is 0.01734
# The standard deviation of team 327  is 0.13170
#
# Team 328
# The mean CGPA of team 328  is 4.10
# The variance of team 328  is 0.01352
# The standard deviation of team 328  is 0.11628
#
# Team 329
# The mean CGPA of team 329  is 4.10
# The variance of team 329  is 0.00930
# The standard deviation of team 329  is 0.09642
#
# Team 330
# The mean CGPA of team 330  is 4.08
# The variance of team 330  is 0.01278
# The standard deviation of team 330  is 0.11303
#
# Team 331
# The mean CGPA of team 331  is 4.10
# The variance of team 331  is 0.00718
# The standard deviation of team 331  is 0.08474
#
# Team 332
# The mean CGPA of team 332  is 4.10
# The variance of team 332  is 0.00684
# The standard deviation of team 332  is 0.08270
#
# Team 333
# The mean CGPA of team 333  is 4.11
# The variance of team 333  is 0.00440
# The standard deviation of team 333  is 0.06633
#
# Team 334
# The mean CGPA of team 334  is 4.06
# The variance of team 334  is 0.01854
# The standard deviation of team 334  is 0.13616
#
# Team 335
# The mean CGPA of team 335  is 4.07
# The variance of team 335  is 0.01455
# The standard deviation of team 335  is 0.12062
#
# Team 336
# The mean CGPA of team 336  is 4.08
# The variance of team 336  is 0.01004
# The standard deviation of team 336  is 0.10018
#
# Team 337
# The mean CGPA of team 337  is 4.06
# The variance of team 337  is 0.01092
# The standard deviation of team 337  is 0.10448
#
# Team 338
# The mean CGPA of team 338  is 4.10
# The variance of team 338  is 0.02962
# The standard deviation of team 338  is 0.17210
#
# Team 339
# The mean CGPA of team 339  is 4.07
# The variance of team 339  is 0.00328
# The standard deviation of team 339  is 0.05731
#
# Team 340
# The mean CGPA of team 340  is 4.10
# The variance of team 340  is 0.01154
# The standard deviation of team 340  is 0.10741
#
# Team 341
# The mean CGPA of team 341  is 4.10
# The variance of team 341  is 0.01418
# The standard deviation of team 341  is 0.11906
#
# Team 342
# The mean CGPA of team 342  is 4.11
# The variance of team 342  is 0.00440
# The standard deviation of team 342  is 0.06636
#
# Team 343
# The mean CGPA of team 343  is 4.14
# The variance of team 343  is 0.00716
# The standard deviation of team 343  is 0.08462
#
# Team 344
# The mean CGPA of team 344  is 4.09
# The variance of team 344  is 0.00510
# The standard deviation of team 344  is 0.07142
#
# Team 345
# The mean CGPA of team 345  is 4.08
# The variance of team 345  is 0.01166
# The standard deviation of team 345  is 0.10799
#
# Team 346
# The mean CGPA of team 346  is 4.09
# The variance of team 346  is 0.00946
# The standard deviation of team 346  is 0.09728
#
# Team 347
# The mean CGPA of team 347  is 4.11
# The variance of team 347  is 0.00366
# The standard deviation of team 347  is 0.06050
#
# Team 348
# The mean CGPA of team 348  is 4.10
# The variance of team 348  is 0.00904
# The standard deviation of team 348  is 0.09506
#
# Team 349
# The mean CGPA of team 349  is 4.08
# The variance of team 349  is 0.00242
# The standard deviation of team 349  is 0.04915
#
# Team 350
# The mean CGPA of team 350  is 4.12
# The variance of team 350  is 0.04671
# The standard deviation of team 350  is 0.21612
#
# Team 351
# The mean CGPA of team 351  is 4.08
# The variance of team 351  is 0.01496
# The standard deviation of team 351  is 0.12232
#
# Team 352
# The mean CGPA of team 352  is 4.13
# The variance of team 352  is 0.00782
# The standard deviation of team 352  is 0.08845
#
# Team 353
# The mean CGPA of team 353  is 4.07
# The variance of team 353  is 0.00787
# The standard deviation of team 353  is 0.08871
#
# Team 354
# The mean CGPA of team 354  is 4.11
# The variance of team 354  is 0.02676
# The standard deviation of team 354  is 0.16359
#
# Team 355
# The mean CGPA of team 355  is 4.10
# The variance of team 355  is 0.01359
# The standard deviation of team 355  is 0.11657
#
# Team 356
# The mean CGPA of team 356  is 4.11
# The variance of team 356  is 0.00537
# The standard deviation of team 356  is 0.07327
#
# Team 357
# The mean CGPA of team 357  is 4.11
# The variance of team 357  is 0.00509
# The standard deviation of team 357  is 0.07131
#
# Team 358
# The mean CGPA of team 358  is 4.10
# The variance of team 358  is 0.00180
# The standard deviation of team 358  is 0.04247
#
# Team 359
# The mean CGPA of team 359  is 4.08
# The variance of team 359  is 0.01786
# The standard deviation of team 359  is 0.13366
#
# Team 360
# The mean CGPA of team 360  is 4.08
# The variance of team 360  is 0.00899
# The standard deviation of team 360  is 0.09481
#
# Team 361
# The mean CGPA of team 361  is 4.10
# The variance of team 361  is 0.00785
# The standard deviation of team 361  is 0.08859
#
# Team 362
# The mean CGPA of team 362  is 4.10
# The variance of team 362  is 0.00761
# The standard deviation of team 362  is 0.08723
#
# Team 363
# The mean CGPA of team 363  is 4.07
# The variance of team 363  is 0.00440
# The standard deviation of team 363  is 0.06636
#
# Team 364
# The mean CGPA of team 364  is 4.08
# The variance of team 364  is 0.00894
# The standard deviation of team 364  is 0.09455
#
# Team 365
# The mean CGPA of team 365  is 4.06
# The variance of team 365  is 0.01436
# The standard deviation of team 365  is 0.11985
#
# Team 366
# The mean CGPA of team 366  is 4.09
# The variance of team 366  is 0.00616
# The standard deviation of team 366  is 0.07851
#
# Team 367
# The mean CGPA of team 367  is 4.09
# The variance of team 367  is 0.00701
# The standard deviation of team 367  is 0.08372
#
# Team 368
# The mean CGPA of team 368  is 4.10
# The variance of team 368  is 0.00196
# The standard deviation of team 368  is 0.04432
#
# Team 369
# The mean CGPA of team 369  is 4.08
# The variance of team 369  is 0.02087
# The standard deviation of team 369  is 0.14445
#
# Team 370
# The mean CGPA of team 370  is 4.09
# The variance of team 370  is 0.03566
# The standard deviation of team 370  is 0.18884
#
# Team 371
# The mean CGPA of team 371  is 4.08
# The variance of team 371  is 0.01275
# The standard deviation of team 371  is 0.11289
#
# Team 372
# The mean CGPA of team 372  is 4.10
# The variance of team 372  is 0.00750
# The standard deviation of team 372  is 0.08663
#
# Team 373
# The mean CGPA of team 373  is 4.12
# The variance of team 373  is 0.02088
# The standard deviation of team 373  is 0.14450
#
# Team 374
# The mean CGPA of team 374  is 4.03
# The variance of team 374  is 0.00770
# The standard deviation of team 374  is 0.08773
#
# Team 375
# The mean CGPA of team 375  is 4.08
# ...
# The variance of team 477  is 0.00578
# The standard deviation of team 477  is 0.07605
#
# Team 478
# The mean CGPA of team 478  is 4.07
# The variance of team 478  is 0.00364
# The standard deviation of team 478  is 0.06030
#
# Team 479
# The mean CGPA of team 479  is 4.09
# The variance of team 479  is 0.02622
# The standard deviation of team 479  is 0.16194
#
# Team 480
# The mean CGPA of team 480  is 4.06
# The variance of team 480  is 0.02100
# The standard deviation of team 480  is 0.14493
#
# Team 481
# The mean CGPA of team 481  is 4.07
# The variance of team 481  is 0.01888
# The standard deviation of team 481  is 0.13741
#
# Team 482
# The mean CGPA of team 482  is 4.05
# The variance of team 482  is 0.01464
# The standard deviation of team 482  is 0.12100
#
# Team 483
# The mean CGPA of team 483  is 4.12
# The variance of team 483  is 0.00562
# The standard deviation of team 483  is 0.07497
#
# Team 484
# The mean CGPA of team 484  is 4.08
# The variance of team 484  is 0.01366
# The standard deviation of team 484  is 0.11689
#
# Team 485
# The mean CGPA of team 485  is 4.09
# The variance of team 485  is 0.02043
# The standard deviation of team 485  is 0.14293
#
# Team 486
# The mean CGPA of team 486  is 4.06
# The variance of team 486  is 0.01434
# The standard deviation of team 486  is 0.11975
#
# Team 487
# The mean CGPA of team 487  is 4.06
# The variance of team 487  is 0.00572
# The standard deviation of team 487  is 0.07563
#
# Team 488
# The mean CGPA of team 488  is 4.11
# The variance of team 488  is 0.02210
# The standard deviation of team 488  is 0.14865
#
# Team 489
# The mean CGPA of team 489  is 4.11
# The variance of team 489  is 0.00824
# The standard deviation of team 489  is 0.09080
#
# Team 490
# The mean CGPA of team 490  is 4.06
# The variance of team 490  is 0.01483
# The standard deviation of team 490  is 0.12177
#
# Team 491
# The mean CGPA of team 491  is 4.08
# The variance of team 491  is 0.00912
# The standard deviation of team 491  is 0.09548
#
# Team 492
# The mean CGPA of team 492  is 4.09
# The variance of team 492  is 0.00738
# The standard deviation of team 492  is 0.08591
#
# Team 493
# The mean CGPA of team 493  is 4.07
# The variance of team 493  is 0.00414
# The standard deviation of team 493  is 0.06435
#
# Team 494
# The mean CGPA of team 494  is 4.02
# The variance of team 494  is 0.00809
# The standard deviation of team 494  is 0.08994
#
# Team 495
# The mean CGPA of team 495  is 4.07
# The variance of team 495  is 0.01526
# The standard deviation of team 495  is 0.12354
#
# Team 496
# The mean CGPA of team 496  is 4.09
# The variance of team 496  is 0.00828
# The standard deviation of team 496  is 0.09097
#
# Team 497
# The mean CGPA of team 497  is 4.10
# The variance of team 497  is 0.00348
# The standard deviation of team 497  is 0.05896
#
# Team 498
# The mean CGPA of team 498  is 4.16
# The variance of team 498  is 0.01948
# The standard deviation of team 498  is 0.13959
#
# Team 499
# The mean CGPA of team 499  is 4.05
# The variance of team 499  is 0.00844
# The standard deviation of team 499  is 0.09187
#
# Team 500
# The mean CGPA of team 500  is 4.10
# The variance of team 500  is 0.02868
# The standard deviation of team 500  is 0.16934
#
# Team 501
# The mean CGPA of team 501  is 4.08
# The variance of team 501  is 0.01828
# The standard deviation of team 501  is 0.13522
#
# Team 502
# The mean CGPA of team 502  is 4.13
# The variance of team 502  is 0.02082
# The standard deviation of team 502  is 0.14429
#
# Team 503
# The mean CGPA of team 503  is 4.12
# The variance of team 503  is 0.00380
# The standard deviation of team 503  is 0.06168
#
# Team 504
# The mean CGPA of team 504  is 4.12
# The variance of team 504  is 0.02442
# The standard deviation of team 504  is 0.15628
#
# Team 505
# The mean CGPA of team 505  is 4.10
# The variance of team 505  is 0.01207
# The standard deviation of team 505  is 0.10984
#
# Team 506
# The mean CGPA of team 506  is 4.10
# The variance of team 506  is 0.00776
# The standard deviation of team 506  is 0.08810
#
# Team 507
# The mean CGPA of team 507  is 4.08
# The variance of team 507  is 0.00236
# The standard deviation of team 507  is 0.04862
#
# Team 508
# The mean CGPA of team 508  is 4.12
# The variance of team 508  is 0.00696
# The standard deviation of team 508  is 0.08343
#
# Team 509
# The mean CGPA of team 509  is 4.09
# The variance of team 509  is 0.01397
# The standard deviation of team 509  is 0.11819
#
# Team 510
# The mean CGPA of team 510  is 4.08
# The variance of team 510  is 0.01964
# The standard deviation of team 510  is 0.14015
#
# Team 511
# The mean CGPA of team 511  is 4.10
# The variance of team 511  is 0.01170
# The standard deviation of team 511  is 0.10815
#
# Team 512
# The mean CGPA of team 512  is 4.12
# The variance of team 512  is 0.00588
# The standard deviation of team 512  is 0.07666
#
# Team 513
# The mean CGPA of team 513  is 4.10
# The variance of team 513  is 0.00758
# The standard deviation of team 513  is 0.08704
#
# Team 514
# The mean CGPA of team 514  is 4.12
# The variance of team 514  is 0.02786
# The standard deviation of team 514  is 0.16692
#
# Team 515
# The mean CGPA of team 515  is 4.06
# The variance of team 515  is 0.01153
# The standard deviation of team 515  is 0.10737
#
# Team 516
# The mean CGPA of team 516  is 4.07
# The variance of team 516  is 0.00669
# The standard deviation of team 516  is 0.08179
#
# Team 517
# The mean CGPA of team 517  is 4.08
# The variance of team 517  is 0.00458
# The standard deviation of team 517  is 0.06765
#
# Team 518
# The mean CGPA of team 518  is 4.05
# The variance of team 518  is 0.00294
# The standard deviation of team 518  is 0.05418
#
# Team 519
# The mean CGPA of team 519  is 4.08
# The variance of team 519  is 0.01073
# The standard deviation of team 519  is 0.10358
#
# Team 520
# The mean CGPA of team 520  is 4.08
# The variance of team 520  is 0.01770
# The standard deviation of team 520  is 0.13304
#
# Team 521
# The mean CGPA of team 521  is 4.11
# The variance of team 521  is 0.00547
# The standard deviation of team 521  is 0.07395
#
# Team 522
# The mean CGPA of team 522  is 4.09
# The variance of team 522  is 0.00672
# The standard deviation of team 522  is 0.08195
#
# Team 523
# The mean CGPA of team 523  is 4.09
# The variance of team 523  is 0.01320
# The standard deviation of team 523  is 0.11487
#
# Team 524
# The mean CGPA of team 524  is 4.09
# The variance of team 524  is 0.00886
# The standard deviation of team 524  is 0.09411
#
# Team 525
# The mean CGPA of team 525  is 4.08
# The variance of team 525  is 0.01150
# The standard deviation of team 525  is 0.10724
#
# Team 526
# The mean CGPA of team 526  is 4.06
# The variance of team 526  is 0.01099
# The standard deviation of team 526  is 0.10481
#
# Team 527
# The mean CGPA of team 527  is 4.08
# The variance of team 527  is 0.00652
# The standard deviation of team 527  is 0.08077
#
# Team 528
# The mean CGPA of team 528  is 4.09
# The variance of team 528  is 0.02680
# The standard deviation of team 528  is 0.16371
#
# Team 529
# The mean CGPA of team 529  is 4.11
# The variance of team 529  is 0.01044
# The standard deviation of team 529  is 0.10218
#
# Team 530
# The mean CGPA of team 530  is 4.06
# The variance of team 530  is 0.02079
# The standard deviation of team 530  is 0.14418
#
# Team 531
# The mean CGPA of team 531  is 4.06
# The variance of team 531  is 0.01780
# The standard deviation of team 531  is 0.13342
#
# Team 532
# The mean CGPA of team 532  is 4.08
# The variance of team 532  is 0.00786
# The standard deviation of team 532  is 0.08868
#
# Team 533
# The mean CGPA of team 533  is 4.08
# The variance of team 533  is 0.00574
# The standard deviation of team 533  is 0.07576
#
# Team 534
# The mean CGPA of team 534  is 4.06
# The variance of team 534  is 0.00948
# The standard deviation of team 534  is 0.09739
#
# Team 535
# The mean CGPA of team 535  is 4.10
# The variance of team 535  is 0.03480
# The standard deviation of team 535  is 0.18654
#
# Team 536
# The mean CGPA of team 536  is 4.08
# The variance of team 536  is 0.00856
# The standard deviation of team 536  is 0.09250
#
# Team 537
# The mean CGPA of team 537  is 4.09
# The variance of team 537  is 0.00440
# The standard deviation of team 537  is 0.06634
#
# Team 538
# The mean CGPA of team 538  is 4.06
# The variance of team 538  is 0.00332
# The standard deviation of team 538  is 0.05758
#
# Team 539
# The mean CGPA of team 539  is 4.09
# The variance of team 539  is 0.04029
# The standard deviation of team 539  is 0.20071
#
# Team 540
# The mean CGPA of team 540  is 4.08
# The variance of team 540  is 0.01762
# The standard deviation of team 540  is 0.13273
#
# Team 541
# The mean CGPA of team 541  is 4.07
# The variance of team 541  is 0.01089
# The standard deviation of team 541  is 0.10435
#
# Team 542
# The mean CGPA of team 542  is 4.09
# The variance of team 542  is 0.01129
# The standard deviation of team 542  is 0.10625
#
# Team 543
# The mean CGPA of team 543  is 4.08
# The variance of team 543  is 0.01198
# The standard deviation of team 543  is 0.10946
#
# Team 544
# The mean CGPA of team 544  is 4.10
# The variance of team 544  is 0.00765
# The standard deviation of team 544  is 0.08744
#
# Team 545
# The mean CGPA of team 545  is 4.08
# The variance of team 545  is 0.00706
# The standard deviation of team 545  is 0.08405
#
# Team 546
# The mean CGPA of team 546  is 4.09
# The variance of team 546  is 0.00455
# The standard deviation of team 546  is 0.06742
#
# Team 547
# The mean CGPA of team 547  is 4.09
# The variance of team 547  is 0.00430
# The standard deviation of team 547  is 0.06558
#
# Team 548
# The mean CGPA of team 548  is 4.07
# The variance of team 548  is 0.00231
# The standard deviation of team 548  is 0.04805
#
# Team 549
# The mean CGPA of team 549  is 4.07
# The variance of team 549  is 0.01247
# The standard deviation of team 549  is 0.11166
#
# Team 550
# The mean CGPA of team 550  is 4.07
# The variance of team 550  is 0.02314
# The standard deviation of team 550  is 0.15211
#
# Team 551
# The mean CGPA of team 551  is 4.09
# The variance of team 551  is 0.01446
# The standard deviation of team 551  is 0.12023
#
# Team 552
# The mean CGPA of team 552  is 4.10
# The variance of team 552  is 0.01048
# The standard deviation of team 552  is 0.10238
#
# Team 553
# The mean CGPA of team 553  is 4.08
# The variance of team 553  is 0.00374
# The standard deviation of team 553  is 0.06120
#
# Team 554
# The mean CGPA of team 554  is 4.08
# The variance of team 554  is 0.03896
# The standard deviation of team 554  is 0.19740
#
# Team 555
# The mean CGPA of team 555  is 4.08
# The variance of team 555  is 0.01708
# The standard deviation of team 555  is 0.13069
#
# Team 556
# The mean CGPA of team 556  is 4.11
# The variance of team 556  is 0.00600
# The standard deviation of team 556  is 0.07747
#
# Team 557
# The mean CGPA of team 557  is 4.09
# The variance of team 557  is 0.00306
# The standard deviation of team 557  is 0.05535
#
# Team 558
# The mean CGPA of team 558  is 4.12
# The variance of team 558  is 0.01002
# The standard deviation of team 558  is 0.10010
#
# Team 559
# The mean CGPA of team 559  is 4.12
# The variance of team 559  is 0.02575
# The standard deviation of team 559  is 0.16046
#
# Team 560
# The mean CGPA of team 560  is 4.04
# The variance of team 560  is 0.02516
# The standard deviation of team 560  is 0.15861
#
# Team 561
# The mean CGPA of team 561  is 4.06
# The variance of team 561  is 0.00766
# The standard deviation of team 561  is 0.08754
#
# Team 562
# The mean CGPA of team 562  is 4.08
# The variance of team 562  is 0.01006
# The standard deviation of team 562  is 0.10032
#
# Team 563
# The mean CGPA of team 563  is 4.01
# The variance of team 563  is 0.01216
# The standard deviation of team 563  is 0.11027
#
# Team 564
# The mean CGPA of team 564  is 4.09
# The variance of team 564  is 0.00270
# The standard deviation of team 564  is 0.05196
#
# Team 565
# The mean CGPA of team 565  is 4.09
# The variance of team 565  is 0.02642
# The standard deviation of team 565  is 0.16253
#
# Team 566
# The mean CGPA of team 566  is 4.09
# The variance of team 566  is 0.00766
# The standard deviation of team 566  is 0.08754
#
# Team 567
# The mean CGPA of team 567  is 4.08
# The variance of team 567  is 0.00434
# The standard deviation of team 567  is 0.06592
#
# Team 568
# The mean CGPA of team 568  is 4.14
# The variance of team 568  is 0.02136
# The standard deviation of team 568  is 0.14616
#
# Team 569
# The mean CGPA of team 569  is 4.05
# The variance of team 569  is 0.00521
# The standard deviation of team 569  is 0.07217
#
# Team 570
# The mean CGPA of team 570  is 4.07
# The variance of team 570  is 0.01628
# The standard deviation of team 570  is 0.12761
#
# Team 571
# The mean CGPA of team 571  is 4.12
# The variance of team 571  is 0.00622
# The standard deviation of team 571  is 0.07884
#
# Team 572
# The mean CGPA of team 572  is 4.12
# The variance of team 572  is 0.00522
# The standard deviation of team 572  is 0.07226
#
# Team 573
# The mean CGPA of team 573  is 4.09
# The variance of team 573  is 0.00869
# The standard deviation of team 573  is 0.09321
#
# Team 574
# The mean CGPA of team 574  is 4.08
# The variance of team 574  is 0.01204
# The standard deviation of team 574  is 0.10975
#
# Team 575
# The mean CGPA of team 575  is 4.11
# The variance of team 575  is 0.03011
# The standard deviation of team 575  is 0.17352
#
# Team 576
# The mean CGPA of team 576  is 4.12
# The variance of team 576  is 0.01394
# The standard deviation of team 576  is 0.11808
#
# Team 577
# The mean CGPA of team 577  is 4.10
# The variance of team 577  is 0.00412
# The standard deviation of team 577  is 0.06416
#
# Team 578
# The mean CGPA of team 578  is 4.13
# The variance of team 578  is 0.02634
# The standard deviation of team 578  is 0.16228
#
# Team 579
# The mean CGPA of team 579  is 4.04
# The variance of team 579  is 0.00828
# The standard deviation of team 579  is 0.09102
#
# Team 580
# The mean CGPA of team 580  is 4.10
# The variance of team 580  is 0.01346
# The standard deviation of team 580  is 0.11600
#
# Team 581
# The mean CGPA of team 581  is 4.09
# The variance of team 581  is 0.01517
# The standard deviation of team 581  is 0.12316
#
# Team 582
# The mean CGPA of team 582  is 4.09
# The variance of team 582  is 0.00332
# The standard deviation of team 582  is 0.05763
#
# Team 583
# The mean CGPA of team 583  is 4.08
# The variance of team 583  is 0.00456
# The standard deviation of team 583  is 0.06756
#
# Team 584
# The mean CGPA of team 584  is 4.17
# The variance of team 584  is 0.04846
# The standard deviation of team 584  is 0.22013
#
# Team 585
# The mean CGPA of team 585  is 4.10
# The variance of team 585  is 0.01603
# The standard deviation of team 585  is 0.12661
#
# Team 586
# The mean CGPA of team 586  is 4.13
# The variance of team 586  is 0.01473
# The standard deviation of team 586  is 0.12136
#
# Team 587
# The mean CGPA of team 587  is 4.09
# The variance of team 587  is 0.01054
# The standard deviation of team 587  is 0.10265
#
# Team 588
# The mean CGPA of team 588  is 4.07
# The variance of team 588  is 0.00629
# The standard deviation of team 588  is 0.07930
#
# Team 589
# The mean CGPA of team 589  is 4.14
# The variance of team 589  is 0.02572
# The standard deviation of team 589  is 0.16038
#
# Team 590
# The mean CGPA of team 590  is 4.09
# The variance of team 590  is 0.02034
# The standard deviation of team 590  is 0.14262
#
# Team 591
# The mean CGPA of team 591  is 4.11
# The variance of team 591  is 0.00494
# The standard deviation of team 591  is 0.07029
#
# Team 592
# The mean CGPA of team 592  is 4.11
# The variance of team 592  is 0.00309
# The standard deviation of team 592  is 0.05554
#
# Team 593
# The mean CGPA of team 593  is 4.09
# The variance of team 593  is 0.01089
# The standard deviation of team 593  is 0.10435
#
# Team 594
# The mean CGPA of team 594  is 4.09
# The variance of team 594  is 0.01202
# The standard deviation of team 594  is 0.10964
#
# Team 595
# The mean CGPA of team 595  is 4.14
# The variance of team 595  is 0.02530
# The standard deviation of team 595  is 0.15907
#
# Team 596
# The mean CGPA of team 596  is 4.12
# The variance of team 596  is 0.00630
# The standard deviation of team 596  is 0.07938
#
# Team 597
# The mean CGPA of team 597  is 4.13
# The variance of team 597  is 0.02013
# The standard deviation of team 597  is 0.14188
#
# Team 598
# The mean CGPA of team 598  is 4.12
# The variance of team 598  is 0.02895
# The standard deviation of team 598  is 0.17014
#
# Team 599
# The mean CGPA of team 599  is 4.10
# The variance of team 599  is 0.00338
# The standard deviation of team 599  is 0.05818
#
# The mean of the population is 4.09
# The standard deviation of the population is 0.02675
# {'m4f6': 368, 'm5f5': 51, 'm2f8': 4, 'm6f4': 167, 'm0f10': 2, 'm3f7': 7, 'm1f9': 1}
