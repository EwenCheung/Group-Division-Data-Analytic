# %% [markdown]
# # Team Allocation Simulator #
# by Ewen Cheung Yi Wen (U2423907E), Guan Yibin (U2423353E), Lee Jun Liang Shawn (U2423153L), Lee You De (U2421544H), Lam Wei Hao(Lan Weihao) U2422666H

# %% [markdown]
# ## Resources provided ##
# We have received a CSV file 'records.csv', which have given us the following information of each of the 6000 students
# 1. The students' name
# 2. The students' ID
# 3. The students' tutorial group
# 4. The students' gender
# 5. The students' school affiliation
# 6. The students' current CGPA

# %% [markdown]
# ## Requirements ##
# We are to develop an application that does the following
# 1. Organize students into teams of five
# 2. Team members should be in the same tutorial group
# 3. No team should have a majority of students from the same school
# 4. No team should have a majority of students of the same gender
# 5. No team should not consist predominantly of students with very high or very low CGPAs

# %% [markdown]
# ## Thought Process for Team Allocation Simulator ##
#
# To develop a robust and efficient Team Allocation Simulator, we adopted the cornerstones of Critical Thinking for Computing. This approach provided a structured guide for analyzing the problem and creating an effective solution.
#
# ### Decomposition ###
# The first step was to decompose the complex problem into manageable sub-tasks. Considering the various requirements for team formation, we evaluated different approaches for grouping students and identified the following optimal process:
#
# - Split the students by tutorial groups.
# - Within each tutorial group, split the students by gender.
# - Sort students within each gender group by CGPA.
# - Select students according to the determined selection strategy.
#
# By breaking the problem into these steps, we were able to develop a clear path for implementation, ensuring each requirement is addressed methodically.
#
# ### Abstraction ###
# To simplify the extraction and management of student information, we chose to represent each student’s data as a dictionary. These dictionaries are stored within lists to facilitate sequential, mutable data access. This decision was based on the need for flexible data structures that allow easy data manipulation and retrieval.
#
# ### Patterns ###
# We anticipated that the student selection process would be the most sophisticated part of the algorithm. Thus, we analyzed the potential patterns within this procedure to simplify and optimize it.
#
# Methodology for Student Selection:
#
# 1. Start by selecting the student with the lowest CGPA from the gender group with more students.
# 2. Alternate by choosing the student with the highest CGPA from the opposite gender.
# 3. Continue with the student who has the median CGPA from the initial gender group.
# 4. Repeat the process, ensuring a 3:2 gender ratio and varied school affiliations.
# 5. This approach ensures that each group has balanced CGPA levels, gender diversity, and students from different schools. The team composition pattern follows the order:
#
# ```
# [LowestFemale, HighestMale, MedianFemale, LowestMale, HighestFemale]
# ```
# Handling School Affiliation Duplicates: If a selected student shares the same school affiliation as another team member, the algorithm selects the next-best candidate (e.g., the second lowest/highest CGPA). This adjustment continues until a suitable candidate is found.
#
# Indexing Pattern:
#
# The indexes used for selection are
# ```
# [0, -1, len(sorted_student[gender_index]) // 2]
# ```
# corresponding to the lowest, highest, and median positions in the gender group.
# Changes in the index are tracked using index_changes
# ```
# [+1, -1, +1]
# ```
#  and a variable cycles through the indexes to maintain the selection pattern.
#
# ### Algorithms ###
# To build the Team Allocation Simulator, we outlined the following procedural steps:
#
# 1. Develop a CSV reading function: Extract and organize student data from the CSV file into dictionaries within lists.
# 2. Create a function to sort students by tutorial group: This ensures that students are initially grouped according to their assigned tutorial.
# 3. Implement a sorting function by gender and CGPA: This function organizes students within their tutorial groups into separate lists based on gender and then sorts them by CGPA.
# 4. Develop a team allocation function: This function distributes students into balanced teams while considering gender ratio, CGPA distribution, and school diversity.
#
# This structured workflow is designed to meet all project requirements and maintain efficiency in forming teams.
#
# ### Conclusion ###
# By following these steps, we believe our approach effectively balances the criteria of CGPA, gender, and school diversity in each team. The use of dictionaries and lists simplifies data handling, while the patterned selection process ensures a logical and fair distribution of students. The thought process outlined above demonstrates how decomposition, abstraction, pattern recognition, and algorithmic planning were integral to our project’s development.

# %% [markdown]
# ## Function to Read CSV File ##
# We will first create a function to read the CSV. It will then add each student's information (those listed above) into a dictionary. The dictionaries of the students' details will be stored in a list.

# %% [markdown]
# ### Pseudocode for read_student_data ###
#
# <font color='32CD32'>FUNCTION</font> read_student_data(file_path):
# <br>&emsp;<font color='32CD32'>INITIALISE</font> students_list as an empty list
# <br>
# <br>&emsp;<font color='32CD32'>OPEN</font> file at file_path in read mode AS file
# <br>&emsp;&emsp;<font color='32CD32'>READ</font> the first line and <font color='32CD32'>SPLIT</font> it by commas, <font color='32CD32'>ASSIGN</font> it to headers
# <br>
# <br>&emsp;&emsp;<font color='32CD32'>FOR EACH</font> line <font color ='32CD32'>IN</font> file:
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>INITIALISE</font> student as an empty dictionary
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>SPLIT</font> line by commas, <font color='32CD32'>ASSIGN</font> it to values
# <br>
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>FOR EACH</font> index i and header IN headers:
# <br>&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>SET</font> student[header] to values[i]
# <br>&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>IF</font> header is equal to "CGPA":
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>CONVERT</font> class of value to float
# <br>
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> student to students_list
# <br>
# <br>&emsp;<font color='32CD32'>RETURN</font> students_list

# %%
from IPython import display
display.Image("assets/Flowchart_read student data.png")

# %% [markdown]
# ## Function to Sort Students By Tutorial Groups ##
# Since the members of each group should be in the same tutorial group, we decided that it would be more efficient to meet this requirement first. In this function, we have split the dictionaries of each student to lists of their own respective tutorial groups.

# %% [markdown]
# ### Pseudocode for Function, pick_student ###
#
# <font color='32CD32'>FUNCTION</font> pick_student(all_students, tut_grp):
# <br>&emsp;<font color='32CD32'>INITIALISE</font> students_list as an empty list
# <br>
# <br>&emsp;<font color='32CD32'>FOR EACH</font> student <font color='32CD32'>IN</font> all_students
# <br>&emsp;&emsp;<font color='32CD32'>IF</font> student's 'Tutorial Group' is equal to 'G-{tut_grp}'
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> student to students_list
# <br>
# <br>&emsp;<font color='32CD32'>RETURN</font> students_list

# %%
display.Image("assets/Flowchart_pick_student.png")

# %% [markdown]
# ## Function to form a team of 5 students ##
# We will now design a function to form a team of 5 students. This function will have 2 parameters, a list with male students with their CGPA sorted, as well as a list with female students with their CGPA sorted. We will implement another function later for the sorting of gender and CGPA.
#
# For this function, we will be primarily be focussing on how we would ensure teams would have students with different school affliations, and how we would balance out the CGPA and gender in each group. We would heavily use pattern recognition to build this function.
#
# We will first pick a student with the lowest CGPA amongst gender X, where gender X has more students. We will then select a student of opposite gender with the highest CGPA. The next student selected would have the median CGPA amongst gender X. The first step repeats again. This effectively allows for a good mix of CGPA in a group, while ensuring there will be a 3:2 ratio for the gender and that students have different school affiliations. The team composition will look something like this:
# ```
# LowestFemale, HighestMale, MedianFemale, LowestMale, HighestFemale
# ```
#
# In the event where the student selected has the same school affliation as another student already in the group, the function will choose the next best alternative
# > If the next female student with the lowest CGPA has the same school affiliation with another student in the group, the second lowest CGPA female student will be selected instead. If the second lowest CGPA female student also has same school affilation with another student in the group, the third lowest CGPA female student will be selected, and so on.
#
# However, to ensure that the mean of CGPA does not differ alot between teams, we would stop the changing of index after it increases by 5. This also ensures that the mixture of CGPA will not affect other teams as well.
#
# Most tutorial groups will not be in a perfect 3:2 gender ratio for us to distribute them evenly. Hence, we have devised a way to ensure that 4:1 teams will be formed instead until the 3:2 ratio in the tutorial groups is formed. The remaining students will then be able to form 3:2 teams.
# > If there are 35 female and 15 male students in the tutorial group, 5 4:1 teams will be formed first. the remaining 5 teams will have a ratio of 3:2.

# %% [markdown]
# ### Pseudocode for Function ###
# <font color='32CD32'>FUNCTION</font> diverse_team(sorted_student_more, sorted_student_less)<br>
# &emsp;<font color='32CD32'>INITIALISE</font> team <font color='32CD32'>AS</font> an empty list<br>
# &emsp;<font color='32CD32'>SET</font> i <font color='32CD32'>TO</font> 0<br>
# &emsp;<font color='32CD32'>INITIALISE</font> sorted_student <font color='32CD32'>AS</font> a list containing sorted_student_more and sorted_student_less<br>
#
# &emsp;<font color='32CD32'>SET</font> gender_run_two_time <font color='32CD32'>TO</font> FALSE<br>
# &emsp;<font color='32CD32'>SET</font> next_gender_same <font color='32CD32'>TO</font> FALSE<br>
# &emsp;<font color='32CD32'>IF</font> (length of sorted_student_more - length of sorted_student_less >= 10-team_index) <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;<font color='32CD32'>SET</font> gender_run_two_time <font color='32CD32'>TO</font> TRUE
#
# &emsp;<font color='32CD32'>SET</font> gender_index <font color='32CD32'>TO</font> 0<br>
#
# &emsp;<font color='32CD32'>WHILE</font> (length of team < 5) <font color='32CD32'>AND</font> (sorted_student[0] <font color='32CD32'>OR</font> sorted_student[1])<br>
# &emsp;&emsp;<font color='32CD32'>SET</font> index_changes <font color='32CD32'>TO</font> [+1, -1, +1]<br>
# &emsp;&emsp;<font color='32CD32'>SET</font> pick_index <font color='32CD32'>TO</font> [0, -1, length of sorted_student[gender_index] // 2]<br>
#
# &emsp;&emsp;<font color='32CD32'>WHILE</font> TRUE<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>IF</font> sorted_student[gender_index] is empty <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>BREAK</font><br>
#
# &emsp;&emsp;&emsp;<font color='32CD32'>IF</font> (index_changes[i] >= 0) <font color='32CD32'>AND</font> (pick_index[i] + index_changes[i] < length of sorted_student[gender_index]) <font color='32CD32'>AND</font> index_changes[i] <= 5 <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>IF</font> sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] <font color='32CD32'>NOT</font> <font color='32CD32'>IN</font> student['School'] <font color='32CD32'>FOR</font> student <font color='32CD32'>IN</font> team] <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> sorted_student[gender_index].<font color='32CD32'>POP</font>(pick_index[i] + index_changes[i]) <font color='32CD32'>TO</font> team<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>BREAK</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>ELSE</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>INCREMENT</font> index_changes[i] <font color='32CD32'>BY</font> 1<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>ELSE IF</font> (index_changes[i] < 0) <font color='32CD32'>AND</font> (ABS(pick_index[i] + index_changes[i]) <= length of sorted_student[gender_index]) <font color='32CD32'>AND</font> (ABS(index_changes[i]) <= 5) <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>IF</font> (sorted_student[gender_index][pick_index[i] + index_changes[i]]['School']) <font color='32CD32'>NOT</font> <font color='32CD32'>IN</font> [student['School'] <font color='32CD32'>FOR</font> student <font color='32CD32'>IN</font> team] <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> sorted_student[gender_index].<font color='32CD32'>POP</font>(pick_index[i] + index_changes[i]) <font color='32CD32'>TO</font> team<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>BREAK</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>ELSE</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>DECREMENT</font> index_changes[i] <font color='32CD32'>BY</font> 1<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>ELSE</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> sorted_student[gender_index].<font color='32CD32'>POP</font>(pick_index[i]) <font color='32CD32'>TO</font> team<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;BREAK<br>
#
# &emsp;&emsp;<font color='32CD32'>INCREMENT</font> i <font color='32CD32'>BY</font> 1
#
# &emsp;&emsp;<font color='32CD32'>IF</font> <font color='32CD32'>NOT</font> next_gender_same <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>INCREMENT</font> gender_index <font color='32CD32'>BY</font> 1
#
# &emsp;&emsp;<font color='32CD32'>ELSE IF</font> next_gender_same <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> next_gender_same <font color='32CD32'>TO</font> FALSE
#
# &emsp;&emsp;<font color='32CD32'>IF</font> i is greater than 2 <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> i <font color='32CD32'>TO</font> 0
#
# &emsp;&emsp;<font color='32CD32'>IF</font> gender_index is greater than 1 <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> gender_index <font color='32CD32'>TO</font> 0
#
# &emsp;&emsp;<font color='32CD32'>IF</font> gender_run_two_time <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> gender_index <font color='32CD32'>TO</font> 0<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> gender_run_two_time <font color='32CD32'>TO</font> TRUE<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> next_gender_same <font color='32CD32'>TO</font> TRUE
#
# &emsp;<font color='32CD32'>RETURN</font> team<br>

# %%
display.Image("assets/Flowchart_diverse_teams.png")

# %% [markdown]
# ## Function to Sort by Gender and CGPA (Division into team) ##
# This function would split students by their gender into 2 lists. Each list will then be sorted by CGPA. The function will determine whether the tutorial group has more males or females, and the lists produced will then be used as diverse_team parameters.
# The function will return the groups formed in lists, nested in a whole list.

# %% [markdown]
# ### Pseudocode for division_into_team ###
#
# <font color='32CD32'>FUNCTION</font> division_into_team(students_list):
# <br>&emsp;<font color='32CD32'>INITIALISE</font> male_students as list of students from students_list where 'Gender' is 'Male'
# <br>&emsp;<font color='32CD32'>INITIALISE</font> female_students as list of students from students_list where 'Gender' is 'Female'
# <br>&emsp;<font color='32CD32'>INITIALISE</font> teams as a list of empty lists, with one list for every 5 students in students_list
# <br>&emsp;<font color='32CD32'>INITIALISE</font> team_index to 0
#
# <br>&emsp;<font color='32CD32'>SORT</font> male_students by 'CGPA' in ascending order, <font color='32CD32'>ASSIGN</font> to male_sorted_students
# <br>&emsp;<font color='32CD32'>SORT</font> female_students by 'CGPA' in ascending order, <font color='32CD32'>ASSIGN</font> to female_sorted_students
#
# <br>&emsp;<font color='32CD32'>WHILE</font> team_index < length of teams:
# <br>&emsp;&emsp;<font color='32CD32'>IF</font> length of male_sorted_students >= length of female_sorted_students:
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>SET</font> teams[team_index] to result of calling diverse_team with male_sorted_students, female_sorted_students, and team_index
# <br>&emsp;&emsp;<font color='32CD32'>ELSE</font>:
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>SET</font> teams[team_index] to result of calling diverse_team with female_sorted_students, male_sorted_students, and team_index
#
# <br>&emsp;&emsp;<font color='32CD32'>INCREMENT</font> team_index by 1
#
# <br><font color='32CD32'>RETURN</font> teams

# %%
display.Image("assets/Flowchart_division into team.png")

# %% [markdown]
# ## Main Code ##

# %% [markdown]
# ### Pseudocode for the Main ###
# <br><font color='32CD32'>INITIALISE</font> students, by reading student data from 'records.csv'
# <br><font color='32CD32'>INITIALISE</font> group_division, as an empty list
# <br><font color='32CD32'>INITIALISE</font> tutorial_grp, to 1 (starting tutorial group)
#
# <br><font color='32CD32'>WHILE</font> (tutorial_grp) is less than or equal to 120
# <br>&emsp;&emsp;<font color='32CD32'>CALL</font> pick_student(students, tutorial_grp)
# <br>&emsp;&emsp;<font color='32CD32'>CALL</font> division_into_team with the picked students
# <br>&emsp;&emsp;<font color='32CD32'>EXTEND</font> group_division with the resulting teams
# <br>&emsp;&emsp;<font color='32CD32'>INCREMENT</font> tutorial_grp by 1
#
# <br><font color='32CD32'>WITH </font>open file "FCEB_Team2_EWEN.csv" in **write** mode as variable 'f'.
# <br><font color='32CD32'>FOR EACH</font> 'i, x' in group_division (where 'i' is the group index and 'x' is the group list):
# <br>&emsp;&emsp;<font color='32CD32'>Write</font> "Group {i}" to the file.
# <br><font color='32CD32'>FOR EACH</font> 'j' in x (where 'j' is each student in the group):
# <br>&emsp;&emsp;<font color='32CD32'>Create</font> string 'l' with 'Student ID', 'School', 'CGPA', and 'Gender' of the student, followed by a newline.
# <br>&emsp;&emsp;<font color='32CD32'>Write</font> 'l' to the file.
# <br><font color='32CD32'>Close</font> the file. (Automatically closed due to 'with'.)

# %%
display.Image("assets/Flowchart_Main Code.png")

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # Visualisation of code #

# %%
from IPython import display
display.Image("assets/dataset_school.jpg")

# %% [markdown]
# ### School Representation ###

# %%
display.Image("assets/school_representation.png")

# %% [markdown]
# ### Gender Representation ###

# %%
display.Image("assets/dataset_gender.jpg")

# %%
display.Image("assets/gender_representation.png")

# %% [markdown]
# ### Histogram for Mean CGPA Per Team ###

# %%
display.Image("assets/Histogram_for_Mean_CGPA_Per_Team.png")

# %% [markdown]
# ### Histogram_for_Standard_Deviation_Per_Team.png ###

# %%
display.Image("assets/Histogram_for_Standard_Deviation_Per_Team.png")

# %% [markdown]
# ### Histogram_of_Z-Scores_for_Mean_CGPA_per_Team ###

# %%
display.Image("assets/Histogram_of_Z-Scores_for_Mean_CGPA_per_Team.png")

# %% [markdown]
# ### Z-Score Interpretation:
# Apply the Empirical Rule (68-95-99.7 Rule):
# - 68% of the z-scores should fall within 1 standard deviation of the mean (z-scores between -1 and 1)
# - 95% of the z-scores should fall within 2 standard deviations of the mean (z-scores between -2 and 2)
# - 99.7% of the z-scores should fall within 3 standard deviations of the mean (z-scores between -3 and 3)
#
# For 1 standard deviation:
# $$\frac{470 + 359}{1200} \approx 0.69\$$
#
# For 2 standard deviations:
# $$\frac{470 + 359 + 181 + 93 + 33}{1200} \approx 0.95\$$
#
# For 3 standard deviations:
# $$\frac{470 + 359 + 181 + 93 + 33 + 27 + 15 + 5}{1200} \approx 0.99\$$

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # Code #
# We had code 2 version, one is the basic code, another one is the advanced code where user can choose number of student in a group

# %% [markdown]
# ## Basic Code

# %%
def read_student_data(file_path):
    """Read data from csv file and return"""
    students_list = []
    with open(file_path, mode='r') as file:
        headers = file.readline().strip().split(",")
        for line in file:
            student = {}
            values = line.strip().split(",")
            for i, header in enumerate(headers):
                student[header.strip()] = values[i].strip()
                if header.strip() == "CGPA":
                    student[header.strip()] = float(student[header.strip()])

            students_list.append(student)

    return students_list


def pick_student(all_students, tut_grp):
    """pick student out from the tutorial group"""
    students_list = []

    for student in all_students:
        if student['Tutorial Group'] == f'G-{tut_grp}':
            students_list.append(student)

    return students_list


def diverse_team(sorted_student_more, sorted_student_less, team_index):  # index(0,-1,or middle)
    team = []
    i = 0  # round
    sorted_student = [sorted_student_more, sorted_student_less]

    gender_run_two_time = False
    next_gender_same = False
    if len(sorted_student_more) - len(sorted_student_less) >= 10-team_index:
        gender_run_two_time = True

    gender_index = 0

    while len(team) < 5 and (sorted_student[0] or sorted_student[1]):  # add student into team when teams is not full
        index_changes = [+1, -1, +1]
        pick_index = [0, -1, len(sorted_student[gender_index]) // 2]
        while True:
            if not sorted_student[gender_index]:
                break
            elif index_changes[i] >= 0 and pick_index[i] + index_changes[i] < len(sorted_student[gender_index]) and index_changes[
                i] <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] += 1
            elif index_changes[i] < 0 and abs(pick_index[i] + index_changes[i]) <= len(sorted_student[gender_index]) and abs(
                    index_changes[i]) <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] -= 1
            else:
                # If the index exceeds the list length, reset index_changes or break
                team.append(sorted_student[gender_index].pop(pick_index[i]))
                break

        i += 1
        if not next_gender_same:
            gender_index += 1
        elif next_gender_same:
            next_gender_same = False
        if i > 2:
            i = 0
        if gender_index > 1:
            gender_index = 0

        if gender_run_two_time:
            gender_index = 0
            gender_run_two_time = False
            next_gender_same = True

    return team


def division_into_team(students_list):
    """Divides student from student_list into group of 5 with balance of cgpa and gender, and diverse of school"""
    # Separate male and female students into two lists
    male_students = [student for student in students_list if student['Gender'] == 'Male']
    female_students = [student for student in students_list if student['Gender'] == 'Female']

    # Sort the male and female students by CGPA
    male_sorted_students = sorted(male_students, key=lambda student: student['CGPA'])
    female_sorted_students = sorted(female_students, key=lambda student: student['CGPA'])

    teams = [[] for _ in range(len(students_list) // 5)]
    team_index = 0

    while team_index < len(teams):  # while haven't added student into all teams
        if len(male_sorted_students) >= len(female_sorted_students):  # if remain male student more than remain female student
            teams[team_index] = diverse_team(male_sorted_students, female_sorted_students, team_index)

        else:  # if remain male student less than remain female student
            teams[team_index] = diverse_team(female_sorted_students, male_sorted_students, team_index)

        team_index += 1

    return teams


students = read_student_data('records.csv')
group_division = []
tutorial_grp = 1

while tutorial_grp <= 120:
    group_division.extend(division_into_team(pick_student(students, tutorial_grp)))
    tutorial_grp += 1
    
with open("FCEB_Team2_EWEN.csv", mode="w") as f:
    f.write("Tutorial Group,Group Number,Student ID,School,Name,Gender,CGPA\n")

    for group_num, group in enumerate(group_division,start=1):
        for student in group:
            l = f"{student['Tutorial Group']},{group_num},{student['Student ID']},{student['School']},{student['Name']},{student['Gender']},{student['CGPA']}\n"
            f.write(l)

# %% [markdown]
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Advanced Code ##

# %%
from ipywidgets import IntSlider, interact


def read_student_data(file_path):
    """Read data from csv file and return"""
    students_list = []
    with open(file_path, mode='r') as file:
        headers = file.readline().strip().split(",")
        for line in file:
            student = {}
            values = line.strip().split(",")
            for i, header in enumerate(headers):
                student[header.strip()] = values[i].strip()
                if header.strip() == "CGPA":
                    student[header.strip()] = float(student[header.strip()])

            students_list.append(student)

    return students_list


def pick_student(all_students, tut_grp):
    """pick student out from the tutorial group"""
    students_list = []

    for student in all_students:
        if student['Tutorial Group'] == f'G-{tut_grp}':
            students_list.append(student)

    return students_list


def diverse_team(size_team, sorted_student_more, sorted_student_less,team_index,len_team):  # size of team, index(0,-1,or middle)
    team = []
    i = 0  # round
    sorted_student = [sorted_student_more, sorted_student_less]

    gender_run_two_time = False
    next_gender_same = False
    if (size_team%2 == 0) or len(sorted_student_more) - len(sorted_student_less) >= ((((size_team//2)+1)*len_team) -((size_team//2)*len_team))-team_index:
        gender_run_two_time = True

    gender_index = 0

    while len(team) < size_team and (sorted_student[0] or sorted_student[1]):  # add student into team when teams is not full
        index_changes = [+1, -1, +1]
        pick_index = [0, -1, len(sorted_student[gender_index]) // 2]
        while True:
            if not sorted_student[gender_index]:
                break
            elif index_changes[i] >= 0 and pick_index[i] + index_changes[i] < len(sorted_student[gender_index]) and index_changes[
                i] <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] += 1
            elif index_changes[i] < 0 and abs(pick_index[i] + index_changes[i]) <= len(sorted_student[gender_index]) and abs(
                    index_changes[i]) <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] -= 1
            else:
                # If the index exceeds the list length, reset index_changes or break
                team.append(sorted_student[gender_index].pop(pick_index[i]))
                break

        i += 1
        if not next_gender_same:
            gender_index += 1
        elif next_gender_same:
            next_gender_same = False
        if i > 2:
            i = 0
        if gender_index > 1:
            gender_index = 0

        if gender_run_two_time:
            gender_index = 0
            gender_run_two_time = False
            next_gender_same = True

    return team


def division_into_team(students_list, size):
    """Divides student from student_list into group of size with balance of cgpa and gender, and diverse of school"""
    # Separate male and female students into two lists
    male_students = [student for student in students_list if student['Gender'] == 'Male']
    female_students = [student for student in students_list if student['Gender'] == 'Female']

    # Sort the male and female students by CGPA
    male_sorted_students = sorted(male_students, key=lambda student: student['CGPA'])
    female_sorted_students = sorted(female_students, key=lambda student: student['CGPA'])

    teams = [[] for _ in range(len(students_list) // size)]
    team_index = 0

    while team_index < len(teams):  # while haven't added student into all teams
        if len(male_sorted_students) >= len(female_sorted_students):  # if remain male student more than remain female student
            teams[team_index] = diverse_team(size, male_sorted_students, female_sorted_students,team_index,len(teams))

        else:  # if remain male student less than remain female student
            teams[team_index] = diverse_team(size, female_sorted_students, male_sorted_students,team_index,len(teams))

        team_index += 1

    first_run = True
    while male_sorted_students or female_sorted_students:
        for team in teams:
            male = sum(1 for student in team if student['Gender'] == 'Male')
            female = sum(1 for student in team if student['Gender'] == 'Female')

            # Handle male students first
            if male_sorted_students:
                if male > female:
                    continue
                elif female > male:
                    team.append(male_sorted_students.pop(0))
                    continue
                elif not first_run and male - female < 2:
                    team.append(male_sorted_students.pop(0))
                    continue

            # Handle female students
            if female_sorted_students:
                if male > female:
                    team.append(female_sorted_students.pop(0))
                    continue
                elif female > male:
                    continue
                elif not first_run and female - male < 2:
                    team.append(female_sorted_students.pop(0))
                    continue

        if not first_run:
            break

        # Mark the first run complete
        first_run = False

    return teams


def main(team_size):
    global group_division
    students = read_student_data('records.csv')
    group_division = []
    tutorial_grp = 1

    while tutorial_grp <= 120:
        group_division.extend(division_into_team(pick_student(students, tutorial_grp), team_size))
        tutorial_grp += 1

    with open("FCEB_Team2_EWEN_Advanced.csv", mode="w") as f:
        f.write("Tutorial Group,Group Number,Student ID,School,Name,Gender,CGPA\n")
    
        for group_num, group in enumerate(group_division,start=1):
            for student in group:
                l = f"{student['Tutorial Group']},{group_num},{student['Student ID']},{student['School']},{student['Name']},{student['Gender']},{student['CGPA']}\n"
                f.write(l)
        
team_size_slider = IntSlider(value=5,min=4,max=10,step=1,description="Team Size")

interact(main,team_size = team_size_slider)
# Out:
# interactive(children=(IntSlider(value=5, description='Team Size', max=10, min=4), Output()), _dom_classes=('wi…
# <function __main__.main(team_size)>

# %% [markdown]
# <br><br><br><br><br><br>

# %% [markdown]
# # Matplotlib Part to Visualise Code #

# %%
import matplotlib.pyplot as plt
import os


def visualize_data(group_division):
    all_sd = []
    all_mean = []
    compiled_z_score = []
    compiled_gender = []
    unique_school_counts = []

    for i, x in enumerate(group_division):
        print(f"Team {i}")
        total_cgpa = 0
        ind_cgpa = []
        ind_gender = []
        ind_school = []
        for j in x:
            total_cgpa += j["CGPA"]
            ind_cgpa.append(j["CGPA"])
            ind_gender.append(j["Gender"])
            ind_school.append(j["School"])

        # for categorisation of gender
        compiled_gender.append(ind_gender)

        # for categorisation for diverse sch representation
        schools_in_team = set(sch for sch in ind_school)  # Use a set to get unique schools
        unique_school_counts.append(len(schools_in_team))  # Count of unique schools

        # for categorisation for CGPA
        ind_mean = total_cgpa / len(ind_cgpa)  # individual group mean CGPA
        deviations = [(each - ind_mean) ** 2 for each in ind_cgpa]
        variance = sum(deviations) / len(ind_cgpa)
        sd = variance ** 0.5
        all_sd.append(sd)
        all_mean.append(ind_mean)

        # printing of cgPA values for each group
        print(f"The mean CGPA of team {i}  is {ind_mean:.2f}")
        print(f"The variance of team {i}  is {variance:.5f}")
        print(f"The standard deviation of team {i}  is {sd:.5f}")
        print()

    # comparing individual team's mean, sd to observe the disparity in CGPA between each team and the population
    total_mean = sum(all_mean) / len(all_mean)
    population_deviations = [(each - total_mean) ** 2 for each in all_mean]
    population_sd = (sum(population_deviations) / len(all_mean)) ** 0.5
    population_median = all_mean[len(all_mean)//2]

    # calculate z-score of every team
    for i in all_mean:
        z_score = (i - total_mean) / population_sd  # calculate z-score for each team and ammend to list for display
        compiled_z_score.append(z_score)

    # printing of the cohort's average cGPA, SD and zScore.
    print(f"The mean of the population is {total_mean:.2f}")
    print(f"Population median is: {population_median}")
    print(f"The standard deviation of the population is {population_sd:.5f}")

    #for base.py only
    # dictionary to hold self-defined variable for gender categorisation and its count per category
    #count_gender = {'m5f0': 0, 'm4f1': 0, 'm3f2': 0, 'm2f3': 0, 'm1f4': 0, 'm0f5': 0}
    #for teamg in compiled_gender:
    #    count = sum(1 for gender in teamg if gender == "Male")
    #    if count > 5:
    #        count = 5
    #    count_gender[f'm{count}f{5 - count}'] += 1
    #print(f"Gender count {count_gender}")

    count_gender = {}

    for teamgender in compiled_gender:
        male_count = sum(1 for gender in teamgender if gender == "Male")
        female_count = len(teamgender) - male_count  # female count is total team size - male count

        # Create the key based on the number of males and females
        gender_key = f'm{male_count}f{female_count}' # Key in the form of mXfY

        if gender_key not in count_gender:
            count_gender[gender_key] = 0
        
        # Update the count for the given key
        count_gender[gender_key] += 1

    # Output the final result
    print(count_gender)

    # Visualisation
    os.makedirs("assets", exist_ok=True)  # make assets folder if it doesnt exist

    show_graph_gender(count_gender)  # bar graph for count_gender dict
    show_graph_school(unique_school_counts)  # bar graph for sch repre
    # show_graph_CGPA(related_list,title,window_title,xlabel,ylabel,color_for_bins):
    show_graph_cgpa(all_mean, "Histogram of Mean CGPA per Team",
                    "Histogram_for_Mean_CGPA_Per_Team",
                    "Mean cGPA",
                    "Frequency",
                    "red")

    show_graph_cgpa(all_sd, "Histogram of Standard Deviation per Team",
                    "Histogram_for_Standard_Deviation_Per_Team",
                    "Standard Deviation",
                    "Frequency",
                    "blue")
    show_graph_cgpa(compiled_z_score, "Histogram of Z-Scores for Mean CGPA per Team",
                    "Histogram_of_Z-Scores_for_Mean_CGPA_per_Team",
                    "Z-Score",
                    "Frequency",
                    "green")

def show_graph_school(unique_school_counts):
    fig = plt.figure(figsize=(10, 6))
    fig.canvas.manager.set_window_title("Bar Graph for School Representation")
    counts, bins, patches = plt.hist(unique_school_counts, bins=range(1, max(unique_school_counts) + 2),
                                     color='skyblue', edgecolor='black', align='left')

    plt.xticks(range(1, max(unique_school_counts) + 1))  # Set x-ticks
    plt.xlabel("Number of Unique Schools per Team")
    plt.ylabel("Number of Teams")
    plt.title("Distribution of Unique Schools in Teams")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Adding labels on top of each bar
    for count, x in zip(counts, bins):
        if count > 0:  # Only label if there's a bar
            plt.text(x, count, int(count), ha='center', va='bottom')

    plt.show()
    fig.savefig("assets/school_representation.png")

def show_graph_gender(count_gender):
    # Data for the bar chart (this to visualize the count_gender dict)
    labels = list(count_gender.keys())  # Category labels using count_gender dictionary
    frequencies = list(count_gender.values())  # Count from dictionary for each category

    # Plotting the bar chart
    fig, ax = plt.subplots(figsize=(10, 6))
    fig.canvas.manager.set_window_title("Bar Graph for Gender Representation")

    # Create the bar chart
    bars = ax.bar(labels, frequencies, color='skyblue')

    # Adding titles and labels
    ax.set_title("Frequency of Gender in Teams")
    ax.set_xlabel("Gender Composition , m5f0 means 5 males, 0 females)")
    ax.set_ylabel("Number of Teams")

    # Adding frequency labels on top of each bar
    for bar in bars:
        yval = bar.get_height()  # Get the height of each bar
        ax.text(bar.get_x() + bar.get_width() / 2, yval, int(yval), ha='center', va='bottom')

    # Display the chart
    plt.xticks(rotation=45)
    plt.show()
    fig.savefig("assets/gender_representation.png")

def show_graph_cgpa(related_list, title, window_title, xlabel, ylabel, color_for_bins):
    fig = plt.figure(figsize=(10, 6))
    fig.canvas.manager.set_window_title(window_title)
    counts, bins, patches = plt.hist(related_list, bins=10, color=color_for_bins, edgecolor='black', alpha=0.7)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Add frequency labels on top of each bar
    for count, bin_edge in zip(counts, bins):
        if count > 0:
            plt.text(bin_edge + (bins[1] - bins[0]) / 2, count, int(count), ha='center', va='bottom')

    plt.show()
    fig.savefig("assets/" + window_title + ".png")
    
visualize_data(group_division)
# Out:
# Team 0
# The mean CGPA of team 0  is 4.13
# The variance of team 0  is 0.04002
# The standard deviation of team 0  is 0.20006
#
# Team 1
# The mean CGPA of team 1  is 4.06
# The variance of team 1  is 0.01614
# The standard deviation of team 1  is 0.12703
#
# Team 2
# The mean CGPA of team 2  is 4.11
# The variance of team 2  is 0.00910
# The standard deviation of team 2  is 0.09541
#
# Team 3
# The mean CGPA of team 3  is 4.11
# The variance of team 3  is 0.00678
# The standard deviation of team 3  is 0.08232
#
# Team 4
# The mean CGPA of team 4  is 4.09
# The variance of team 4  is 0.00430
# The standard deviation of team 4  is 0.06560
#
# Team 5
# The mean CGPA of team 5  is 4.07
# The variance of team 5  is 0.00074
# The standard deviation of team 5  is 0.02728
#
# Team 6
# The mean CGPA of team 6  is 4.09
# The variance of team 6  is 0.00244
# The standard deviation of team 6  is 0.04940
#
# Team 7
# The mean CGPA of team 7  is 4.08
# The variance of team 7  is 0.00358
# The standard deviation of team 7  is 0.05980
#
# Team 8
# The mean CGPA of team 8  is 4.07
# The variance of team 8  is 0.01604
# The standard deviation of team 8  is 0.12665
#
# Team 9
# The mean CGPA of team 9  is 4.14
# The variance of team 9  is 0.04528
# The standard deviation of team 9  is 0.21279
#
# Team 10
# The mean CGPA of team 10  is 4.08
# The variance of team 10  is 0.01462
# The standard deviation of team 10  is 0.12093
#
# Team 11
# The mean CGPA of team 11  is 4.10
# The variance of team 11  is 0.00650
# The standard deviation of team 11  is 0.08060
#
# Team 12
# The mean CGPA of team 12  is 4.09
# The variance of team 12  is 0.00594
# The standard deviation of team 12  is 0.07710
#
# Team 13
# The mean CGPA of team 13  is 4.09
# The variance of team 13  is 0.00586
# The standard deviation of team 13  is 0.07658
#
# Team 14
# The mean CGPA of team 14  is 4.11
# The variance of team 14  is 0.00454
# The standard deviation of team 14  is 0.06741
#
# Team 15
# The mean CGPA of team 15  is 4.09
# The variance of team 15  is 0.00410
# The standard deviation of team 15  is 0.06400
#
# Team 16
# The mean CGPA of team 16  is 4.10
# The variance of team 16  is 0.00374
# The standard deviation of team 16  is 0.06112
#
# Team 17
# The mean CGPA of team 17  is 4.09
# The variance of team 17  is 0.00278
# The standard deviation of team 17  is 0.05276
#
# Team 18
# The mean CGPA of team 18  is 4.09
# The variance of team 18  is 0.00370
# The standard deviation of team 18  is 0.06086
#
# Team 19
# The mean CGPA of team 19  is 4.04
# The variance of team 19  is 0.01452
# The standard deviation of team 19  is 0.12050
#
# Team 20
# The mean CGPA of team 20  is 4.07
# The variance of team 20  is 0.01902
# The standard deviation of team 20  is 0.13790
#
# Team 21
# The mean CGPA of team 21  is 4.19
# The variance of team 21  is 0.09734
# The standard deviation of team 21  is 0.31199
#
# Team 22
# The mean CGPA of team 22  is 4.09
# The variance of team 22  is 0.00928
# The standard deviation of team 22  is 0.09633
#
# Team 23
# The mean CGPA of team 23  is 4.07
# The variance of team 23  is 0.00742
# The standard deviation of team 23  is 0.08612
#
# Team 24
# The mean CGPA of team 24  is 4.11
# The variance of team 24  is 0.00586
# The standard deviation of team 24  is 0.07658
#
# Team 25
# The mean CGPA of team 25  is 4.09
# The variance of team 25  is 0.00358
# The standard deviation of team 25  is 0.05987
#
# Team 26
# The mean CGPA of team 26  is 4.10
# The variance of team 26  is 0.00326
# The standard deviation of team 26  is 0.05713
#
# Team 27
# The mean CGPA of team 27  is 4.08
# The variance of team 27  is 0.00106
# The standard deviation of team 27  is 0.03250
#
# Team 28
# The mean CGPA of team 28  is 4.24
# The variance of team 28  is 0.13518
# The standard deviation of team 28  is 0.36767
#
# Team 29
# The mean CGPA of team 29  is 4.03
# The variance of team 29  is 0.01450
# The standard deviation of team 29  is 0.12043
#
# Team 30
# The mean CGPA of team 30  is 4.09
# The variance of team 30  is 0.01368
# The standard deviation of team 30  is 0.11696
#
# Team 31
# The mean CGPA of team 31  is 4.07
# The variance of team 31  is 0.01662
# The standard deviation of team 31  is 0.12890
#
# Team 32
# The mean CGPA of team 32  is 4.09
# The variance of team 32  is 0.01038
# The standard deviation of team 32  is 0.10186
#
# Team 33
# The mean CGPA of team 33  is 4.07
# The variance of team 33  is 0.00630
# The standard deviation of team 33  is 0.07935
#
# Team 34
# The mean CGPA of team 34  is 4.06
# The variance of team 34  is 0.00418
# The standard deviation of team 34  is 0.06468
#
# Team 35
# The mean CGPA of team 35  is 4.08
# The variance of team 35  is 0.00358
# The standard deviation of team 35  is 0.05987
#
# Team 36
# The mean CGPA of team 36  is 4.11
# The variance of team 36  is 0.00228
# The standard deviation of team 36  is 0.04775
#
# Team 37
# The mean CGPA of team 37  is 4.07
# The variance of team 37  is 0.00246
# The standard deviation of team 37  is 0.04956
#
# Team 38
# The mean CGPA of team 38  is 4.05
# The variance of team 38  is 0.01202
# The standard deviation of team 38  is 0.10965
#
# Team 39
# The mean CGPA of team 39  is 4.10
# The variance of team 39  is 0.01970
# The standard deviation of team 39  is 0.14037
#
# Team 40
# The mean CGPA of team 40  is 4.07
# The variance of team 40  is 0.02390
# The standard deviation of team 40  is 0.15458
#
# Team 41
# The mean CGPA of team 41  is 4.07
# The variance of team 41  is 0.01734
# The standard deviation of team 41  is 0.13170
#
# Team 42
# The mean CGPA of team 42  is 4.10
# The variance of team 42  is 0.01306
# The standard deviation of team 42  is 0.11430
#
# Team 43
# The mean CGPA of team 43  is 4.06
# The variance of team 43  is 0.01692
# The standard deviation of team 43  is 0.13008
#
# Team 44
# The mean CGPA of team 44  is 4.10
# The variance of team 44  is 0.00790
# The standard deviation of team 44  is 0.08890
#
# Team 45
# The mean CGPA of team 45  is 4.06
# The variance of team 45  is 0.00842
# The standard deviation of team 45  is 0.09178
#
# Team 46
# The mean CGPA of team 46  is 4.07
# The variance of team 46  is 0.00430
# The standard deviation of team 46  is 0.06554
#
# Team 47
# The mean CGPA of team 47  is 4.08
# The variance of team 47  is 0.00558
# The standard deviation of team 47  is 0.07467
#
# Team 48
# The mean CGPA of team 48  is 4.08
# The variance of team 48  is 0.00218
# The standard deviation of team 48  is 0.04673
#
# Team 49
# The mean CGPA of team 49  is 4.09
# The variance of team 49  is 0.06256
# The standard deviation of team 49  is 0.25012
#
# Team 50
# The mean CGPA of team 50  is 4.10
# The variance of team 50  is 0.01830
# The standard deviation of team 50  is 0.13529
#
# Team 51
# The mean CGPA of team 51  is 4.11
# The variance of team 51  is 0.01640
# The standard deviation of team 51  is 0.12806
#
# Team 52
# The mean CGPA of team 52  is 4.09
# The variance of team 52  is 0.01038
# The standard deviation of team 52  is 0.10186
#
# Team 53
# The mean CGPA of team 53  is 4.09
# The variance of team 53  is 0.00938
# The standard deviation of team 53  is 0.09683
#
# Team 54
# The mean CGPA of team 54  is 4.11
# The variance of team 54  is 0.00894
# The standard deviation of team 54  is 0.09457
#
# Team 55
# The mean CGPA of team 55  is 4.08
# The variance of team 55  is 0.00608
# The standard deviation of team 55  is 0.07797
#
# Team 56
# The mean CGPA of team 56  is 4.11
# The variance of team 56  is 0.00532
# The standard deviation of team 56  is 0.07294
#
# Team 57
# The mean CGPA of team 57  is 4.08
# The variance of team 57  is 0.00382
# The standard deviation of team 57  is 0.06184
#
# Team 58
# The mean CGPA of team 58  is 4.09
# The variance of team 58  is 0.00706
# The standard deviation of team 58  is 0.08405
#
# Team 59
# The mean CGPA of team 59  is 4.13
# The variance of team 59  is 0.11522
# The standard deviation of team 59  is 0.33943
#
# Team 60
# The mean CGPA of team 60  is 4.08
# The variance of team 60  is 0.02442
# The standard deviation of team 60  is 0.15626
#
# Team 61
# The mean CGPA of team 61  is 4.11
# The variance of team 61  is 0.03024
# The standard deviation of team 61  is 0.17390
#
# Team 62
# The mean CGPA of team 62  is 4.09
# The variance of team 62  is 0.01430
# The standard deviation of team 62  is 0.11960
#
# Team 63
# The mean CGPA of team 63  is 4.08
# The variance of team 63  is 0.01216
# The standard deviation of team 63  is 0.11027
#
# Team 64
# The mean CGPA of team 64  is 4.08
# The variance of team 64  is 0.01082
# The standard deviation of team 64  is 0.10404
#
# Team 65
# The mean CGPA of team 65  is 4.10
# The variance of team 65  is 0.00486
# The standard deviation of team 65  is 0.06969
#
# Team 66
# The mean CGPA of team 66  is 4.09
# The variance of team 66  is 0.00230
# The standard deviation of team 66  is 0.04792
#
# Team 67
# The mean CGPA of team 67  is 4.08
# The variance of team 67  is 0.00190
# The standard deviation of team 67  is 0.04354
#
# Team 68
# The mean CGPA of team 68  is 4.16
# The variance of team 68  is 0.03318
# The standard deviation of team 68  is 0.18214
#
# Team 69
# The mean CGPA of team 69  is 4.04
# The variance of team 69  is 0.02426
# The standard deviation of team 69  is 0.15574
#
# Team 70
# The mean CGPA of team 70  is 4.07
# The variance of team 70  is 0.01150
# The standard deviation of team 70  is 0.10722
#
# Team 71
# The mean CGPA of team 71  is 4.08
# The variance of team 71  is 0.01162
# The standard deviation of team 71  is 0.10778
#
# Team 72
# The mean CGPA of team 72  is 4.08
# The variance of team 72  is 0.01046
# The standard deviation of team 72  is 0.10225
#
# Team 73
# The mean CGPA of team 73  is 4.09
# The variance of team 73  is 0.00790
# The standard deviation of team 73  is 0.08886
#
# Team 74
# The mean CGPA of team 74  is 4.09
# The variance of team 74  is 0.00482
# The standard deviation of team 74  is 0.06940
#
# Team 75
# The mean CGPA of team 75  is 4.11
# The variance of team 75  is 0.00252
# The standard deviation of team 75  is 0.05020
#
# Team 76
# The mean CGPA of team 76  is 4.10
# The variance of team 76  is 0.00202
# The standard deviation of team 76  is 0.04490
#
# Team 77
# The mean CGPA of team 77  is 4.09
# The variance of team 77  is 0.00208
# The standard deviation of team 77  is 0.04561
#
# Team 78
# The mean CGPA of team 78  is 4.09
# The variance of team 78  is 0.00186
# The standard deviation of team 78  is 0.04308
#
# Team 79
# The mean CGPA of team 79  is 4.10
# The variance of team 79  is 0.05442
# The standard deviation of team 79  is 0.23329
#
# Team 80
# The mean CGPA of team 80  is 4.07
# The variance of team 80  is 0.02542
# The standard deviation of team 80  is 0.15942
#
# Team 81
# The mean CGPA of team 81  is 4.07
# The variance of team 81  is 0.01658
# The standard deviation of team 81  is 0.12875
#
# Team 82
# The mean CGPA of team 82  is 4.09
# The variance of team 82  is 0.00604
# The standard deviation of team 82  is 0.07772
#
# Team 83
# The mean CGPA of team 83  is 4.09
# The variance of team 83  is 0.00508
# The standard deviation of team 83  is 0.07127
#
# Team 84
# The mean CGPA of team 84  is 4.09
# The variance of team 84  is 0.00486
# The standard deviation of team 84  is 0.06969
#
# Team 85
# The mean CGPA of team 85  is 4.08
# The variance of team 85  is 0.00274
# The standard deviation of team 85  is 0.05231
#
# Team 86
# The mean CGPA of team 86  is 4.08
# The variance of team 86  is 0.00208
# The standard deviation of team 86  is 0.04561
#
# Team 87
# The mean CGPA of team 87  is 4.05
# The variance of team 87  is 0.00066
# The standard deviation of team 87  is 0.02577
#
# Team 88
# The mean CGPA of team 88  is 4.15
# The variance of team 88  is 0.02686
# The standard deviation of team 88  is 0.16390
#
# Team 89
# The mean CGPA of team 89  is 4.02
# The variance of team 89  is 0.01542
# The standard deviation of team 89  is 0.12419
#
# Team 90
# The mean CGPA of team 90  is 4.10
# The variance of team 90  is 0.01930
# The standard deviation of team 90  is 0.13894
#
# Team 91
# The mean CGPA of team 91  is 4.10
# The variance of team 91  is 0.00806
# The standard deviation of team 91  is 0.08980
#
# Team 92
# The mean CGPA of team 92  is 4.11
# The variance of team 92  is 0.00618
# The standard deviation of team 92  is 0.07864
#
# Team 93
# The mean CGPA of team 93  is 4.13
# The variance of team 93  is 0.00910
# The standard deviation of team 93  is 0.09541
#
# Team 94
# The mean CGPA of team 94  is 4.13
# The variance of team 94  is 0.00470
# The standard deviation of team 94  is 0.06853
#
# Team 95
# The mean CGPA of team 95  is 4.13
# The variance of team 95  is 0.00478
# The standard deviation of team 95  is 0.06911
#
# Team 96
# The mean CGPA of team 96  is 4.11
# The variance of team 96  is 0.00262
# The standard deviation of team 96  is 0.05122
#
# Team 97
# The mean CGPA of team 97  is 4.12
# The variance of team 97  is 0.00214
# The standard deviation of team 97  is 0.04622
#
# Team 98
# The mean CGPA of team 98  is 4.12
# The variance of team 98  is 0.04692
# The standard deviation of team 98  is 0.21661
#
# Team 99
# The mean CGPA of team 99  is 4.13
# The variance of team 99  is 0.04422
# The standard deviation of team 99  is 0.21028
#
# Team 100
# The mean CGPA of team 100  is 4.11
# The variance of team 100  is 0.02254
# The standard deviation of team 100  is 0.15015
#
# Team 101
# The mean CGPA of team 101  is 4.07
# The variance of team 101  is 0.01470
# The standard deviation of team 101  is 0.12126
#
# Team 102
# The mean CGPA of team 102  is 4.09
# The variance of team 102  is 0.01448
# The standard deviation of team 102  is 0.12033
#
# Team 103
# The mean CGPA of team 103  is 4.07
# The variance of team 103  is 0.01118
# The standard deviation of team 103  is 0.10572
#
# Team 104
# The mean CGPA of team 104  is 4.07
# The variance of team 104  is 0.00932
# The standard deviation of team 104  is 0.09654
#
# Team 105
# The mean CGPA of team 105  is 4.09
# The variance of team 105  is 0.00602
# The standard deviation of team 105  is 0.07761
#
# Team 106
# The mean CGPA of team 106  is 4.09
# The variance of team 106  is 0.01190
# The standard deviation of team 106  is 0.10907
#
# Team 107
# The mean CGPA of team 107  is 4.08
# The variance of team 107  is 0.01378
# The standard deviation of team 107  is 0.11737
#
# Team 108
# The mean CGPA of team 108  is 4.08
# The variance of team 108  is 0.00318
# The standard deviation of team 108  is 0.05636
#
# Team 109
# The mean CGPA of team 109  is 3.98
# The variance of team 109  is 0.01582
# The standard deviation of team 109  is 0.12579
#
# Team 110
# The mean CGPA of team 110  is 4.12
# The variance of team 110  is 0.02002
# The standard deviation of team 110  is 0.14151
#
# Team 111
# The mean CGPA of team 111  is 4.12
# The variance of team 111  is 0.01574
# The standard deviation of team 111  is 0.12548
#
# Team 112
# The mean CGPA of team 112  is 4.10
# The variance of team 112  is 0.01738
# The standard deviation of team 112  is 0.13185
#
# Team 113
# The mean CGPA of team 113  is 4.13
# The variance of team 113  is 0.01038
# The standard deviation of team 113  is 0.10186
#
# Team 114
# The mean CGPA of team 114  is 4.12
# The variance of team 114  is 0.00824
# The standard deviation of team 114  is 0.09077
#
# Team 115
# The mean CGPA of team 115  is 4.13
# The variance of team 115  is 0.00826
# The standard deviation of team 115  is 0.09091
#
# Team 116
# The mean CGPA of team 116  is 4.11
# The variance of team 116  is 0.00628
# The standard deviation of team 116  is 0.07925
#
# Team 117
# The mean CGPA of team 117  is 4.10
# The variance of team 117  is 0.00150
# The standard deviation of team 117  is 0.03878
#
# Team 118
# The mean CGPA of team 118  is 4.16
# The variance of team 118  is 0.03246
# The standard deviation of team 118  is 0.18016
#
# Team 119
# The mean CGPA of team 119  is 4.09
# The variance of team 119  is 0.05558
# The standard deviation of team 119  is 0.23575
#
# Team 120
# The mean CGPA of team 120  is 4.06
# The variance of team 120  is 0.02610
# The standard deviation of team 120  is 0.16157
#
# Team 121
# The mean CGPA of team 121  is 4.06
# The variance of team 121  is 0.01482
# The standard deviation of team 121  is 0.12175
#
# Team 122
# The mean CGPA of team 122  is 4.07
# The variance of team 122  is 0.01766
# The standard deviation of team 122  is 0.13288
#
# Team 123
# The mean CGPA of team 123  is 4.06
# The variance of team 123  is 0.01250
# The standard deviation of team 123  is 0.11182
#
# Team 124
# The mean CGPA of team 124  is 4.07
# The variance of team 124  is 0.00726
# The standard deviation of team 124  is 0.08523
#
# Team 125
# The mean CGPA of team 125  is 4.08
# The variance of team 125  is 0.00570
# The standard deviation of team 125  is 0.07552
#
# Team 126
# The mean CGPA of team 126  is 4.06
# The variance of team 126  is 0.00574
# The standard deviation of team 126  is 0.07579
#
# Team 127
# The mean CGPA of team 127  is 4.06
# The variance of team 127  is 0.00322
# The standard deviation of team 127  is 0.05678
#
# Team 128
# The mean CGPA of team 128  is 4.07
# The variance of team 128  is 0.00502
# The standard deviation of team 128  is 0.07082
#
# Team 129
# The mean CGPA of team 129  is 4.03
# The variance of team 129  is 0.02606
# The standard deviation of team 129  is 0.16142
#
# Team 130
# The mean CGPA of team 130  is 4.08
# The variance of team 130  is 0.03166
# The standard deviation of team 130  is 0.17794
#
# Team 131
# The mean CGPA of team 131  is 4.06
# The variance of team 131  is 0.01874
# The standard deviation of team 131  is 0.13688
#
# Team 132
# The mean CGPA of team 132  is 4.09
# The variance of team 132  is 0.01350
# The standard deviation of team 132  is 0.11621
#
# Team 133
# The mean CGPA of team 133  is 4.07
# The variance of team 133  is 0.01174
# The standard deviation of team 133  is 0.10837
#
# Team 134
# The mean CGPA of team 134  is 4.07
# The variance of team 134  is 0.00520
# The standard deviation of team 134  is 0.07211
#
# Team 135
# The mean CGPA of team 135  is 4.09
# The variance of team 135  is 0.00394
# The standard deviation of team 135  is 0.06280
#
# Team 136
# The mean CGPA of team 136  is 4.08
# The variance of team 136  is 0.00282
# The standard deviation of team 136  is 0.05314
#
# Team 137
# The mean CGPA of team 137  is 4.08
# The variance of team 137  is 0.00150
# The standard deviation of team 137  is 0.03878
#
# Team 138
# The mean CGPA of team 138  is 4.17
# The variance of team 138  is 0.03254
# The standard deviation of team 138  is 0.18040
#
# Team 139
# The mean CGPA of team 139  is 4.00
# The variance of team 139  is 0.03062
# The standard deviation of team 139  is 0.17497
#
# Team 140
# The mean CGPA of team 140  is 4.05
# The variance of team 140  is 0.01694
# The standard deviation of team 140  is 0.13014
#
# Team 141
# The mean CGPA of team 141  is 4.05
# The variance of team 141  is 0.01410
# The standard deviation of team 141  is 0.11876
#
# Team 142
# The mean CGPA of team 142  is 4.07
# The variance of team 142  is 0.01130
# The standard deviation of team 142  is 0.10632
#
# Team 143
# The mean CGPA of team 143  is 4.07
# The variance of team 143  is 0.00802
# The standard deviation of team 143  is 0.08958
#
# Team 144
# The mean CGPA of team 144  is 4.08
# The variance of team 144  is 0.00870
# The standard deviation of team 144  is 0.09330
#
# Team 145
# The mean CGPA of team 145  is 4.06
# The variance of team 145  is 0.00370
# The standard deviation of team 145  is 0.06086
#
# Team 146
# The mean CGPA of team 146  is 4.07
# The variance of team 146  is 0.00374
# The standard deviation of team 146  is 0.06119
#
# Team 147
# The mean CGPA of team 147  is 4.06
# The variance of team 147  is 0.00238
# The standard deviation of team 147  is 0.04874
#
# Team 148
# The mean CGPA of team 148  is 4.08
# The variance of team 148  is 0.01236
# The standard deviation of team 148  is 0.11118
#
# Team 149
# The mean CGPA of team 149  is 3.99
# The variance of team 149  is 0.01146
# The standard deviation of team 149  is 0.10707
#
# Team 150
# The mean CGPA of team 150  is 4.06
# The variance of team 150  is 0.01906
# The standard deviation of team 150  is 0.13804
#
# Team 151
# The mean CGPA of team 151  is 4.08
# The variance of team 151  is 0.01314
# The standard deviation of team 151  is 0.11461
#
# Team 152
# The mean CGPA of team 152  is 4.07
# The variance of team 152  is 0.01212
# The standard deviation of team 152  is 0.11009
#
# Team 153
# The mean CGPA of team 153  is 4.09
# The variance of team 153  is 0.00640
# The standard deviation of team 153  is 0.08000
#
# Team 154
# The mean CGPA of team 154  is 4.07
# The variance of team 154  is 0.00362
# The standard deviation of team 154  is 0.06020
#
# Team 155
# The mean CGPA of team 155  is 4.09
# The variance of team 155  is 0.00366
# The standard deviation of team 155  is 0.06046
#
# Team 156
# The mean CGPA of team 156  is 4.07
# The variance of team 156  is 0.00206
# The standard deviation of team 156  is 0.04543
#
# Team 157
# The mean CGPA of team 157  is 4.09
# The variance of team 157  is 0.00224
# The standard deviation of team 157  is 0.04733
#
# Team 158
# The mean CGPA of team 158  is 4.08
# The variance of team 158  is 0.00486
# The standard deviation of team 158  is 0.06969
#
# Team 159
# The mean CGPA of team 159  is 4.07
# The variance of team 159  is 0.05116
# The standard deviation of team 159  is 0.22619
#
# Team 160
# The mean CGPA of team 160  is 4.09
# The variance of team 160  is 0.02558
# The standard deviation of team 160  is 0.15995
#
# Team 161
# The mean CGPA of team 161  is 4.09
# The variance of team 161  is 0.01660
# The standard deviation of team 161  is 0.12884
#
# Team 162
# The mean CGPA of team 162  is 4.07
# The variance of team 162  is 0.01830
# The standard deviation of team 162  is 0.13529
#
# Team 163
# The mean CGPA of team 163  is 4.08
# The variance of team 163  is 0.00720
# The standard deviation of team 163  is 0.08485
#
# Team 164
# The mean CGPA of team 164  is 4.10
# The variance of team 164  is 0.00470
# The standard deviation of team 164  is 0.06853
#
# Team 165
# The mean CGPA of team 165  is 4.09
# The variance of team 165  is 0.00306
# The standard deviation of team 165  is 0.05528
#
# Team 166
# The mean CGPA of team 166  is 4.09
# The variance of team 166  is 0.00258
# The standard deviation of team 166  is 0.05083
#
# Team 167
# The mean CGPA of team 167  is 4.09
# The variance of team 167  is 0.00214
# The standard deviation of team 167  is 0.04630
#
# Team 168
# The mean CGPA of team 168  is 4.16
# The variance of team 168  is 0.03322
# The standard deviation of team 168  is 0.18225
#
# Team 169
# The mean CGPA of team 169  is 4.03
# The variance of team 169  is 0.01972
# The standard deviation of team 169  is 0.14043
#
# Team 170
# The mean CGPA of team 170  is 4.05
# The variance of team 170  is 0.01936
# The standard deviation of team 170  is 0.13914
#
# Team 171
# The mean CGPA of team 171  is 4.05
# The variance of team 171  is 0.01626
# The standard deviation of team 171  is 0.12750
#
# Team 172
# The mean CGPA of team 172  is 4.06
# The variance of team 172  is 0.01556
# The standard deviation of team 172  is 0.12474
#
# Team 173
# The mean CGPA of team 173  is 4.07
# The variance of team 173  is 0.01102
# The standard deviation of team 173  is 0.10496
#
# Team 174
# The mean CGPA of team 174  is 4.08
# The variance of team 174  is 0.00608
# The standard deviation of team 174  is 0.07797
#
# Team 175
# The mean CGPA of team 175  is 4.08
# The variance of team 175  is 0.00428
# The standard deviation of team 175  is 0.06542
#
# Team 176
# The mean CGPA of team 176  is 4.10
# The variance of team 176  is 0.00346
# The standard deviation of team 176  is 0.05886
#
# Team 177
# The mean CGPA of team 177  is 4.08
# The variance of team 177  is 0.00274
# The standard deviation of team 177  is 0.05238
#
# Team 178
# The mean CGPA of team 178  is 4.11
# The variance of team 178  is 0.00310
# The standard deviation of team 178  is 0.05564
#
# Team 179
# The mean CGPA of team 179  is 4.02
# The variance of team 179  is 0.01958
# The standard deviation of team 179  is 0.13991
#
# Team 180
# The mean CGPA of team 180  is 4.07
# The variance of team 180  is 0.01286
# The standard deviation of team 180  is 0.11338
#
# Team 181
# The mean CGPA of team 181  is 4.07
# The variance of team 181  is 0.01174
# The standard deviation of team 181  is 0.10837
#
# Team 182
# The mean CGPA of team 182  is 4.07
# The variance of team 182  is 0.00826
# The standard deviation of team 182  is 0.09091
#
# Team 183
# The mean CGPA of team 183  is 4.09
# The variance of team 183  is 0.00498
# The standard deviation of team 183  is 0.07054
#
# Team 184
# The mean CGPA of team 184  is 4.09
# The variance of team 184  is 0.00470
# The standard deviation of team 184  is 0.06859
#
# Team 185
# The mean CGPA of team 185  is 4.09
# The variance of team 185  is 0.00288
# The standard deviation of team 185  is 0.05367
#
# Team 186
# The mean CGPA of team 186  is 4.08
# The variance of team 186  is 0.00334
# The standard deviation of team 186  is 0.05783
#
# Team 187
# The mean CGPA of team 187  is 4.08
# The variance of team 187  is 0.00158
# The standard deviation of team 187  is 0.03970
#
# Team 188
# The mean CGPA of team 188  is 4.04
# The variance of team 188  is 0.00916
# The standard deviation of team 188  is 0.09571
#
# Team 189
# The mean CGPA of team 189  is 4.06
# The variance of team 189  is 0.01654
# The standard deviation of team 189  is 0.12862
#
# Team 190
# The mean CGPA of team 190  is 4.07
# The variance of team 190  is 0.01816
# The standard deviation of team 190  is 0.13476
#
# Team 191
# The mean CGPA of team 191  is 4.07
# The variance of team 191  is 0.01726
# The standard deviation of team 191  is 0.13136
#
# Team 192
# The mean CGPA of team 192  is 4.09
# The variance of team 192  is 0.00906
# The standard deviation of team 192  is 0.09516
#
# Team 193
# The mean CGPA of team 193  is 4.09
# The variance of team 193  is 0.00542
# The standard deviation of team 193  is 0.07359
#
# Team 194
# The mean CGPA of team 194  is 4.09
# The variance of team 194  is 0.00754
# The standard deviation of team 194  is 0.08686
#
# Team 195
# The mean CGPA of team 195  is 4.09
# The variance of team 195  is 0.00432
# The standard deviation of team 195  is 0.06573
#
# Team 196
# The mean CGPA of team 196  is 4.07
# The variance of team 196  is 0.00302
# The standard deviation of team 196  is 0.05492
#
# Team 197
# The mean CGPA of team 197  is 4.09
# The variance of team 197  is 0.00176
# The standard deviation of team 197  is 0.04195
#
# Team 198
# The mean CGPA of team 198  is 4.10
# The variance of team 198  is 0.01052
# The standard deviation of team 198  is 0.10257
#
# Team 199
# The mean CGPA of team 199  is 4.07
# The variance of team 199  is 0.05950
# The standard deviation of team 199  is 0.24392
#
# Team 200
# The mean CGPA of team 200  is 4.05
# The variance of team 200  is 0.01866
# The standard deviation of team 200  is 0.13659
#
# Team 201
# The mean CGPA of team 201  is 4.09
# The variance of team 201  is 0.01398
# The standard deviation of team 201  is 0.11825
#
# Team 202
# The mean CGPA of team 202  is 4.08
# The variance of team 202  is 0.01034
# The standard deviation of team 202  is 0.10171
#
# Team 203
# The mean CGPA of team 203  is 4.08
# The variance of team 203  is 0.00816
# The standard deviation of team 203  is 0.09033
#
# Team 204
# The mean CGPA of team 204  is 4.06
# The variance of team 204  is 0.00918
# The standard deviation of team 204  is 0.09579
#
# Team 205
# The mean CGPA of team 205  is 4.07
# The variance of team 205  is 0.00628
# The standard deviation of team 205  is 0.07925
#
# Team 206
# The mean CGPA of team 206  is 4.09
# The variance of team 206  is 0.00540
# The standard deviation of team 206  is 0.07348
#
# Team 207
# The mean CGPA of team 207  is 4.05
# The variance of team 207  is 0.00070
# The standard deviation of team 207  is 0.02653
#
# Team 208
# The mean CGPA of team 208  is 4.12
# The variance of team 208  is 0.00678
# The standard deviation of team 208  is 0.08232
#
# Team 209
# The mean CGPA of team 209  is 4.02
# The variance of team 209  is 0.01994
# The standard deviation of team 209  is 0.14122
#
# Team 210
# The mean CGPA of team 210  is 4.08
# The variance of team 210  is 0.01802
# The standard deviation of team 210  is 0.13422
#
# Team 211
# The mean CGPA of team 211  is 4.09
# The variance of team 211  is 0.00950
# The standard deviation of team 211  is 0.09745
#
# Team 212
# The mean CGPA of team 212  is 4.09
# The variance of team 212  is 0.00982
# The standard deviation of team 212  is 0.09912
#
# Team 213
# The mean CGPA of team 213  is 4.08
# The variance of team 213  is 0.00638
# The standard deviation of team 213  is 0.07985
#
# Team 214
# The mean CGPA of team 214  is 4.10
# The variance of team 214  is 0.00638
# The standard deviation of team 214  is 0.07985
#
# Team 215
# The mean CGPA of team 215  is 4.10
# The variance of team 215  is 0.00496
# The standard deviation of team 215  is 0.07043
#
# Team 216
# The mean CGPA of team 216  is 4.11
# The variance of team 216  is 0.00306
# The standard deviation of team 216  is 0.05535
#
# Team 217
# The mean CGPA of team 217  is 4.06
# The variance of team 217  is 0.00326
# The standard deviation of team 217  is 0.05706
#
# Team 218
# The mean CGPA of team 218  is 4.07
# The variance of team 218  is 0.01544
# The standard deviation of team 218  is 0.12426
#
# Team 219
# The mean CGPA of team 219  is 4.03
# The variance of team 219  is 0.01402
# The standard deviation of team 219  is 0.11842
#
# Team 220
# The mean CGPA of team 220  is 4.08
# The variance of team 220  is 0.03082
# The standard deviation of team 220  is 0.17554
#
# Team 221
# The mean CGPA of team 221  is 4.05
# The variance of team 221  is 0.01450
# The standard deviation of team 221  is 0.12040
#
# Team 222
# The mean CGPA of team 222  is 4.06
# The variance of team 222  is 0.01474
# The standard deviation of team 222  is 0.12142
#
# Team 223
# The mean CGPA of team 223  is 4.07
# The variance of team 223  is 0.01238
# The standard deviation of team 223  is 0.11125
#
# Team 224
# The mean CGPA of team 224  is 4.07
# The variance of team 224  is 0.00982
# The standard deviation of team 224  is 0.09908
#
# Team 225
# The mean CGPA of team 225  is 4.05
# The variance of team 225  is 0.00682
# The standard deviation of team 225  is 0.08261
#
# Team 226
# The mean CGPA of team 226  is 4.08
# The variance of team 226  is 0.00318
# The standard deviation of team 226  is 0.05636
#
# Team 227
# The mean CGPA of team 227  is 4.06
# The variance of team 227  is 0.00278
# The standard deviation of team 227  is 0.05276
#
# Team 228
# The mean CGPA of team 228  is 4.08
# The variance of team 228  is 0.00134
# The standard deviation of team 228  is 0.03655
#
# Team 229
# The mean CGPA of team 229  is 4.18
# The variance of team 229  is 0.13236
# The standard deviation of team 229  is 0.36381
#
# Team 230
# The mean CGPA of team 230  is 4.04
# The variance of team 230  is 0.02322
# The standard deviation of team 230  is 0.15237
#
# Team 231
# The mean CGPA of team 231  is 4.06
# The variance of team 231  is 0.01210
# The standard deviation of team 231  is 0.11002
#
# Team 232
# The mean CGPA of team 232  is 4.04
# The variance of team 232  is 0.01382
# The standard deviation of team 232  is 0.11754
#
# Team 233
# The mean CGPA of team 233  is 4.07
# The variance of team 233  is 0.00496
# The standard deviation of team 233  is 0.07043
#
# Team 234
# The mean CGPA of team 234  is 4.07
# The variance of team 234  is 0.00360
# The standard deviation of team 234  is 0.06000
#
# Team 235
# The mean CGPA of team 235  is 4.07
# The variance of team 235  is 0.00400
# The standard deviation of team 235  is 0.06325
#
# Team 236
# The mean CGPA of team 236  is 4.07
# The variance of team 236  is 0.00246
# The standard deviation of team 236  is 0.04956
#
# Team 237
# The mean CGPA of team 237  is 4.06
# The variance of team 237  is 0.00158
# The standard deviation of team 237  is 0.03970
#
# Team 238
# The mean CGPA of team 238  is 4.04
# The variance of team 238  is 0.01314
# The standard deviation of team 238  is 0.11461
#
# Team 239
# The mean CGPA of team 239  is 4.05
# The variance of team 239  is 0.01618
# The standard deviation of team 239  is 0.12722
#
# Team 240
# The mean CGPA of team 240  is 4.08
# The variance of team 240  is 0.01878
# The standard deviation of team 240  is 0.13703
#
# Team 241
# The mean CGPA of team 241  is 4.09
# The variance of team 241  is 0.01288
# The standard deviation of team 241  is 0.11349
#
# Team 242
# The mean CGPA of team 242  is 4.07
# The variance of team 242  is 0.01366
# The standard deviation of team 242  is 0.11689
#
# Team 243
# The mean CGPA of team 243  is 4.10
# The variance of team 243  is 0.00550
# The standard deviation of team 243  is 0.07419
#
# Team 244
# The mean CGPA of team 244  is 4.10
# The variance of team 244  is 0.00390
# The standard deviation of team 244  is 0.06248
#
# Team 245
# The mean CGPA of team 245  is 4.09
# The variance of team 245  is 0.00194
# The standard deviation of team 245  is 0.04409
#
# Team 246
# The mean CGPA of team 246  is 4.10
# The variance of team 246  is 0.00214
# The standard deviation of team 246  is 0.04622
#
# Team 247
# The mean CGPA of team 247  is 4.05
# The variance of team 247  is 0.00078
# The standard deviation of team 247  is 0.02786
#
# Team 248
# The mean CGPA of team 248  is 4.12
# The variance of team 248  is 0.00428
# The standard deviation of team 248  is 0.06542
#
# Team 249
# The mean CGPA of team 249  is 4.12
# The variance of team 249  is 0.10562
# The standard deviation of team 249  is 0.32500
#
# Team 250
# The mean CGPA of team 250  is 4.07
# The variance of team 250  is 0.01618
# The standard deviation of team 250  is 0.12722
#
# Team 251
# The mean CGPA of team 251  is 4.07
# The variance of team 251  is 0.01122
# The standard deviation of team 251  is 0.10594
#
# Team 252
# The mean CGPA of team 252  is 4.06
# The variance of team 252  is 0.01798
# The standard deviation of team 252  is 0.13410
#
# Team 253
# The mean CGPA of team 253  is 4.08
# The variance of team 253  is 0.01410
# The standard deviation of team 253  is 0.11876
#
# Team 254
# The mean CGPA of team 254  is 4.10
# The variance of team 254  is 0.01030
# The standard deviation of team 254  is 0.10147
#
# Team 255
# The mean CGPA of team 255  is 4.08
# The variance of team 255  is 0.00652
# The standard deviation of team 255  is 0.08075
#
# Team 256
# The mean CGPA of team 256  is 4.09
# The variance of team 256  is 0.00662
# The standard deviation of team 256  is 0.08134
#
# Team 257
# The mean CGPA of team 257  is 4.10
# The variance of team 257  is 0.00510
# The standard deviation of team 257  is 0.07139
#
# Team 258
# The mean CGPA of team 258  is 4.11
# The variance of team 258  is 0.00312
# The standard deviation of team 258  is 0.05586
#
# Team 259
# The mean CGPA of team 259  is 4.05
# The variance of team 259  is 0.03096
# The standard deviation of team 259  is 0.17595
#
# Team 260
# The mean CGPA of team 260  is 4.07
# The variance of team 260  is 0.02634
# The standard deviation of team 260  is 0.16231
#
# Team 261
# The mean CGPA of team 261  is 4.06
# The variance of team 261  is 0.01706
# The standard deviation of team 261  is 0.13060
#
# Team 262
# The mean CGPA of team 262  is 4.06
# The variance of team 262  is 0.01526
# The standard deviation of team 262  is 0.12355
#
# Team 263
# The mean CGPA of team 263  is 4.06
# The variance of team 263  is 0.01586
# The standard deviation of team 263  is 0.12595
#
# Team 264
# The mean CGPA of team 264  is 4.07
# The variance of team 264  is 0.00946
# The standard deviation of team 264  is 0.09728
#
# Team 265
# The mean CGPA of team 265  is 4.09
# The variance of team 265  is 0.00658
# The standard deviation of team 265  is 0.08114
#
# Team 266
# The mean CGPA of team 266  is 4.09
# The variance of team 266  is 0.00290
# The standard deviation of team 266  is 0.05389
#
# Team 267
# The mean CGPA of team 267  is 4.09
# The variance of team 267  is 0.00206
# The standard deviation of team 267  is 0.04543
#
# Team 268
# The mean CGPA of team 268  is 4.11
# The variance of team 268  is 0.00966
# The standard deviation of team 268  is 0.09826
#
# Team 269
# The mean CGPA of team 269  is 4.05
# The variance of team 269  is 0.06954
# The standard deviation of team 269  is 0.26371
#
# Team 270
# The mean CGPA of team 270  is 4.06
# The variance of team 270  is 0.01846
# The standard deviation of team 270  is 0.13588
#
# Team 271
# The mean CGPA of team 271  is 4.06
# The variance of team 271  is 0.01922
# The standard deviation of team 271  is 0.13862
#
# Team 272
# The mean CGPA of team 272  is 4.08
# The variance of team 272  is 0.01234
# The standard deviation of team 272  is 0.11107
#
# Team 273
# The mean CGPA of team 273  is 4.09
# The variance of team 273  is 0.00526
# The standard deviation of team 273  is 0.07250
#
# Team 274
# The mean CGPA of team 274  is 4.08
# The variance of team 274  is 0.00338
# The standard deviation of team 274  is 0.05810
#
# Team 275
# The mean CGPA of team 275  is 4.09
# The variance of team 275  is 0.00512
# The standard deviation of team 275  is 0.07155
#
# Team 276
# The mean CGPA of team 276  is 4.08
# The variance of team 276  is 0.00306
# The standard deviation of team 276  is 0.05535
#
# Team 277
# The mean CGPA of team 277  is 4.08
# The variance of team 277  is 0.00550
# The standard deviation of team 277  is 0.07419
#
# Team 278
# The mean CGPA of team 278  is 4.05
# The variance of team 278  is 0.01678
# The standard deviation of team 278  is 0.12955
#
# Team 279
# The mean CGPA of team 279  is 4.06
# The variance of team 279  is 0.00966
# The standard deviation of team 279  is 0.09826
#
# Team 280
# The mean CGPA of team 280  is 4.07
# The variance of team 280  is 0.02216
# The standard deviation of team 280  is 0.14886
#
# Team 281
# The mean CGPA of team 281  is 4.09
# The variance of team 281  is 0.01746
# The standard deviation of team 281  is 0.13215
#
# Team 282
# The mean CGPA of team 282  is 4.08
# The variance of team 282  is 0.00854
# The standard deviation of team 282  is 0.09239
#
# Team 283
# The mean CGPA of team 283  is 4.10
# The variance of team 283  is 0.00550
# The standard deviation of team 283  is 0.07414
#
# Team 284
# The mean CGPA of team 284  is 4.08
# The variance of team 284  is 0.00642
# The standard deviation of team 284  is 0.08015
#
# Team 285
# The mean CGPA of team 285  is 4.08
# The variance of team 285  is 0.00222
# The standard deviation of team 285  is 0.04707
#
# Team 286
# The mean CGPA of team 286  is 4.08
# The variance of team 286  is 0.00192
# The standard deviation of team 286  is 0.04382
#
# Team 287
# The mean CGPA of team 287  is 4.07
# The variance of team 287  is 0.00178
# The standard deviation of team 287  is 0.04224
#
# Team 288
# The mean CGPA of team 288  is 4.11
# The variance of team 288  is 0.00278
# The standard deviation of team 288  is 0.05269
#
# Team 289
# The mean CGPA of team 289  is 4.07
# The variance of team 289  is 0.06094
# The standard deviation of team 289  is 0.24687
#
# Team 290
# The mean CGPA of team 290  is 4.07
# The variance of team 290  is 0.02318
# The standard deviation of team 290  is 0.15224
#
# Team 291
# The mean CGPA of team 291  is 4.09
# The variance of team 291  is 0.01682
# The standard deviation of team 291  is 0.12971
#
# Team 292
# The mean CGPA of team 292  is 4.07
# The variance of team 292  is 0.01542
# The standard deviation of team 292  is 0.12419
#
# Team 293
# The mean CGPA of team 293  is 4.11
# The variance of team 293  is 0.00764
# The standard deviation of team 293  is 0.08741
#
# Team 294
# The mean CGPA of team 294  is 4.07
# The variance of team 294  is 0.01722
# The standard deviation of team 294  is 0.13124
#
# Team 295
# The mean CGPA of team 295  is 4.12
# The variance of team 295  is 0.00690
# The standard deviation of team 295  is 0.08309
#
# Team 296
# The mean CGPA of team 296  is 4.09
# The variance of team 296  is 0.00496
# The standard deviation of team 296  is 0.07043
#
# Team 297
# The mean CGPA of team 297  is 4.11
# The variance of team 297  is 0.00356
# The standard deviation of team 297  is 0.05967
#
# Team 298
# The mean CGPA of team 298  is 4.12
# The variance of team 298  is 0.04546
# The standard deviation of team 298  is 0.21322
#
# Team 299
# The mean CGPA of team 299  is 4.10
# The variance of team 299  is 0.00746
# The standard deviation of team 299  is 0.08639
#
# Team 300
# The mean CGPA of team 300  is 4.07
# The variance of team 300  is 0.02602
# The standard deviation of team 300  is 0.16132
#
# Team 301
# The mean CGPA of team 301  is 4.08
# The variance of team 301  is 0.01922
# The standard deviation of team 301  is 0.13862
#
# Team 302
# The mean CGPA of team 302  is 4.09
# The variance of team 302  is 0.01452
# The standard deviation of team 302  is 0.12050
#
# Team 303
# The mean CGPA of team 303  is 4.10
# The variance of team 303  is 0.01182
# The standard deviation of team 303  is 0.10874
#
# Team 304
# The mean CGPA of team 304  is 4.11
# The variance of team 304  is 0.00710
# The standard deviation of team 304  is 0.08424
#
# Team 305
# The mean CGPA of team 305  is 4.11
# The variance of team 305  is 0.00446
# The standard deviation of team 305  is 0.06675
#
# Team 306
# The mean CGPA of team 306  is 4.12
# The variance of team 306  is 0.00474
# The standard deviation of team 306  is 0.06888
#
# Team 307
# The mean CGPA of team 307  is 4.10
# The variance of team 307  is 0.00308
# The standard deviation of team 307  is 0.05550
#
# Team 308
# The mean CGPA of team 308  is 4.23
# The variance of team 308  is 0.10022
# The standard deviation of team 308  is 0.31658
#
# Team 309
# The mean CGPA of team 309  is 4.05
# The variance of team 309  is 0.00774
# The standard deviation of team 309  is 0.08800
#
# Team 310
# The mean CGPA of team 310  is 4.08
# The variance of team 310  is 0.01792
# The standard deviation of team 310  is 0.13387
#
# Team 311
# The mean CGPA of team 311  is 4.10
# The variance of team 311  is 0.01042
# The standard deviation of team 311  is 0.10210
#
# Team 312
# The mean CGPA of team 312  is 4.08
# The variance of team 312  is 0.00824
# The standard deviation of team 312  is 0.09077
#
# Team 313
# The mean CGPA of team 313  is 4.10
# The variance of team 313  is 0.00490
# The standard deviation of team 313  is 0.06997
#
# Team 314
# The mean CGPA of team 314  is 4.09
# The variance of team 314  is 0.00434
# The standard deviation of team 314  is 0.06591
#
# Team 315
# The mean CGPA of team 315  is 4.10
# The variance of team 315  is 0.00326
# The standard deviation of team 315  is 0.05713
#
# Team 316
# The mean CGPA of team 316  is 4.08
# The variance of team 316  is 0.00322
# The standard deviation of team 316  is 0.05671
#
# Team 317
# The mean CGPA of team 317  is 4.09
# The variance of team 317  is 0.00206
# The standard deviation of team 317  is 0.04534
#
# Team 318
# The mean CGPA of team 318  is 4.07
# The variance of team 318  is 0.00234
# The standard deviation of team 318  is 0.04841
#
# Team 319
# The mean CGPA of team 319  is 4.07
# The variance of team 319  is 0.03724
# The standard deviation of team 319  is 0.19298
#
# Team 320
# The mean CGPA of team 320  is 4.16
# The variance of team 320  is 0.04416
# The standard deviation of team 320  is 0.21014
#
# Team 321
# The mean CGPA of team 321  is 4.11
# The variance of team 321  is 0.01674
# The standard deviation of team 321  is 0.12937
#
# Team 322
# The mean CGPA of team 322  is 4.12
# The variance of team 322  is 0.00720
# The standard deviation of team 322  is 0.08485
#
# Team 323
# The mean CGPA of team 323  is 4.12
# The variance of team 323  is 0.00678
# The standard deviation of team 323  is 0.08232
#
# Team 324
# The mean CGPA of team 324  is 4.12
# The variance of team 324  is 0.00808
# The standard deviation of team 324  is 0.08989
#
# Team 325
# The mean CGPA of team 325  is 4.10
# The variance of team 325  is 0.00414
# The standard deviation of team 325  is 0.06431
#
# Team 326
# The mean CGPA of team 326  is 4.10
# The variance of team 326  is 0.00242
# The standard deviation of team 326  is 0.04923
#
# Team 327
# The mean CGPA of team 327  is 4.09
# The variance of team 327  is 0.00194
# The standard deviation of team 327  is 0.04400
#
# Team 328
# The mean CGPA of team 328  is 4.09
# The variance of team 328  is 0.00484
# The standard deviation of team 328  is 0.06957
#
# Team 329
# The mean CGPA of team 329  is 4.08
# The variance of team 329  is 0.05710
# The standard deviation of team 329  is 0.23895
#
# Team 330
# The mean CGPA of team 330  is 4.08
# The variance of team 330  is 0.02450
# The standard deviation of team 330  is 0.15651
#
# Team 331
# The mean CGPA of team 331  is 4.08
# The variance of team 331  is 0.01466
# The standard deviation of team 331  is 0.12110
#
# Team 332
# The mean CGPA of team 332  is 4.10
# The variance of team 332  is 0.01690
# The standard deviation of team 332  is 0.13002
#
# Team 333
# The mean CGPA of team 333  is 4.09
# The variance of team 333  is 0.01238
# The standard deviation of team 333  is 0.11128
#
# Team 334
# The mean CGPA of team 334  is 4.11
# The variance of team 334  is 0.00714
# The standard deviation of team 334  is 0.08452
#
# Team 335
# The mean CGPA of team 335  is 4.10
# The variance of team 335  is 0.00500
# The standard deviation of team 335  is 0.07071
#
# Team 336
# The mean CGPA of team 336  is 4.09
# The variance of team 336  is 0.00426
# The standard deviation of team 336  is 0.06530
#
# Team 337
# The mean CGPA of team 337  is 4.10
# The variance of team 337  is 0.00296
# The standard deviation of team 337  is 0.05441
#
# Team 338
# The mean CGPA of team 338  is 4.10
# The variance of team 338  is 0.00646
# The standard deviation of team 338  is 0.08040
#
# Team 339
# The mean CGPA of team 339  is 4.04
# The variance of team 339  is 0.02650
# The standard deviation of team 339  is 0.16278
#
# Team 340
# The mean CGPA of team 340  is 4.09
# The variance of team 340  is 0.01942
# The standard deviation of team 340  is 0.13937
#
# Team 341
# The mean CGPA of team 341  is 4.10
# The variance of team 341  is 0.01042
# The standard deviation of team 341  is 0.10210
#
# Team 342
# The mean CGPA of team 342  is 4.12
# The variance of team 342  is 0.00594
# The standard deviation of team 342  is 0.07705
#
# Team 343
# The mean CGPA of team 343  is 4.12
# The variance of team 343  is 0.00618
# The standard deviation of team 343  is 0.07864
#
# Team 344
# The mean CGPA of team 344  is 4.13
# The variance of team 344  is 0.00314
# The standard deviation of team 344  is 0.05607
#
# Team 345
# The mean CGPA of team 345  is 4.11
# The variance of team 345  is 0.00182
# The standard deviation of team 345  is 0.04271
#
# Team 346
# The mean CGPA of team 346  is 4.13
# The variance of team 346  is 0.00208
# The standard deviation of team 346  is 0.04561
#
# Team 347
# The mean CGPA of team 347  is 4.15
# The variance of team 347  is 0.00678
# The standard deviation of team 347  is 0.08237
#
# Team 348
# The mean CGPA of team 348  is 4.13
# The variance of team 348  is 0.00542
# The standard deviation of team 348  is 0.07365
#
# Team 349
# The mean CGPA of team 349  is 4.01
# The variance of team 349  is 0.01812
# The standard deviation of team 349  is 0.13461
#
# Team 350
# The mean CGPA of team 350  is 4.07
# The variance of team 350  is 0.02574
# The standard deviation of team 350  is 0.16042
#
# Team 351
# The mean CGPA of team 351  is 4.08
# The variance of team 351  is 0.02314
# The standard deviation of team 351  is 0.15211
#
# Team 352
# The mean CGPA of team 352  is 4.07
# The variance of team 352  is 0.01012
# The standard deviation of team 352  is 0.10060
#
# Team 353
# The mean CGPA of team 353  is 4.09
# The variance of team 353  is 0.01264
# The standard deviation of team 353  is 0.11243
#
# Team 354
# The mean CGPA of team 354  is 4.07
# The variance of team 354  is 0.00558
# The standard deviation of team 354  is 0.07467
#
# Team 355
# The mean CGPA of team 355  is 4.10
# The variance of team 355  is 0.00850
# The standard deviation of team 355  is 0.09217
#
# Team 356
# The mean CGPA of team 356  is 4.10
# The variance of team 356  is 0.00306
# The standard deviation of team 356  is 0.05535
#
# Team 357
# The mean CGPA of team 357  is 4.07
# The variance of team 357  is 0.00146
# The standard deviation of team 357  is 0.03826
#
# Team 358
# The mean CGPA of team 358  is 4.09
# The variance of team 358  is 0.00790
# The standard deviation of team 358  is 0.08890
#
# Team 359
# The mean CGPA of team 359  is 4.03
# The variance of team 359  is 0.02218
# The standard deviation of team 359  is 0.14894
#
# Team 360
# The mean CGPA of team 360  is 4.14
# The variance of team 360  is 0.05338
# The standard deviation of team 360  is 0.23103
#
# Team 361
# The mean CGPA of team 361  is 4.12
# The variance of team 361  is 0.01630
# The standard deviation of team 361  is 0.12766
#
# Team 362
# The mean CGPA of team 362  is 4.12
# The variance of team 362  is 0.00818
# The standard deviation of team 362  is 0.09047
#
# Team 363
# The mean CGPA of team 363  is 4.11
# The variance of team 363  is 0.00606
# The standard deviation of team 363  is 0.07782
#
# Team 364
# The mean CGPA of team 364  is 4.11
# The variance of team 364  is 0.00430
# The standard deviation of team 364  is 0.06560
#
# Team 365
# The mean CGPA of team 365  is 4.09
# The variance of team 365  is 0.00444
# The standard deviation of team 365  is 0.06663
#
# Team 366
# The mean CGPA of team 366  is 4.12
# The variance of team 366  is 0.00434
# The standard deviation of team 366  is 0.06591
#
# Team 367
# The mean CGPA of team 367  is 4.11
# The variance of team 367  is 0.00194
# The standard deviation of team 367  is 0.04409
#
# Team 368
# The mean CGPA of team 368  is 4.22
# The variance of team 368  is 0.14606
# The standard deviation of team 368  is 0.38217
#
# Team 369
# The mean CGPA of team 369  is 4.14
# The variance of team 369  is 0.04172
# The standard deviation of team 369  is 0.20425
#
# Team 370
# The mean CGPA of team 370  is 4.05
# The variance of team 370  is 0.02202
# The standard deviation of team 370  is 0.14840
#
# Team 371
# The mean CGPA of team 371  is 4.11
# The variance of team 371  is 0.02034
# The standard deviation of team 371  is 0.14263
#
# Team 372
# The mean CGPA of team 372  is 4.09
# The variance of team 372  is 0.01454
# The standard deviation of team 372  is 0.12057
#
# Team 373
# The mean CGPA of team 373  is 4.08
# The variance of team 373  is 0.01072
# The standard deviation of team 373  is 0.10354
#
# Team 374
# The mean CGPA of team 374  is 4.10
# The variance of team 374  is 0.00850
# The standard deviation of team 374  is 0.09222
#
# Team 375
# The mean CGPA of team 375  is 4.09
# ...
#
# Team 1081
# The mean CGPA of team 1081  is 4.08
# The variance of team 1081  is 0.01648
# The standard deviation of team 1081  is 0.12837
#
# Team 1082
# The mean CGPA of team 1082  is 4.09
# The variance of team 1082  is 0.01514
# The standard deviation of team 1082  is 0.12303
#
# Team 1083
# The mean CGPA of team 1083  is 4.06
# The variance of team 1083  is 0.01668
# The standard deviation of team 1083  is 0.12915
#
# Team 1084
# The mean CGPA of team 1084  is 4.09
# The variance of team 1084  is 0.01004
# The standard deviation of team 1084  is 0.10020
#
# Team 1085
# The mean CGPA of team 1085  is 4.09
# The variance of team 1085  is 0.00522
# The standard deviation of team 1085  is 0.07228
#
# Team 1086
# The mean CGPA of team 1086  is 4.10
# The variance of team 1086  is 0.00582
# The standard deviation of team 1086  is 0.07626
#
# Team 1087
# The mean CGPA of team 1087  is 4.08
# The variance of team 1087  is 0.00234
# The standard deviation of team 1087  is 0.04833
#
# Team 1088
# The mean CGPA of team 1088  is 4.06
# The variance of team 1088  is 0.00062
# The standard deviation of team 1088  is 0.02482
#
# Team 1089
# The mean CGPA of team 1089  is 4.09
# The variance of team 1089  is 0.02518
# The standard deviation of team 1089  is 0.15867
#
# Team 1090
# The mean CGPA of team 1090  is 4.08
# The variance of team 1090  is 0.01004
# The standard deviation of team 1090  is 0.10020
#
# Team 1091
# The mean CGPA of team 1091  is 4.09
# The variance of team 1091  is 0.00630
# The standard deviation of team 1091  is 0.07940
#
# Team 1092
# The mean CGPA of team 1092  is 4.09
# The variance of team 1092  is 0.00484
# The standard deviation of team 1092  is 0.06957
#
# Team 1093
# The mean CGPA of team 1093  is 4.08
# The variance of team 1093  is 0.00534
# The standard deviation of team 1093  is 0.07310
#
# Team 1094
# The mean CGPA of team 1094  is 4.09
# The variance of team 1094  is 0.00394
# The standard deviation of team 1094  is 0.06280
#
# Team 1095
# The mean CGPA of team 1095  is 4.08
# The variance of team 1095  is 0.00362
# The standard deviation of team 1095  is 0.06013
#
# Team 1096
# The mean CGPA of team 1096  is 4.09
# The variance of team 1096  is 0.00182
# The standard deviation of team 1096  is 0.04261
#
# Team 1097
# The mean CGPA of team 1097  is 4.07
# The variance of team 1097  is 0.00114
# The standard deviation of team 1097  is 0.03382
#
# Team 1098
# The mean CGPA of team 1098  is 4.09
# The variance of team 1098  is 0.00810
# The standard deviation of team 1098  is 0.09002
#
# Team 1099
# The mean CGPA of team 1099  is 4.03
# The variance of team 1099  is 0.01386
# The standard deviation of team 1099  is 0.11771
#
# Team 1100
# The mean CGPA of team 1100  is 4.07
# The variance of team 1100  is 0.02490
# The standard deviation of team 1100  is 0.15781
#
# Team 1101
# The mean CGPA of team 1101  is 4.09
# The variance of team 1101  is 0.02814
# The standard deviation of team 1101  is 0.16774
#
# Team 1102
# The mean CGPA of team 1102  is 4.09
# The variance of team 1102  is 0.02450
# The standard deviation of team 1102  is 0.15654
#
# Team 1103
# The mean CGPA of team 1103  is 4.09
# The variance of team 1103  is 0.01136
# The standard deviation of team 1103  is 0.10658
#
# Team 1104
# The mean CGPA of team 1104  is 4.10
# The variance of team 1104  is 0.00556
# The standard deviation of team 1104  is 0.07457
#
# Team 1105
# The mean CGPA of team 1105  is 4.10
# The variance of team 1105  is 0.00410
# The standard deviation of team 1105  is 0.06406
#
# Team 1106
# The mean CGPA of team 1106  is 4.09
# The variance of team 1106  is 0.00330
# The standard deviation of team 1106  is 0.05741
#
# Team 1107
# The mean CGPA of team 1107  is 4.08
# The variance of team 1107  is 0.00270
# The standard deviation of team 1107  is 0.05192
#
# Team 1108
# The mean CGPA of team 1108  is 4.08
# The variance of team 1108  is 0.00134
# The standard deviation of team 1108  is 0.03666
#
# Team 1109
# The mean CGPA of team 1109  is 4.08
# The variance of team 1109  is 0.07618
# The standard deviation of team 1109  is 0.27600
#
# Team 1110
# The mean CGPA of team 1110  is 4.08
# The variance of team 1110  is 0.02332
# The standard deviation of team 1110  is 0.15271
#
# Team 1111
# The mean CGPA of team 1111  is 4.09
# The variance of team 1111  is 0.01368
# The standard deviation of team 1111  is 0.11696
#
# Team 1112
# The mean CGPA of team 1112  is 4.11
# The variance of team 1112  is 0.00710
# The standard deviation of team 1112  is 0.08429
#
# Team 1113
# The mean CGPA of team 1113  is 4.12
# The variance of team 1113  is 0.00714
# The standard deviation of team 1113  is 0.08452
#
# Team 1114
# The mean CGPA of team 1114  is 4.12
# The variance of team 1114  is 0.00398
# The standard deviation of team 1114  is 0.06312
#
# Team 1115
# The mean CGPA of team 1115  is 4.10
# The variance of team 1115  is 0.00280
# The standard deviation of team 1115  is 0.05292
#
# Team 1116
# The mean CGPA of team 1116  is 4.11
# The variance of team 1116  is 0.00190
# The standard deviation of team 1116  is 0.04354
#
# Team 1117
# The mean CGPA of team 1117  is 4.10
# The variance of team 1117  is 0.00174
# The standard deviation of team 1117  is 0.04176
#
# Team 1118
# The mean CGPA of team 1118  is 4.13
# The variance of team 1118  is 0.00710
# The standard deviation of team 1118  is 0.08424
#
# Team 1119
# The mean CGPA of team 1119  is 4.09
# The variance of team 1119  is 0.05518
# The standard deviation of team 1119  is 0.23490
#
# Team 1120
# The mean CGPA of team 1120  is 4.02
# The variance of team 1120  is 0.02742
# The standard deviation of team 1120  is 0.16558
#
# Team 1121
# The mean CGPA of team 1121  is 4.05
# The variance of team 1121  is 0.01902
# The standard deviation of team 1121  is 0.13793
#
# Team 1122
# The mean CGPA of team 1122  is 4.05
# The variance of team 1122  is 0.00966
# The standard deviation of team 1122  is 0.09831
#
# Team 1123
# The mean CGPA of team 1123  is 4.07
# The variance of team 1123  is 0.00698
# The standard deviation of team 1123  is 0.08352
#
# Team 1124
# The mean CGPA of team 1124  is 4.05
# The variance of team 1124  is 0.00546
# The standard deviation of team 1124  is 0.07386
#
# Team 1125
# The mean CGPA of team 1125  is 4.07
# The variance of team 1125  is 0.00502
# The standard deviation of team 1125  is 0.07082
#
# Team 1126
# The mean CGPA of team 1126  is 4.06
# The variance of team 1126  is 0.00426
# The standard deviation of team 1126  is 0.06530
#
# Team 1127
# The mean CGPA of team 1127  is 4.07
# The variance of team 1127  is 0.00194
# The standard deviation of team 1127  is 0.04400
#
# Team 1128
# The mean CGPA of team 1128  is 4.04
# The variance of team 1128  is 0.02732
# The standard deviation of team 1128  is 0.16529
#
# Team 1129
# The mean CGPA of team 1129  is 4.05
# The variance of team 1129  is 0.01412
# The standard deviation of team 1129  is 0.11883
#
# Team 1130
# The mean CGPA of team 1130  is 4.07
# The variance of team 1130  is 0.01422
# The standard deviation of team 1130  is 0.11923
#
# Team 1131
# The mean CGPA of team 1131  is 4.08
# The variance of team 1131  is 0.00906
# The standard deviation of team 1131  is 0.09516
#
# Team 1132
# The mean CGPA of team 1132  is 4.07
# The variance of team 1132  is 0.00566
# The standard deviation of team 1132  is 0.07521
#
# Team 1133
# The mean CGPA of team 1133  is 4.08
# The variance of team 1133  is 0.00294
# The standard deviation of team 1133  is 0.05426
#
# Team 1134
# The mean CGPA of team 1134  is 4.10
# The variance of team 1134  is 0.00582
# The standard deviation of team 1134  is 0.07632
#
# Team 1135
# The mean CGPA of team 1135  is 4.15
# The variance of team 1135  is 0.02894
# The standard deviation of team 1135  is 0.17011
#
# Team 1136
# The mean CGPA of team 1136  is 4.09
# The variance of team 1136  is 0.00468
# The standard deviation of team 1136  is 0.06841
#
# Team 1137
# The mean CGPA of team 1137  is 4.07
# The variance of team 1137  is 0.00218
# The standard deviation of team 1137  is 0.04665
#
# Team 1138
# The mean CGPA of team 1138  is 4.09
# The variance of team 1138  is 0.00134
# The standard deviation of team 1138  is 0.03666
#
# Team 1139
# The mean CGPA of team 1139  is 4.12
# The variance of team 1139  is 0.05702
# The standard deviation of team 1139  is 0.23878
#
# Team 1140
# The mean CGPA of team 1140  is 4.06
# The variance of team 1140  is 0.02058
# The standard deviation of team 1140  is 0.14347
#
# Team 1141
# The mean CGPA of team 1141  is 4.09
# The variance of team 1141  is 0.01534
# The standard deviation of team 1141  is 0.12384
#
# Team 1142
# The mean CGPA of team 1142  is 4.11
# The variance of team 1142  is 0.00618
# The standard deviation of team 1142  is 0.07864
#
# Team 1143
# The mean CGPA of team 1143  is 4.11
# The variance of team 1143  is 0.00902
# The standard deviation of team 1143  is 0.09495
#
# Team 1144
# The mean CGPA of team 1144  is 4.12
# The variance of team 1144  is 0.00478
# The standard deviation of team 1144  is 0.06911
#
# Team 1145
# The mean CGPA of team 1145  is 4.11
# The variance of team 1145  is 0.00326
# The standard deviation of team 1145  is 0.05706
#
# Team 1146
# The mean CGPA of team 1146  is 4.11
# The variance of team 1146  is 0.00322
# The standard deviation of team 1146  is 0.05671
#
# Team 1147
# The mean CGPA of team 1147  is 4.13
# The variance of team 1147  is 0.00772
# The standard deviation of team 1147  is 0.08786
#
# Team 1148
# The mean CGPA of team 1148  is 4.11
# The variance of team 1148  is 0.00362
# The standard deviation of team 1148  is 0.06013
#
# Team 1149
# The mean CGPA of team 1149  is 4.00
# The variance of team 1149  is 0.01414
# The standard deviation of team 1149  is 0.11889
#
# Team 1150
# The mean CGPA of team 1150  is 4.12
# The variance of team 1150  is 0.04838
# The standard deviation of team 1150  is 0.21996
#
# Team 1151
# The mean CGPA of team 1151  is 4.13
# The variance of team 1151  is 0.01642
# The standard deviation of team 1151  is 0.12816
#
# Team 1152
# The mean CGPA of team 1152  is 4.12
# The variance of team 1152  is 0.01230
# The standard deviation of team 1152  is 0.11089
#
# Team 1153
# The mean CGPA of team 1153  is 4.11
# The variance of team 1153  is 0.01204
# The standard deviation of team 1153  is 0.10973
#
# Team 1154
# The mean CGPA of team 1154  is 4.10
# The variance of team 1154  is 0.00540
# The standard deviation of team 1154  is 0.07348
#
# Team 1155
# The mean CGPA of team 1155  is 4.10
# The variance of team 1155  is 0.00434
# The standard deviation of team 1155  is 0.06591
#
# Team 1156
# The mean CGPA of team 1156  is 4.06
# The variance of team 1156  is 0.00154
# The standard deviation of team 1156  is 0.03929
#
# Team 1157
# The mean CGPA of team 1157  is 4.09
# The variance of team 1157  is 0.00282
# The standard deviation of team 1157  is 0.05314
#
# Team 1158
# The mean CGPA of team 1158  is 4.15
# The variance of team 1158  is 0.03462
# The standard deviation of team 1158  is 0.18605
#
# Team 1159
# The mean CGPA of team 1159  is 4.02
# The variance of team 1159  is 0.02570
# The standard deviation of team 1159  is 0.16030
#
# Team 1160
# The mean CGPA of team 1160  is 4.09
# The variance of team 1160  is 0.01578
# The standard deviation of team 1160  is 0.12560
#
# Team 1161
# The mean CGPA of team 1161  is 4.11
# The variance of team 1161  is 0.01886
# The standard deviation of team 1161  is 0.13732
#
# Team 1162
# The mean CGPA of team 1162  is 4.10
# The variance of team 1162  is 0.01018
# The standard deviation of team 1162  is 0.10092
#
# Team 1163
# The mean CGPA of team 1163  is 4.11
# The variance of team 1163  is 0.00694
# The standard deviation of team 1163  is 0.08328
#
# Team 1164
# The mean CGPA of team 1164  is 4.11
# The variance of team 1164  is 0.00542
# The standard deviation of team 1164  is 0.07359
#
# Team 1165
# The mean CGPA of team 1165  is 4.11
# The variance of team 1165  is 0.00442
# The standard deviation of team 1165  is 0.06645
#
# Team 1166
# The mean CGPA of team 1166  is 4.12
# The variance of team 1166  is 0.00354
# The standard deviation of team 1166  is 0.05953
#
# Team 1167
# The mean CGPA of team 1167  is 4.07
# The variance of team 1167  is 0.00086
# The standard deviation of team 1167  is 0.02926
#
# Team 1168
# The mean CGPA of team 1168  is 4.11
# The variance of team 1168  is 0.00964
# The standard deviation of team 1168  is 0.09818
#
# Team 1169
# The mean CGPA of team 1169  is 4.16
# The variance of team 1169  is 0.10038
# The standard deviation of team 1169  is 0.31683
#
# Team 1170
# The mean CGPA of team 1170  is 4.09
# The variance of team 1170  is 0.02290
# The standard deviation of team 1170  is 0.15131
#
# Team 1171
# The mean CGPA of team 1171  is 4.08
# The variance of team 1171  is 0.02202
# The standard deviation of team 1171  is 0.14838
#
# Team 1172
# The mean CGPA of team 1172  is 4.12
# The variance of team 1172  is 0.01122
# The standard deviation of team 1172  is 0.10591
#
# Team 1173
# The mean CGPA of team 1173  is 4.10
# The variance of team 1173  is 0.00692
# The standard deviation of team 1173  is 0.08319
#
# Team 1174
# The mean CGPA of team 1174  is 4.11
# The variance of team 1174  is 0.00554
# The standard deviation of team 1174  is 0.07446
#
# Team 1175
# The mean CGPA of team 1175  is 4.10
# The variance of team 1175  is 0.00278
# The standard deviation of team 1175  is 0.05269
#
# Team 1176
# The mean CGPA of team 1176  is 4.14
# The variance of team 1176  is 0.01234
# The standard deviation of team 1176  is 0.11110
#
# Team 1177
# The mean CGPA of team 1177  is 4.09
# The variance of team 1177  is 0.00128
# The standard deviation of team 1177  is 0.03578
#
# Team 1178
# The mean CGPA of team 1178  is 4.21
# The variance of team 1178  is 0.02686
# The standard deviation of team 1178  is 0.16390
#
# Team 1179
# The mean CGPA of team 1179  is 4.03
# The variance of team 1179  is 0.02378
# The standard deviation of team 1179  is 0.15419
#
# Team 1180
# The mean CGPA of team 1180  is 4.07
# The variance of team 1180  is 0.02488
# The standard deviation of team 1180  is 0.15773
#
# Team 1181
# The mean CGPA of team 1181  is 4.08
# The variance of team 1181  is 0.01410
# The standard deviation of team 1181  is 0.11873
#
# Team 1182
# The mean CGPA of team 1182  is 4.11
# The variance of team 1182  is 0.00890
# The standard deviation of team 1182  is 0.09436
#
# Team 1183
# The mean CGPA of team 1183  is 4.12
# The variance of team 1183  is 0.00402
# The standard deviation of team 1183  is 0.06344
#
# Team 1184
# The mean CGPA of team 1184  is 4.11
# The variance of team 1184  is 0.00330
# The standard deviation of team 1184  is 0.05748
#
# Team 1185
# The mean CGPA of team 1185  is 4.10
# The variance of team 1185  is 0.00234
# The standard deviation of team 1185  is 0.04841
#
# Team 1186
# The mean CGPA of team 1186  is 4.13
# The variance of team 1186  is 0.00292
# The standard deviation of team 1186  is 0.05404
#
# Team 1187
# The mean CGPA of team 1187  is 4.11
# The variance of team 1187  is 0.00126
# The standard deviation of team 1187  is 0.03544
#
# Team 1188
# The mean CGPA of team 1188  is 4.10
# The variance of team 1188  is 0.00182
# The standard deviation of team 1188  is 0.04261
#
# Team 1189
# The mean CGPA of team 1189  is 4.05
# The variance of team 1189  is 0.03422
# The standard deviation of team 1189  is 0.18498
#
# Team 1190
# The mean CGPA of team 1190  is 4.10
# The variance of team 1190  is 0.01300
# The standard deviation of team 1190  is 0.11402
#
# Team 1191
# The mean CGPA of team 1191  is 4.17
# The variance of team 1191  is 0.03654
# The standard deviation of team 1191  is 0.19116
#
# Team 1192
# The mean CGPA of team 1192  is 4.12
# The variance of team 1192  is 0.00922
# The standard deviation of team 1192  is 0.09600
#
# Team 1193
# The mean CGPA of team 1193  is 4.11
# The variance of team 1193  is 0.00616
# The standard deviation of team 1193  is 0.07849
#
# Team 1194
# The mean CGPA of team 1194  is 4.11
# The variance of team 1194  is 0.00402
# The standard deviation of team 1194  is 0.06344
#
# Team 1195
# The mean CGPA of team 1195  is 4.12
# The variance of team 1195  is 0.00514
# The standard deviation of team 1195  is 0.07172
#
# Team 1196
# The mean CGPA of team 1196  is 4.09
# The variance of team 1196  is 0.00250
# The standard deviation of team 1196  is 0.04996
#
# Team 1197
# The mean CGPA of team 1197  is 4.09
# The variance of team 1197  is 0.00134
# The standard deviation of team 1197  is 0.03666
#
# Team 1198
# The mean CGPA of team 1198  is 4.18
# The variance of team 1198  is 0.03866
# The standard deviation of team 1198  is 0.19661
#
# Team 1199
# The mean CGPA of team 1199  is 4.12
# The variance of team 1199  is 0.04496
# The standard deviation of team 1199  is 0.21204
#
# The mean of the population is 4.09
# Population median is: 4.086
# The standard deviation of the population is 0.03126
# {'m2f3': 731, 'm3f2': 411, 'm1f4': 56, 'm4f1': 2}
