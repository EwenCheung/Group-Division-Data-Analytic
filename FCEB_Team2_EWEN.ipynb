# %% [markdown]
# # Team Allocation Simulator #
# by Ewen, Wei Hao, Yibin, Youde, Shawn

# %% [markdown]
# ## Resources provided ##
# We have received a CSV file 'records.csv', which have given us the following information of each of the 6000 students
# 1. The students' name
# 2. The students' ID
# 3. The students' tutorial group
# 4. The students' gender
# 5. The students' school affiliation
# 6. The students' current CGPA

# %% [markdown]
# ## Requirements ##
# We are to develop an application that does the following
# 1. Organize students into teams of five
# 2. Team members should be in the same tutorial group
# 3. No team should have a majority of students from the same school
# 4. No team should have a majority of students of the same gender
# 5. No team should not consist predominantly of students with very high or very low CGPAs

# %% [markdown]
# ## Thought Process for Team Allocation Simulator ##
#
# To develop a robust and efficient Team Allocation Simulator, we adopted the cornerstones of Critical Thinking for Computing. This approach provided a structured guide for analyzing the problem and creating an effective solution.
#
# ### Decomposition ###
# The first step was to decompose the complex problem into manageable sub-tasks. Considering the various requirements for team formation, we evaluated different approaches for grouping students and identified the following optimal process:
#
# - Split the students by tutorial groups.
# - Within each tutorial group, split the students by gender.
# - Sort students within each gender group by CGPA.
# - Select students according to the determined selection strategy.
#
# By breaking the problem into these steps, we were able to develop a clear path for implementation, ensuring each requirement is addressed methodically.
#
# ### Abstraction ###
# To simplify the extraction and management of student information, we chose to represent each student’s data as a dictionary. These dictionaries are stored within lists to facilitate sequential, mutable data access. This decision was based on the need for flexible data structures that allow easy data manipulation and retrieval.
#
# ### Patterns ###
# We anticipated that the student selection process would be the most sophisticated part of the algorithm. Thus, we analyzed the potential patterns within this procedure to simplify and optimize it.
#
# Methodology for Student Selection:
#
# 1. Start by selecting the student with the lowest CGPA from the gender group with more students.
# 2. Alternate by choosing the student with the highest CGPA from the opposite gender.
# 3. Continue with the student who has the median CGPA from the initial gender group.
# 4. Repeat the process, ensuring a 3:2 gender ratio and varied school affiliations.
# 5. This approach ensures that each group has balanced CGPA levels, gender diversity, and students from different schools. The team composition pattern follows the order:
#
# ```
# [LowestFemale, HighestMale, MedianFemale, LowestMale, HighestFemale]
# ```
# Handling School Affiliation Duplicates: If a selected student shares the same school affiliation as another team member, the algorithm selects the next-best candidate (e.g., the second lowest/highest CGPA). This adjustment continues until a suitable candidate is found.
#
# Indexing Pattern:
#
# The indexes used for selection are
# ```
# [0, -1, len(sorted_student[gender_index]) // 2]
# ```
# corresponding to the lowest, highest, and median positions in the gender group.
# Changes in the index are tracked using index_changes
# ```
# [+1, -1, +1]
# ```
#  and a variable cycles through the indexes to maintain the selection pattern.
#
# ### Algorithms ###
# To build the Team Allocation Simulator, we outlined the following procedural steps:
#
# 1. Develop a CSV reading function: Extract and organize student data from the CSV file into dictionaries within lists.
# 2. Create a function to sort students by tutorial group: This ensures that students are initially grouped according to their assigned tutorial.
# 3. Implement a sorting function by gender and CGPA: This function organizes students within their tutorial groups into separate lists based on gender and then sorts them by CGPA.
# 4. Develop a team allocation function: This function distributes students into balanced teams while considering gender ratio, CGPA distribution, and school diversity.
#
# This structured workflow is designed to meet all project requirements and maintain efficiency in forming teams.
#
# ### Conclusion ###
# By following these steps, we believe our approach effectively balances the criteria of CGPA, gender, and school diversity in each team. The use of dictionaries and lists simplifies data handling, while the patterned selection process ensures a logical and fair distribution of students. The thought process outlined above demonstrates how decomposition, abstraction, pattern recognition, and algorithmic planning were integral to our project’s development.

# %% [markdown]
# ## Function to Read CSV File ##
# We will first create a function to read the CSV. It will then add each student's information (those listed above) into a dictionary. The dictionaries of the students' details will be stored in a list.

# %% [markdown]
# ### Pseudocode for read_student_data ###
#
# <font color='32CD32'>FUNCTION</font> read_student_data(file_path):
# <br>&emsp;<font color='32CD32'>INITIALISE</font> students_list as an empty list
# <br>
# <br>&emsp;<font color='32CD32'>OPEN</font> file at file_path in read mode AS file
# <br>&emsp;&emsp;<font color='32CD32'>READ</font> the first line and <font color='32CD32'>SPLIT</font> it by commas, <font color='32CD32'>ASSIGN</font> it to headers
# <br>
# <br>&emsp;&emsp;<font color='32CD32'>FOR EACH</font> line <font color ='32CD32'>IN</font> file:
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>INITIALISE</font> student as an empty dictionary
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>SPLIT</font> line by commas, <font color='32CD32'>ASSIGN</font> it to values
# <br>
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>FOR EACH</font> index i and header IN headers:
# <br>&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>SET</font> student[header] to values[i]
# <br>&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>IF</font> header is equal to "CGPA":
# <br>&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>CONVERT</font> class of value to float
# <br>
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> student to students_list
# <br>
# <br>&emsp;<font color='32CD32'>RETURN</font> students_list

# %%
from IPython import display
display.Image("assets/Flowchart_read student data.png")

# %% [markdown]
# ## Function to Sort Students By Tutorial Groups ##
# Since the members of each group should be in the same tutorial group, we decided that it would be more efficient to meet this requirement first. In this function, we have split the dictionaries of each student to lists of their own respective tutorial groups.

# %% [markdown]
# ### Pseudocode for Function, pick_student ###
#
# <font color='32CD32'>FUNCTION</font> pick_student(all_students, tut_grp):
# <br>&emsp;<font color='32CD32'>INITIALISE</font> students_list as an empty list
# <br>
# <br>&emsp;<font color='32CD32'>FOR EACH</font> student <font color='32CD32'>IN</font> all_students
# <br>&emsp;&emsp;<font color='32CD32'>IF</font> student's 'Tutorial Group' is equal to 'G-{tut_grp}'
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> student to students_list
# <br>
# <br>&emsp;<font color='32CD32'>RETURN</font> students_list

# %%
display.Image("assets/Flowchart_pick_student.png")

# %% [markdown]
# ## Function to form a team of 5 students ##
# We will now design a function to form a team of 5 students. This function will have 2 parameters, a list with male students with their CGPA sorted, as well as a list with female students with their CGPA sorted. We will implement another function later for the sorting of gender and CGPA.
#
# For this function, we will be primarily be focussing on how we would ensure teams would have students with different school affliations, and how we would balance out the CGPA and gender in each group. We would heavily use pattern recognition to build this function.
#
# We will first pick a student with the lowest CGPA amongst gender X, where gender X has more students. We will then select a student of opposite gender with the highest CGPA. The next student selected would have the median CGPA amongst gender X. The first step repeats again. This effectively allows for a good mix of CGPA in a group, while ensuring there will be a 3:2 ratio for the gender and that students have different school affiliations. The team composition will look something like this:
# ```
# LowestFemale, HighestMale, MedianFemale, LowestMale, HighestFemale
# ```
#
# In the event where the student selected has the same school affliation as another student already in the group, the function will choose the next best alternative
# > If the next female student with the lowest CGPA has the same school affiliation with another student in the group, the second lowest CGPA female student will be selected instead. If the second lowest CGPA female student also has same school affilation with another student in the group, the third lowest CGPA female student will be selected, and so on.
#
# However, to ensure that the mean of CGPA does not differ alot between teams, we would stop the changing of index after it increases by 5. This also ensures that the mixture of CGPA will not affect other teams as well.
#
# Most tutorial groups will not be in a perfect 3:2 gender ratio for us to distribute them evenly. Hence, we have devised a way to ensure that 4:1 teams will be formed instead until the 3:2 ratio in the tutorial groups is formed. The remaining students will then be able to form 3:2 teams.
# > If there are 35 female and 15 male students in the tutorial group, 5 4:1 teams will be formed first. the remaining 5 teams will have a ratio of 3:2.

# %% [markdown]
# ### Pseudocode for Function ###
# <font color='32CD32'>FUNCTION</font> diverse_team(sorted_student_more, sorted_student_less)<br>
# &emsp;<font color='32CD32'>INITIALISE</font> team <font color='32CD32'>AS</font> an empty list<br>
# &emsp;<font color='32CD32'>SET</font> i <font color='32CD32'>TO</font> 0<br>
# &emsp;<font color='32CD32'>INITIALISE</font> sorted_student <font color='32CD32'>AS</font> a list containing sorted_student_more and sorted_student_less<br>
#
# &emsp;<font color='32CD32'>SET</font> gender_run_two_time <font color='32CD32'>TO</font> FALSE<br>
# &emsp;<font color='32CD32'>SET</font> next_gender_same <font color='32CD32'>TO</font> FALSE<br>
# &emsp;<font color='32CD32'>IF</font> (length of sorted_student_more - length of sorted_student_less >= 10-team_index) <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;<font color='32CD32'>SET</font> gender_run_two_time <font color='32CD32'>TO</font> TRUE
#
# &emsp;<font color='32CD32'>SET</font> gender_index <font color='32CD32'>TO</font> 0<br>
#
# &emsp;<font color='32CD32'>WHILE</font> (length of team < 5) <font color='32CD32'>AND</font> (sorted_student[0] <font color='32CD32'>OR</font> sorted_student[1])<br>
# &emsp;&emsp;<font color='32CD32'>SET</font> index_changes <font color='32CD32'>TO</font> [+1, -1, +1]<br>
# &emsp;&emsp;<font color='32CD32'>SET</font> pick_index <font color='32CD32'>TO</font> [0, -1, length of sorted_student[gender_index] // 2]<br>
#
# &emsp;&emsp;<font color='32CD32'>WHILE</font> TRUE<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>IF</font> sorted_student[gender_index] is empty <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>BREAK</font><br>
#
# &emsp;&emsp;&emsp;<font color='32CD32'>IF</font> (index_changes[i] >= 0) <font color='32CD32'>AND</font> (pick_index[i] + index_changes[i] < length of sorted_student[gender_index]) <font color='32CD32'>AND</font> index_changes[i] <= 5 <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>IF</font> sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] <font color='32CD32'>NOT</font> <font color='32CD32'>IN</font> student['School'] <font color='32CD32'>FOR</font> student <font color='32CD32'>IN</font> team] <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> sorted_student[gender_index].<font color='32CD32'>POP</font>(pick_index[i] + index_changes[i]) <font color='32CD32'>TO</font> team<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>BREAK</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>ELSE</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>INCREMENT</font> index_changes[i] <font color='32CD32'>BY</font> 1<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>ELSE IF</font> (index_changes[i] < 0) <font color='32CD32'>AND</font> (ABS(pick_index[i] + index_changes[i]) <= length of sorted_student[gender_index]) <font color='32CD32'>AND</font> (ABS(index_changes[i]) <= 5) <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>IF</font> (sorted_student[gender_index][pick_index[i] + index_changes[i]]['School']) <font color='32CD32'>NOT</font> <font color='32CD32'>IN</font> [student['School'] <font color='32CD32'>FOR</font> student <font color='32CD32'>IN</font> team] <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> sorted_student[gender_index].<font color='32CD32'>POP</font>(pick_index[i] + index_changes[i]) <font color='32CD32'>TO</font> team<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>BREAK</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>ELSE</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>DECREMENT</font> index_changes[i] <font color='32CD32'>BY</font> 1<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>ELSE</font><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;<font color='32CD32'>APPEND</font> sorted_student[gender_index].<font color='32CD32'>POP</font>(pick_index[i]) <font color='32CD32'>TO</font> team<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;BREAK<br>
#
# &emsp;&emsp;<font color='32CD32'>INCREMENT</font> i <font color='32CD32'>BY</font> 1
#
# &emsp;&emsp;<font color='32CD32'>IF</font> <font color='32CD32'>NOT</font> next_gender_same <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>INCREMENT</font> gender_index <font color='32CD32'>BY</font> 1
#
# &emsp;&emsp;<font color='32CD32'>ELSE IF</font> next_gender_same <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> next_gender_same <font color='32CD32'>TO</font> FALSE
#
# &emsp;&emsp;<font color='32CD32'>IF</font> i is greater than 2 <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> i <font color='32CD32'>TO</font> 0
#
# &emsp;&emsp;<font color='32CD32'>IF</font> gender_index is greater than 1 <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> gender_index <font color='32CD32'>TO</font> 0
#
# &emsp;&emsp;<font color='32CD32'>IF</font> gender_run_two_time <font color='32CD32'>THEN</font><br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> gender_index <font color='32CD32'>TO</font> 0<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> gender_run_two_time <font color='32CD32'>TO</font> TRUE<br>
# &emsp;&emsp;&emsp;<font color='32CD32'>SET</font> next_gender_same <font color='32CD32'>TO</font> TRUE
#
# &emsp;<font color='32CD32'>RETURN</font> team<br>

# %%
display.Image("assets/Flowchart_diverse_teams.png")

# %% [markdown]
# ## Function to Sort by Gender and CGPA (Division into team) ##
# This function would split students by their gender into 2 lists. Each list will then be sorted by CGPA. The function will determine whether the tutorial group has more males or females, and the lists produced will then be used as diverse_team parameters.
# The function will return the groups formed in lists, nested in a whole list.

# %% [markdown]
# ### Pseudocode for division_into_team ###
#
# <font color='32CD32'>FUNCTION</font> division_into_team(students_list):
# <br>&emsp;<font color='32CD32'>INITIALISE</font> male_students as list of students from students_list where 'Gender' is 'Male'
# <br>&emsp;<font color='32CD32'>INITIALISE</font> female_students as list of students from students_list where 'Gender' is 'Female'
# <br>&emsp;<font color='32CD32'>INITIALISE</font> teams as a list of empty lists, with one list for every 5 students in students_list
# <br>&emsp;<font color='32CD32'>INITIALISE</font> team_index to 0
#
# <br>&emsp;<font color='32CD32'>SORT</font> male_students by 'CGPA' in ascending order, <font color='32CD32'>ASSIGN</font> to male_sorted_students
# <br>&emsp;<font color='32CD32'>SORT</font> female_students by 'CGPA' in ascending order, <font color='32CD32'>ASSIGN</font> to female_sorted_students
#
# <br>&emsp;<font color='32CD32'>WHILE</font> team_index < length of teams:
# <br>&emsp;&emsp;<font color='32CD32'>IF</font> length of male_sorted_students >= length of female_sorted_students:
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>SET</font> teams[team_index] to result of calling diverse_team with male_sorted_students, female_sorted_students, and team_index
# <br>&emsp;&emsp;<font color='32CD32'>ELSE</font>:
# <br>&emsp;&emsp;&emsp;<font color='32CD32'>SET</font> teams[team_index] to result of calling diverse_team with female_sorted_students, male_sorted_students, and team_index
#
# <br>&emsp;&emsp;<font color='32CD32'>INCREMENT</font> team_index by 1
#
# <br><font color='32CD32'>RETURN</font> teams

# %%
display.Image("assets/Flowchart_division into team.png")

# %% [markdown]
# ## Main Code ##

# %% [markdown]
# ### Pseudocode for the Main ###
# <br><font color='32CD32'>INITIALISE</font> students, by reading student data from 'records.csv'
# <br><font color='32CD32'>INITIALISE</font> group_division, as an empty list
# <br><font color='32CD32'>INITIALISE</font> tutorial_grp, to 1 (starting tutorial group)
#
# <br><font color='32CD32'>WHILE</font> (tutorial_grp) is less than or equal to 120
# <br>&emsp;&emsp;<font color='32CD32'>CALL</font> pick_student(students, tutorial_grp)
# <br>&emsp;&emsp;<font color='32CD32'>CALL</font> division_into_team with the picked students
# <br>&emsp;&emsp;<font color='32CD32'>EXTEND</font> group_division with the resulting teams
# <br>&emsp;&emsp;<font color='32CD32'>INCREMENT</font> tutorial_grp by 1
#
# <br><font color='32CD32'>WITH </font>open file "FCEB_Team2_EWEN.csv" in **write** mode as variable 'f'.
# <br><font color='32CD32'>FOR EACH</font> 'i, x' in group_division (where 'i' is the group index and 'x' is the group list):
# <br>&emsp;&emsp;<font color='32CD32'>Write</font> "Group {i}" to the file.
# <br><font color='32CD32'>FOR EACH</font> 'j' in x (where 'j' is each student in the group):
# <br>&emsp;&emsp;<font color='32CD32'>Create</font> string 'l' with 'Student ID', 'School', 'CGPA', and 'Gender' of the student, followed by a newline.
# <br>&emsp;&emsp;<font color='32CD32'>Write</font> 'l' to the file.
# <br><font color='32CD32'>Close</font> the file. (Automatically closed due to 'with'.)

# %%
display.Image("assets/Flowchart_Main Code.png")

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # Visualisation of code #

# %%
from IPython import display
display.Image("assets/dataset_school.jpg")

# %% [markdown]
# ### School Representation ###

# %%
display.Image("assets/school_representation.png")

# %% [markdown]
# ### Gender Representation ###

# %%
display.Image("assets/dataset_gender.jpg")

# %%
display.Image("assets/gender_representation.png")

# %% [markdown]
# ### Histogram for Mean CGPA Per Team ###

# %%
display.Image("assets/Histogram_for_Mean_CGPA_Per_Team.png")

# %% [markdown]
# ### Histogram_for_Standard_Deviation_Per_Team.png ###

# %%
display.Image("assets/Histogram_for_Standard_Deviation_Per_Team.png")

# %% [markdown]
# ### Histogram_of_Z-Scores_for_Mean_CGPA_per_Team ###

# %%
display.Image("assets/Histogram_of_Z-Scores_for_Mean_CGPA_per_Team.png")

# %% [markdown]
# ### Z-Score Interpretation:
# Apply the Empirical Rule (68-95-99.7 Rule):
# - 68% of the z-scores should fall within 1 standard deviation of the mean (z-scores between -1 and 1)
# - 95% of the z-scores should fall within 2 standard deviations of the mean (z-scores between -2 and 2)
# - 99.7% of the z-scores should fall within 3 standard deviations of the mean (z-scores between -3 and 3)
#
# For 1 standard deviation:
# $$\frac{470 + 359}{1200} \approx 0.69\$$
#
# For 2 standard deviations:
# $$\frac{470 + 359 + 181 + 93 + 33}{1200} \approx 0.95\$$
#
# For 3 standard deviations:
# $$\frac{470 + 359 + 181 + 93 + 33 + 27 + 15 + 5}{1200} \approx 0.99\$$

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # Code #
# We had code 2 version, one is the basic code, another one is the advanced code where user can choose number of student in a group

# %% [markdown]
# ## Basic Code

# %%
def read_student_data(file_path):
    """Read data from csv file and return"""
    students_list = []
    with open(file_path, mode='r') as file:
        headers = file.readline().strip().split(",")
        for line in file:
            student = {}
            values = line.strip().split(",")
            for i, header in enumerate(headers):
                student[header.strip()] = values[i].strip()
                if header.strip() == "CGPA":
                    student[header.strip()] = float(student[header.strip()])

            students_list.append(student)

    return students_list


def pick_student(all_students, tut_grp):
    """pick student out from the tutorial group"""
    students_list = []

    for student in all_students:
        if student['Tutorial Group'] == f'G-{tut_grp}':
            students_list.append(student)

    return students_list


def diverse_team(sorted_student_more, sorted_student_less, team_index):  # index(0,-1,or middle)
    team = []
    i = 0  # round
    sorted_student = [sorted_student_more, sorted_student_less]

    gender_run_two_time = False
    next_gender_same = False
    if len(sorted_student_more) - len(sorted_student_less) >= 10-team_index:
        gender_run_two_time = True

    gender_index = 0

    while len(team) < 5 and (sorted_student[0] or sorted_student[1]):  # add student into team when teams is not full
        index_changes = [+1, -1, +1]
        pick_index = [0, -1, len(sorted_student[gender_index]) // 2]
        while True:
            if not sorted_student[gender_index]:
                break
            elif index_changes[i] >= 0 and pick_index[i] + index_changes[i] < len(sorted_student[gender_index]) and index_changes[
                i] <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] += 1
            elif index_changes[i] < 0 and abs(pick_index[i] + index_changes[i]) <= len(sorted_student[gender_index]) and abs(
                    index_changes[i]) <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] -= 1
            else:
                # If the index exceeds the list length, reset index_changes or break
                team.append(sorted_student[gender_index].pop(pick_index[i]))
                break

        i += 1
        if not next_gender_same:
            gender_index += 1
        elif next_gender_same:
            next_gender_same = False
        if i > 2:
            i = 0
        if gender_index > 1:
            gender_index = 0

        if gender_run_two_time:
            gender_index = 0
            gender_run_two_time = False
            next_gender_same = True

    return team


def division_into_team(students_list):
    """Divides student from student_list into group of 5 with balance of cgpa and gender, and diverse of school"""
    # Separate male and female students into two lists
    male_students = [student for student in students_list if student['Gender'] == 'Male']
    female_students = [student for student in students_list if student['Gender'] == 'Female']

    # Sort the male and female students by CGPA
    male_sorted_students = sorted(male_students, key=lambda student: student['CGPA'])
    female_sorted_students = sorted(female_students, key=lambda student: student['CGPA'])

    teams = [[] for _ in range(len(students_list) // 5)]
    team_index = 0

    while team_index < len(teams):  # while haven't added student into all teams
        if len(male_sorted_students) >= len(female_sorted_students):  # if remain male student more than remain female student
            teams[team_index] = diverse_team(male_sorted_students, female_sorted_students, team_index)

        else:  # if remain male student less than remain female student
            teams[team_index] = diverse_team(female_sorted_students, male_sorted_students, team_index)

        team_index += 1

    return teams


students = read_student_data('records.csv')
group_division = []
tutorial_grp = 1

while tutorial_grp <= 120:
    group_division.extend(division_into_team(pick_student(students, tutorial_grp)))
    tutorial_grp += 1
    
with open("FCEB_Team2_EWEN.csv", mode="w") as f:
    f.write("Tutorial Group,Group Number,Student ID,School,Name,Gender,CGPA\n")

    for group_num, group in enumerate(group_division,start=1):
        for student in group:
            l = f"{student['Tutorial Group']},{group_num},{student['Student ID']},{student['School']},{student['Name']},{student['Gender']},{student['CGPA']}\n"
            f.write(l)

# %% [markdown]
# <br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Advanced Code ##

# %%
from ipywidgets import IntSlider, interact


def read_student_data(file_path):
    """Read data from csv file and return"""
    students_list = []
    with open(file_path, mode='r') as file:
        headers = file.readline().strip().split(",")
        for line in file:
            student = {}
            values = line.strip().split(",")
            for i, header in enumerate(headers):
                student[header.strip()] = values[i].strip()
                if header.strip() == "CGPA":
                    student[header.strip()] = float(student[header.strip()])

            students_list.append(student)

    return students_list


def pick_student(all_students, tut_grp):
    """pick student out from the tutorial group"""
    students_list = []

    for student in all_students:
        if student['Tutorial Group'] == f'G-{tut_grp}':
            students_list.append(student)

    return students_list


def diverse_team(size_team, sorted_student_more, sorted_student_less,team_index,len_team):  # size of team, index(0,-1,or middle)
    team = []
    i = 0  # round
    sorted_student = [sorted_student_more, sorted_student_less]

    gender_run_two_time = False
    next_gender_same = False
    if (size_team%2 == 0) or len(sorted_student_more) - len(sorted_student_less) >= ((((size_team//2)+1)*len_team) -((size_team//2)*len_team))-team_index:
        gender_run_two_time = True

    gender_index = 0

    while len(team) < size_team and (sorted_student[0] or sorted_student[1]):  # add student into team when teams is not full
        index_changes = [+1, -1, +1]
        pick_index = [0, -1, len(sorted_student[gender_index]) // 2]
        while True:
            if not sorted_student[gender_index]:
                break
            elif index_changes[i] >= 0 and pick_index[i] + index_changes[i] < len(sorted_student[gender_index]) and index_changes[
                i] <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] += 1
            elif index_changes[i] < 0 and abs(pick_index[i] + index_changes[i]) <= len(sorted_student[gender_index]) and abs(
                    index_changes[i]) <= 5:
                # Check if school is not in the team
                if sorted_student[gender_index][pick_index[i] + index_changes[i]]['School'] not in [student['School'] for student in
                                                                                                    team]:
                    team.append(sorted_student[gender_index].pop(pick_index[i] + index_changes[i]))
                    break
                else:
                    index_changes[i] -= 1
            else:
                # If the index exceeds the list length, reset index_changes or break
                team.append(sorted_student[gender_index].pop(pick_index[i]))
                break

        i += 1
        if not next_gender_same:
            gender_index += 1
        elif next_gender_same:
            next_gender_same = False
        if i > 2:
            i = 0
        if gender_index > 1:
            gender_index = 0

        if gender_run_two_time:
            gender_index = 0
            gender_run_two_time = False
            next_gender_same = True

    return team


def division_into_team(students_list, size):
    """Divides student from student_list into group of size with balance of cgpa and gender, and diverse of school"""
    # Separate male and female students into two lists
    male_students = [student for student in students_list if student['Gender'] == 'Male']
    female_students = [student for student in students_list if student['Gender'] == 'Female']

    # Sort the male and female students by CGPA
    male_sorted_students = sorted(male_students, key=lambda student: student['CGPA'])
    female_sorted_students = sorted(female_students, key=lambda student: student['CGPA'])

    teams = [[] for _ in range(len(students_list) // size)]
    team_index = 0

    while team_index < len(teams):  # while haven't added student into all teams
        if len(male_sorted_students) >= len(female_sorted_students):  # if remain male student more than remain female student
            teams[team_index] = diverse_team(size, male_sorted_students, female_sorted_students,team_index,len(teams))

        else:  # if remain male student less than remain female student
            teams[team_index] = diverse_team(size, female_sorted_students, male_sorted_students,team_index,len(teams))

        team_index += 1

    first_run = True
    while male_sorted_students or female_sorted_students:
        for team in teams:
            male = sum(1 for student in team if student['Gender'] == 'Male')
            female = sum(1 for student in team if student['Gender'] == 'Female')

            # Handle male students first
            if male_sorted_students:
                if male > female:
                    continue
                elif female > male:
                    team.append(male_sorted_students.pop(0))
                    continue
                elif not first_run and male - female < 2:
                    team.append(male_sorted_students.pop(0))
                    continue

            # Handle female students
            if female_sorted_students:
                if male > female:
                    team.append(female_sorted_students.pop(0))
                    continue
                elif female > male:
                    continue
                elif not first_run and female - male < 2:
                    team.append(female_sorted_students.pop(0))
                    continue

        if not first_run:
            break

        # Mark the first run complete
        first_run = False

    return teams


def main(team_size):
    global group_division
    students = read_student_data('records.csv')
    group_division = []
    tutorial_grp = 1

    while tutorial_grp <= 120:
        group_division.extend(division_into_team(pick_student(students, tutorial_grp), team_size))
        tutorial_grp += 1

    with open("FCEB_Team2_EWEN_Advanced.csv", mode="w") as f:
        f.write("Tutorial Group,Group Number,Student ID,School,Name,Gender,CGPA\n")
    
        for group_num, group in enumerate(group_division,start=1):
            for student in group:
                l = f"{student['Tutorial Group']},{group_num},{student['Student ID']},{student['School']},{student['Name']},{student['Gender']},{student['CGPA']}\n"
                f.write(l)
        
team_size_slider = IntSlider(value=5,min=4,max=10,step=1,description="Team Size")

interact(main,team_size = team_size_slider)
# Out:
# interactive(children=(IntSlider(value=5, description='Team Size', max=10, min=4), Output()), _dom_classes=('wi…
# <function __main__.main(team_size)>

# %% [markdown]
# <br><br><br><br><br><br>

# %% [markdown]
# # Matplotlib Part to Visualise Code #

# %%
import matplotlib.pyplot as plt
import os


def visualize_data(group_division):
    all_sd = []
    all_mean = []
    compiled_z_score = []
    compiled_gender = []
    unique_school_counts = []

    for i, x in enumerate(group_division):
        print(f"Team {i}")
        total_cgpa = 0
        ind_cgpa = []
        ind_gender = []
        ind_school = []
        for j in x:
            total_cgpa += j["CGPA"]
            ind_cgpa.append(j["CGPA"])
            ind_gender.append(j["Gender"])
            ind_school.append(j["School"])

        # for categorisation of gender
        compiled_gender.append(ind_gender)

        # for categorisation for diverse sch representation
        schools_in_team = set(sch for sch in ind_school)  # Use a set to get unique schools
        unique_school_counts.append(len(schools_in_team))  # Count of unique schools

        # for categorisation for CGPA
        ind_mean = total_cgpa / len(ind_cgpa)  # individual group mean CGPA
        deviations = [(each - ind_mean) ** 2 for each in ind_cgpa]
        variance = sum(deviations) / len(ind_cgpa)
        sd = variance ** 0.5
        all_sd.append(sd)
        all_mean.append(ind_mean)

        # printing of cgPA values for each group
        print(f"The mean CGPA of team {i}  is {ind_mean:.2f}")
        print(f"The variance of team {i}  is {variance:.5f}")
        print(f"The standard deviation of team {i}  is {sd:.5f}")
        print()

    # comparing individual team's mean, sd to observe the disparity in CGPA between each team and the population
    total_mean = sum(all_mean) / len(all_mean)
    population_deviations = [(each - total_mean) ** 2 for each in all_mean]
    population_sd = (sum(population_deviations) / len(all_mean)) ** 0.5
    population_median = all_mean[len(all_mean)//2]

    # calculate z-score of every team
    for i in all_mean:
        z_score = (i - total_mean) / population_sd  # calculate z-score for each team and ammend to list for display
        compiled_z_score.append(z_score)

    # printing of the cohort's average cGPA, SD and zScore.
    print(f"The mean of the population is {total_mean:.2f}")
    print(f"Population median is: {population_median}")
    print(f"The standard deviation of the population is {population_sd:.5f}")

    #for base.py only
    # dictionary to hold self-defined variable for gender categorisation and its count per category
    #count_gender = {'m5f0': 0, 'm4f1': 0, 'm3f2': 0, 'm2f3': 0, 'm1f4': 0, 'm0f5': 0}
    #for teamg in compiled_gender:
    #    count = sum(1 for gender in teamg if gender == "Male")
    #    if count > 5:
    #        count = 5
    #    count_gender[f'm{count}f{5 - count}'] += 1
    #print(f"Gender count {count_gender}")

    count_gender = {}

    for teamgender in compiled_gender:
        male_count = sum(1 for gender in teamgender if gender == "Male")
        female_count = len(teamgender) - male_count  # female count is total team size - male count

        # Create the key based on the number of males and females
        gender_key = f'm{male_count}f{female_count}' # Key in the form of mXfY

        if gender_key not in count_gender:
            count_gender[gender_key] = 0
        
        # Update the count for the given key
        count_gender[gender_key] += 1

    # Output the final result
    print(count_gender)

    # Visualisation
    os.makedirs("assets", exist_ok=True)  # make assets folder if it doesnt exist

    show_graph_gender(count_gender)  # bar graph for count_gender dict
    show_graph_school(unique_school_counts)  # bar graph for sch repre
    # show_graph_CGPA(related_list,title,window_title,xlabel,ylabel,color_for_bins):
    show_graph_cgpa(all_mean, "Histogram of Mean CGPA per Team",
                    "Histogram_for_Mean_CGPA_Per_Team",
                    "Mean cGPA",
                    "Frequency",
                    "red")

    show_graph_cgpa(all_sd, "Histogram of Standard Deviation per Team",
                    "Histogram_for_Standard_Deviation_Per_Team",
                    "Standard Deviation",
                    "Frequency",
                    "blue")
    show_graph_cgpa(compiled_z_score, "Histogram of Z-Scores for Mean CGPA per Team",
                    "Histogram_of_Z-Scores_for_Mean_CGPA_per_Team",
                    "Z-Score",
                    "Frequency",
                    "green")

def show_graph_school(unique_school_counts):
    fig = plt.figure(figsize=(10, 6))
    fig.canvas.manager.set_window_title("Bar Graph for School Representation")
    counts, bins, patches = plt.hist(unique_school_counts, bins=range(1, max(unique_school_counts) + 2),
                                     color='skyblue', edgecolor='black', align='left')

    plt.xticks(range(1, max(unique_school_counts) + 1))  # Set x-ticks
    plt.xlabel("Number of Unique Schools per Team")
    plt.ylabel("Number of Teams")
    plt.title("Distribution of Unique Schools in Teams")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Adding labels on top of each bar
    for count, x in zip(counts, bins):
        if count > 0:  # Only label if there's a bar
            plt.text(x, count, int(count), ha='center', va='bottom')

    plt.show()
    fig.savefig("assets/school_representation.png")

def show_graph_gender(count_gender):
    # Data for the bar chart (this to visualize the count_gender dict)
    labels = list(count_gender.keys())  # Category labels using count_gender dictionary
    frequencies = list(count_gender.values())  # Count from dictionary for each category

    # Plotting the bar chart
    fig, ax = plt.subplots(figsize=(10, 6))
    fig.canvas.manager.set_window_title("Bar Graph for Gender Representation")

    # Create the bar chart
    bars = ax.bar(labels, frequencies, color='skyblue')

    # Adding titles and labels
    ax.set_title("Frequency of Gender in Teams")
    ax.set_xlabel("Gender Composition , m5f0 means 5 males, 0 females)")
    ax.set_ylabel("Number of Teams")

    # Adding frequency labels on top of each bar
    for bar in bars:
        yval = bar.get_height()  # Get the height of each bar
        ax.text(bar.get_x() + bar.get_width() / 2, yval, int(yval), ha='center', va='bottom')

    # Display the chart
    plt.xticks(rotation=45)
    plt.show()
    fig.savefig("assets/gender_representation.png")

def show_graph_cgpa(related_list, title, window_title, xlabel, ylabel, color_for_bins):
    fig = plt.figure(figsize=(10, 6))
    fig.canvas.manager.set_window_title(window_title)
    counts, bins, patches = plt.hist(related_list, bins=10, color=color_for_bins, edgecolor='black', alpha=0.7)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Add frequency labels on top of each bar
    for count, bin_edge in zip(counts, bins):
        if count > 0:
            plt.text(bin_edge + (bins[1] - bins[0]) / 2, count, int(count), ha='center', va='bottom')

    plt.show()
    fig.savefig("assets/" + window_title + ".png")
    
visualize_data(group_division)
# Out:
# Team 0
# The mean CGPA of team 0  is 4.11
# The variance of team 0  is 0.03547
# The standard deviation of team 0  is 0.18833
#
# Team 1
# The mean CGPA of team 1  is 4.08
# The variance of team 1  is 0.01120
# The standard deviation of team 1  is 0.10583
#
# Team 2
# The mean CGPA of team 2  is 4.09
# The variance of team 2  is 0.00529
# The standard deviation of team 2  is 0.07270
#
# Team 3
# The mean CGPA of team 3  is 4.10
# The variance of team 3  is 0.00451
# The standard deviation of team 3  is 0.06719
#
# Team 4
# The mean CGPA of team 4  is 4.08
# The variance of team 4  is 0.01088
# The standard deviation of team 4  is 0.10430
#
# Team 5
# The mean CGPA of team 5  is 4.15
# The variance of team 5  is 0.02469
# The standard deviation of team 5  is 0.15712
#
# Team 6
# The mean CGPA of team 6  is 4.07
# The variance of team 6  is 0.00937
# The standard deviation of team 6  is 0.09682
#
# Team 7
# The mean CGPA of team 7  is 4.08
# The variance of team 7  is 0.01138
# The standard deviation of team 7  is 0.10669
#
# Team 8
# The mean CGPA of team 8  is 4.09
# The variance of team 8  is 0.00533
# The standard deviation of team 8  is 0.07298
#
# Team 9
# The mean CGPA of team 9  is 4.10
# The variance of team 9  is 0.00576
# The standard deviation of team 9  is 0.07592
#
# Team 10
# The mean CGPA of team 10  is 4.09
# The variance of team 10  is 0.00373
# The standard deviation of team 10  is 0.06105
#
# Team 11
# The mean CGPA of team 11  is 4.11
# The variance of team 11  is 0.00454
# The standard deviation of team 11  is 0.06740
#
# Team 12
# The mean CGPA of team 12  is 4.11
# The variance of team 12  is 0.00485
# The standard deviation of team 12  is 0.06966
#
# Team 13
# The mean CGPA of team 13  is 4.04
# The variance of team 13  is 0.00846
# The standard deviation of team 13  is 0.09198
#
# Team 14
# The mean CGPA of team 14  is 4.06
# The variance of team 14  is 0.01229
# The standard deviation of team 14  is 0.11088
#
# Team 15
# The mean CGPA of team 15  is 4.16
# The variance of team 15  is 0.07245
# The standard deviation of team 15  is 0.26916
#
# Team 16
# The mean CGPA of team 16  is 4.09
# The variance of team 16  is 0.00724
# The standard deviation of team 16  is 0.08509
#
# Team 17
# The mean CGPA of team 17  is 4.08
# The variance of team 17  is 0.00682
# The standard deviation of team 17  is 0.08259
#
# Team 18
# The mean CGPA of team 18  is 4.09
# The variance of team 18  is 0.00691
# The standard deviation of team 18  is 0.08313
#
# Team 19
# The mean CGPA of team 19  is 4.09
# The variance of team 19  is 0.00291
# The standard deviation of team 19  is 0.05391
#
# Team 20
# The mean CGPA of team 20  is 4.19
# The variance of team 20  is 0.11158
# The standard deviation of team 20  is 0.33404
#
# Team 21
# The mean CGPA of team 21  is 4.07
# The variance of team 21  is 0.01245
# The standard deviation of team 21  is 0.11159
#
# Team 22
# The mean CGPA of team 22  is 4.07
# The variance of team 22  is 0.01482
# The standard deviation of team 22  is 0.12176
#
# Team 23
# The mean CGPA of team 23  is 4.08
# The variance of team 23  is 0.00716
# The standard deviation of team 23  is 0.08464
#
# Team 24
# The mean CGPA of team 24  is 4.10
# The variance of team 24  is 0.00548
# The standard deviation of team 24  is 0.07401
#
# Team 25
# The mean CGPA of team 25  is 4.08
# The variance of team 25  is 0.00294
# The standard deviation of team 25  is 0.05421
#
# Team 26
# The mean CGPA of team 26  is 4.05
# The variance of team 26  is 0.00888
# The standard deviation of team 26  is 0.09424
#
# Team 27
# The mean CGPA of team 27  is 4.09
# The variance of team 27  is 0.01209
# The standard deviation of team 27  is 0.10997
#
# Team 28
# The mean CGPA of team 28  is 4.06
# The variance of team 28  is 0.01913
# The standard deviation of team 28  is 0.13830
#
# Team 29
# The mean CGPA of team 29  is 4.07
# The variance of team 29  is 0.01514
# The standard deviation of team 29  is 0.12304
#
# Team 30
# The mean CGPA of team 30  is 4.08
# The variance of team 30  is 0.01208
# The standard deviation of team 30  is 0.10990
#
# Team 31
# The mean CGPA of team 31  is 4.11
# The variance of team 31  is 0.00673
# The standard deviation of team 31  is 0.08207
#
# Team 32
# The mean CGPA of team 32  is 4.09
# The variance of team 32  is 0.00516
# The standard deviation of team 32  is 0.07186
#
# Team 33
# The mean CGPA of team 33  is 4.04
# The variance of team 33  is 0.00639
# The standard deviation of team 33  is 0.07995
#
# Team 34
# The mean CGPA of team 34  is 4.09
# The variance of team 34  is 0.04252
# The standard deviation of team 34  is 0.20620
#
# Team 35
# The mean CGPA of team 35  is 4.08
# The variance of team 35  is 0.01591
# The standard deviation of team 35  is 0.12615
#
# Team 36
# The mean CGPA of team 36  is 4.08
# The variance of team 36  is 0.01466
# The standard deviation of team 36  is 0.12107
#
# Team 37
# The mean CGPA of team 37  is 4.09
# The variance of team 37  is 0.00786
# The standard deviation of team 37  is 0.08864
#
# Team 38
# The mean CGPA of team 38  is 4.10
# The variance of team 38  is 0.00716
# The standard deviation of team 38  is 0.08464
#
# Team 39
# The mean CGPA of team 39  is 4.11
# The variance of team 39  is 0.00593
# The standard deviation of team 39  is 0.07704
#
# Team 40
# The mean CGPA of team 40  is 4.16
# The variance of team 40  is 0.06676
# The standard deviation of team 40  is 0.25837
#
# Team 41
# The mean CGPA of team 41  is 4.07
# The variance of team 41  is 0.01835
# The standard deviation of team 41  is 0.13546
#
# Team 42
# The mean CGPA of team 42  is 4.03
# The variance of team 42  is 0.02257
# The standard deviation of team 42  is 0.15023
#
# Team 43
# The mean CGPA of team 43  is 4.06
# The variance of team 43  is 0.01959
# The standard deviation of team 43  is 0.13997
#
# Team 44
# The mean CGPA of team 44  is 4.11
# The variance of team 44  is 0.01800
# The standard deviation of team 44  is 0.13416
#
# Team 45
# The mean CGPA of team 45  is 4.11
# The variance of team 45  is 0.00511
# The standard deviation of team 45  is 0.07149
#
# Team 46
# The mean CGPA of team 46  is 4.09
# The variance of team 46  is 0.00303
# The standard deviation of team 46  is 0.05503
#
# Team 47
# The mean CGPA of team 47  is 4.14
# The variance of team 47  is 0.02577
# The standard deviation of team 47  is 0.16052
#
# Team 48
# The mean CGPA of team 48  is 4.11
# The variance of team 48  is 0.01351
# The standard deviation of team 48  is 0.11623
#
# Team 49
# The mean CGPA of team 49  is 4.06
# The variance of team 49  is 0.01203
# The standard deviation of team 49  is 0.10967
#
# Team 50
# The mean CGPA of team 50  is 4.06
# The variance of team 50  is 0.00962
# The standard deviation of team 50  is 0.09810
#
# Team 51
# The mean CGPA of team 51  is 4.10
# The variance of team 51  is 0.00531
# The standard deviation of team 51  is 0.07284
#
# Team 52
# The mean CGPA of team 52  is 4.10
# The variance of team 52  is 0.00462
# The standard deviation of team 52  is 0.06797
#
# Team 53
# The mean CGPA of team 53  is 4.11
# The variance of team 53  is 0.00362
# The standard deviation of team 53  is 0.06020
#
# Team 54
# The mean CGPA of team 54  is 4.11
# The variance of team 54  is 0.00205
# The standard deviation of team 54  is 0.04531
#
# Team 55
# The mean CGPA of team 55  is 4.10
# The variance of team 55  is 0.03439
# The standard deviation of team 55  is 0.18546
#
# Team 56
# The mean CGPA of team 56  is 4.06
# The variance of team 56  is 0.01888
# The standard deviation of team 56  is 0.13741
#
# Team 57
# The mean CGPA of team 57  is 4.07
# The variance of team 57  is 0.01324
# The standard deviation of team 57  is 0.11507
#
# Team 58
# The mean CGPA of team 58  is 4.12
# The variance of team 58  is 0.02109
# The standard deviation of team 58  is 0.14521
#
# Team 59
# The mean CGPA of team 59  is 4.09
# The variance of team 59  is 0.00428
# The standard deviation of team 59  is 0.06540
#
# Team 60
# The mean CGPA of team 60  is 4.08
# The variance of team 60  is 0.00188
# The standard deviation of team 60  is 0.04338
#
# Team 61
# The mean CGPA of team 61  is 4.04
# The variance of team 61  is 0.00705
# The standard deviation of team 61  is 0.08398
#
# Team 62
# The mean CGPA of team 62  is 4.09
# The variance of team 62  is 0.00967
# The standard deviation of team 62  is 0.09833
#
# Team 63
# The mean CGPA of team 63  is 4.09
# The variance of team 63  is 0.01321
# The standard deviation of team 63  is 0.11494
#
# Team 64
# The mean CGPA of team 64  is 4.10
# The variance of team 64  is 0.00533
# The standard deviation of team 64  is 0.07304
#
# Team 65
# The mean CGPA of team 65  is 4.11
# The variance of team 65  is 0.00491
# The standard deviation of team 65  is 0.07004
#
# Team 66
# The mean CGPA of team 66  is 4.13
# The variance of team 66  is 0.00765
# The standard deviation of team 66  is 0.08748
#
# Team 67
# The mean CGPA of team 67  is 4.11
# The variance of team 67  is 0.00281
# The standard deviation of team 67  is 0.05303
#
# Team 68
# The mean CGPA of team 68  is 4.17
# The variance of team 68  is 0.02365
# The standard deviation of team 68  is 0.15378
#
# Team 69
# The mean CGPA of team 69  is 4.11
# The variance of team 69  is 0.04302
# The standard deviation of team 69  is 0.20741
#
# Team 70
# The mean CGPA of team 70  is 4.07
# The variance of team 70  is 0.02116
# The standard deviation of team 70  is 0.14548
#
# Team 71
# The mean CGPA of team 71  is 4.06
# The variance of team 71  is 0.01448
# The standard deviation of team 71  is 0.12032
#
# Team 72
# The mean CGPA of team 72  is 4.09
# The variance of team 72  is 0.01150
# The standard deviation of team 72  is 0.10723
#
# Team 73
# The mean CGPA of team 73  is 4.08
# The variance of team 73  is 0.01411
# The standard deviation of team 73  is 0.11879
#
# Team 74
# The mean CGPA of team 74  is 4.06
# The variance of team 74  is 0.00242
# The standard deviation of team 74  is 0.04918
#
# Team 75
# The mean CGPA of team 75  is 4.12
# The variance of team 75  is 0.01617
# The standard deviation of team 75  is 0.12717
#
# Team 76
# The mean CGPA of team 76  is 4.02
# The variance of team 76  is 0.01030
# The standard deviation of team 76  is 0.10148
#
# Team 77
# The mean CGPA of team 77  is 4.10
# The variance of team 77  is 0.01540
# The standard deviation of team 77  is 0.12410
#
# Team 78
# The mean CGPA of team 78  is 4.10
# The variance of team 78  is 0.01287
# The standard deviation of team 78  is 0.11344
#
# Team 79
# The mean CGPA of team 79  is 4.08
# The variance of team 79  is 0.01834
# The standard deviation of team 79  is 0.13544
#
# Team 80
# The mean CGPA of team 80  is 4.12
# The variance of team 80  is 0.00748
# The standard deviation of team 80  is 0.08647
#
# Team 81
# The mean CGPA of team 81  is 4.11
# The variance of team 81  is 0.00748
# The standard deviation of team 81  is 0.08647
#
# Team 82
# The mean CGPA of team 82  is 4.11
# The variance of team 82  is 0.00322
# The standard deviation of team 82  is 0.05678
#
# Team 83
# The mean CGPA of team 83  is 4.20
# The variance of team 83  is 0.05260
# The standard deviation of team 83  is 0.22934
#
# Team 84
# The mean CGPA of team 84  is 4.05
# The variance of team 84  is 0.02102
# The standard deviation of team 84  is 0.14498
#
# Team 85
# The mean CGPA of team 85  is 4.05
# The variance of team 85  is 0.01229
# The standard deviation of team 85  is 0.11084
#
# Team 86
# The mean CGPA of team 86  is 4.07
# The variance of team 86  is 0.01460
# The standard deviation of team 86  is 0.12081
#
# Team 87
# The mean CGPA of team 87  is 4.07
# The variance of team 87  is 0.00733
# The standard deviation of team 87  is 0.08560
#
# Team 88
# The mean CGPA of team 88  is 4.10
# The variance of team 88  is 0.00654
# The standard deviation of team 88  is 0.08089
#
# Team 89
# The mean CGPA of team 89  is 4.07
# The variance of team 89  is 0.00522
# The standard deviation of team 89  is 0.07228
#
# Team 90
# The mean CGPA of team 90  is 4.03
# The variance of team 90  is 0.01725
# The standard deviation of team 90  is 0.13133
#
# Team 91
# The mean CGPA of team 91  is 4.08
# The variance of team 91  is 0.02319
# The standard deviation of team 91  is 0.15229
#
# Team 92
# The mean CGPA of team 92  is 4.05
# The variance of team 92  is 0.01371
# The standard deviation of team 92  is 0.11707
#
# Team 93
# The mean CGPA of team 93  is 4.04
# The variance of team 93  is 0.02036
# The standard deviation of team 93  is 0.14269
#
# Team 94
# The mean CGPA of team 94  is 4.08
# The variance of team 94  is 0.00797
# The standard deviation of team 94  is 0.08928
#
# Team 95
# The mean CGPA of team 95  is 4.08
# The variance of team 95  is 0.00271
# The standard deviation of team 95  is 0.05202
#
# Team 96
# The mean CGPA of team 96  is 4.16
# The variance of team 96  is 0.02305
# The standard deviation of team 96  is 0.15182
#
# Team 97
# The mean CGPA of team 97  is 4.06
# The variance of team 97  is 0.01534
# The standard deviation of team 97  is 0.12385
#
# Team 98
# The mean CGPA of team 98  is 4.04
# The variance of team 98  is 0.01417
# The standard deviation of team 98  is 0.11906
#
# Team 99
# The mean CGPA of team 99  is 4.02
# The variance of team 99  is 0.01411
# The standard deviation of team 99  is 0.11879
#
# Team 100
# The mean CGPA of team 100  is 4.06
# The variance of team 100  is 0.00782
# The standard deviation of team 100  is 0.08843
#
# Team 101
# The mean CGPA of team 101  is 4.06
# The variance of team 101  is 0.00739
# The standard deviation of team 101  is 0.08598
#
# Team 102
# The mean CGPA of team 102  is 4.08
# The variance of team 102  is 0.00296
# The standard deviation of team 102  is 0.05436
#
# Team 103
# The mean CGPA of team 103  is 4.10
# The variance of team 103  is 0.00993
# The standard deviation of team 103  is 0.09967
#
# Team 104
# The mean CGPA of team 104  is 4.05
# The variance of team 104  is 0.00773
# The standard deviation of team 104  is 0.08790
#
# Team 105
# The mean CGPA of team 105  is 4.05
# The variance of team 105  is 0.01544
# The standard deviation of team 105  is 0.12426
#
# Team 106
# The mean CGPA of team 106  is 4.07
# The variance of team 106  is 0.01104
# The standard deviation of team 106  is 0.10508
#
# Team 107
# The mean CGPA of team 107  is 4.07
# The variance of team 107  is 0.00733
# The standard deviation of team 107  is 0.08560
#
# Team 108
# The mean CGPA of team 108  is 4.09
# The variance of team 108  is 0.00467
# The standard deviation of team 108  is 0.06833
#
# Team 109
# The mean CGPA of team 109  is 4.05
# The variance of team 109  is 0.00711
# The standard deviation of team 109  is 0.08433
#
# Team 110
# The mean CGPA of team 110  is 4.09
# The variance of team 110  is 0.00204
# The standard deviation of team 110  is 0.04518
#
# Team 111
# The mean CGPA of team 111  is 4.12
# The variance of team 111  is 0.03259
# The standard deviation of team 111  is 0.18053
#
# Team 112
# The mean CGPA of team 112  is 4.07
# The variance of team 112  is 0.01669
# The standard deviation of team 112  is 0.12920
#
# Team 113
# The mean CGPA of team 113  is 4.05
# The variance of team 113  is 0.01938
# The standard deviation of team 113  is 0.13923
#
# Team 114
# The mean CGPA of team 114  is 4.10
# The variance of team 114  is 0.00756
# The standard deviation of team 114  is 0.08697
#
# Team 115
# The mean CGPA of team 115  is 4.10
# The variance of team 115  is 0.00482
# The standard deviation of team 115  is 0.06946
#
# Team 116
# The mean CGPA of team 116  is 4.10
# The variance of team 116  is 0.00343
# The standard deviation of team 116  is 0.05855
#
# Team 117
# The mean CGPA of team 117  is 4.07
# The variance of team 117  is 0.00714
# The standard deviation of team 117  is 0.08452
#
# Team 118
# The mean CGPA of team 118  is 4.13
# The variance of team 118  is 0.03601
# The standard deviation of team 118  is 0.18977
#
# Team 119
# The mean CGPA of team 119  is 4.04
# The variance of team 119  is 0.01813
# The standard deviation of team 119  is 0.13463
#
# Team 120
# The mean CGPA of team 120  is 4.04
# The variance of team 120  is 0.01568
# The standard deviation of team 120  is 0.12521
#
# Team 121
# The mean CGPA of team 121  is 4.08
# The variance of team 121  is 0.00922
# The standard deviation of team 121  is 0.09604
#
# Team 122
# The mean CGPA of team 122  is 4.09
# The variance of team 122  is 0.00637
# The standard deviation of team 122  is 0.07980
#
# Team 123
# The mean CGPA of team 123  is 4.09
# The variance of team 123  is 0.00428
# The standard deviation of team 123  is 0.06543
#
# Team 124
# The mean CGPA of team 124  is 4.08
# The variance of team 124  is 0.00206
# The standard deviation of team 124  is 0.04536
#
# Team 125
# The mean CGPA of team 125  is 4.07
# The variance of team 125  is 0.01562
# The standard deviation of team 125  is 0.12500
#
# Team 126
# The mean CGPA of team 126  is 4.07
# The variance of team 126  is 0.01335
# The standard deviation of team 126  is 0.11554
#
# Team 127
# The mean CGPA of team 127  is 4.07
# The variance of team 127  is 0.00689
# The standard deviation of team 127  is 0.08298
#
# Team 128
# The mean CGPA of team 128  is 4.08
# The variance of team 128  is 0.00498
# The standard deviation of team 128  is 0.07060
#
# Team 129
# The mean CGPA of team 129  is 4.09
# The variance of team 129  is 0.00400
# The standard deviation of team 129  is 0.06325
#
# Team 130
# The mean CGPA of team 130  is 4.09
# The variance of team 130  is 0.00387
# The standard deviation of team 130  is 0.06220
#
# Team 131
# The mean CGPA of team 131  is 4.06
# The variance of team 131  is 0.00978
# The standard deviation of team 131  is 0.09891
#
# Team 132
# The mean CGPA of team 132  is 4.06
# The variance of team 132  is 0.01016
# The standard deviation of team 132  is 0.10081
#
# Team 133
# The mean CGPA of team 133  is 4.06
# The variance of team 133  is 0.01356
# The standard deviation of team 133  is 0.11646
#
# Team 134
# The mean CGPA of team 134  is 4.08
# The variance of team 134  is 0.01271
# The standard deviation of team 134  is 0.11274
#
# Team 135
# The mean CGPA of team 135  is 4.09
# The variance of team 135  is 0.00534
# The standard deviation of team 135  is 0.07307
#
# Team 136
# The mean CGPA of team 136  is 4.09
# The variance of team 136  is 0.00567
# The standard deviation of team 136  is 0.07530
#
# Team 137
# The mean CGPA of team 137  is 4.07
# The variance of team 137  is 0.00477
# The standard deviation of team 137  is 0.06906
#
# Team 138
# The mean CGPA of team 138  is 4.15
# The variance of team 138  is 0.04042
# The standard deviation of team 138  is 0.20106
#
# Team 139
# The mean CGPA of team 139  is 4.05
# The variance of team 139  is 0.00931
# The standard deviation of team 139  is 0.09647
#
# Team 140
# The mean CGPA of team 140  is 4.04
# The variance of team 140  is 0.01636
# The standard deviation of team 140  is 0.12792
#
# Team 141
# The mean CGPA of team 141  is 4.06
# The variance of team 141  is 0.01161
# The standard deviation of team 141  is 0.10776
#
# Team 142
# The mean CGPA of team 142  is 4.08
# The variance of team 142  is 0.00916
# The standard deviation of team 142  is 0.09572
#
# Team 143
# The mean CGPA of team 143  is 4.10
# The variance of team 143  is 0.00558
# The standard deviation of team 143  is 0.07472
#
# Team 144
# The mean CGPA of team 144  is 4.10
# The variance of team 144  is 0.00922
# The standard deviation of team 144  is 0.09602
#
# Team 145
# The mean CGPA of team 145  is 4.06
# The variance of team 145  is 0.00247
# The standard deviation of team 145  is 0.04969
#
# Team 146
# The mean CGPA of team 146  is 4.05
# The variance of team 146  is 0.01616
# The standard deviation of team 146  is 0.12713
#
# Team 147
# The mean CGPA of team 147  is 4.07
# The variance of team 147  is 0.01521
# The standard deviation of team 147  is 0.12334
#
# Team 148
# The mean CGPA of team 148  is 4.09
# The variance of team 148  is 0.00851
# The standard deviation of team 148  is 0.09223
#
# Team 149
# The mean CGPA of team 149  is 4.10
# The variance of team 149  is 0.00777
# The standard deviation of team 149  is 0.08816
#
# Team 150
# The mean CGPA of team 150  is 4.10
# The variance of team 150  is 0.00502
# The standard deviation of team 150  is 0.07085
#
# Team 151
# The mean CGPA of team 151  is 4.07
# The variance of team 151  is 0.00820
# The standard deviation of team 151  is 0.09055
#
# Team 152
# The mean CGPA of team 152  is 4.06
# The variance of team 152  is 0.01500
# The standard deviation of team 152  is 0.12247
#
# Team 153
# The mean CGPA of team 153  is 4.09
# The variance of team 153  is 0.00538
# The standard deviation of team 153  is 0.07337
#
# Team 154
# The mean CGPA of team 154  is 4.03
# The variance of team 154  is 0.02754
# The standard deviation of team 154  is 0.16594
#
# Team 155
# The mean CGPA of team 155  is 4.04
# The variance of team 155  is 0.01449
# The standard deviation of team 155  is 0.12036
#
# Team 156
# The mean CGPA of team 156  is 4.06
# The variance of team 156  is 0.01094
# The standard deviation of team 156  is 0.10459
#
# Team 157
# The mean CGPA of team 157  is 4.07
# The variance of team 157  is 0.00868
# The standard deviation of team 157  is 0.09315
#
# Team 158
# The mean CGPA of team 158  is 4.10
# The variance of team 158  is 0.00525
# The standard deviation of team 158  is 0.07248
#
# Team 159
# The mean CGPA of team 159  is 4.15
# The variance of team 159  is 0.05990
# The standard deviation of team 159  is 0.24474
#
# Team 160
# The mean CGPA of team 160  is 4.11
# The variance of team 160  is 0.03097
# The standard deviation of team 160  is 0.17598
#
# Team 161
# The mean CGPA of team 161  is 4.00
# The variance of team 161  is 0.01709
# The standard deviation of team 161  is 0.13071
#
# Team 162
# The mean CGPA of team 162  is 4.06
# The variance of team 162  is 0.00745
# The standard deviation of team 162  is 0.08633
#
# Team 163
# The mean CGPA of team 163  is 4.05
# The variance of team 163  is 0.01007
# The standard deviation of team 163  is 0.10035
#
# Team 164
# The mean CGPA of team 164  is 4.09
# The variance of team 164  is 0.00537
# The standard deviation of team 164  is 0.07326
#
# Team 165
# The mean CGPA of team 165  is 4.08
# The variance of team 165  is 0.00666
# The standard deviation of team 165  is 0.08159
#
# Team 166
# The mean CGPA of team 166  is 4.07
# The variance of team 166  is 0.00374
# The standard deviation of team 166  is 0.06118
#
# Team 167
# The mean CGPA of team 167  is 4.06
# The variance of team 167  is 0.01070
# The standard deviation of team 167  is 0.10343
#
# Team 168
# The mean CGPA of team 168  is 4.06
# The variance of team 168  is 0.01696
# The standard deviation of team 168  is 0.13021
#
# Team 169
# The mean CGPA of team 169  is 4.07
# The variance of team 169  is 0.01110
# The standard deviation of team 169  is 0.10535
#
# Team 170
# The mean CGPA of team 170  is 4.09
# The variance of team 170  is 0.00620
# The standard deviation of team 170  is 0.07871
#
# Team 171
# The mean CGPA of team 171  is 4.10
# The variance of team 171  is 0.00382
# The standard deviation of team 171  is 0.06181
#
# Team 172
# The mean CGPA of team 172  is 4.11
# The variance of team 172  is 0.00322
# The standard deviation of team 172  is 0.05675
#
# Team 173
# The mean CGPA of team 173  is 4.08
# The variance of team 173  is 0.00136
# The standard deviation of team 173  is 0.03692
#
# Team 174
# The mean CGPA of team 174  is 4.13
# The variance of team 174  is 0.06815
# The standard deviation of team 174  is 0.26105
#
# Team 175
# The mean CGPA of team 175  is 4.06
# The variance of team 175  is 0.01804
# The standard deviation of team 175  is 0.13432
#
# Team 176
# The mean CGPA of team 176  is 4.08
# The variance of team 176  is 0.01187
# The standard deviation of team 176  is 0.10895
#
# Team 177
# The mean CGPA of team 177  is 4.08
# The variance of team 177  is 0.01167
# The standard deviation of team 177  is 0.10802
#
# Team 178
# The mean CGPA of team 178  is 4.10
# The variance of team 178  is 0.00907
# The standard deviation of team 178  is 0.09523
#
# Team 179
# The mean CGPA of team 179  is 4.09
# The variance of team 179  is 0.00919
# The standard deviation of team 179  is 0.09587
#
# Team 180
# The mean CGPA of team 180  is 4.08
# The variance of team 180  is 0.00451
# The standard deviation of team 180  is 0.06713
#
# Team 181
# The mean CGPA of team 181  is 4.08
# The variance of team 181  is 0.02137
# The standard deviation of team 181  is 0.14620
#
# Team 182
# The mean CGPA of team 182  is 4.05
# The variance of team 182  is 0.02193
# The standard deviation of team 182  is 0.14808
#
# Team 183
# The mean CGPA of team 183  is 4.06
# The variance of team 183  is 0.01283
# The standard deviation of team 183  is 0.11326
#
# Team 184
# The mean CGPA of team 184  is 4.06
# The variance of team 184  is 0.01478
# The standard deviation of team 184  is 0.12159
#
# Team 185
# The mean CGPA of team 185  is 4.07
# The variance of team 185  is 0.00910
# The standard deviation of team 185  is 0.09538
#
# Team 186
# The mean CGPA of team 186  is 4.11
# The variance of team 186  is 0.01038
# The standard deviation of team 186  is 0.10190
#
# Team 187
# The mean CGPA of team 187  is 4.04
# The variance of team 187  is 0.00791
# The standard deviation of team 187  is 0.08894
#
# Team 188
# The mean CGPA of team 188  is 4.12
# The variance of team 188  is 0.03914
# The standard deviation of team 188  is 0.19783
#
# Team 189
# The mean CGPA of team 189  is 4.06
# The variance of team 189  is 0.01394
# The standard deviation of team 189  is 0.11808
#
# Team 190
# The mean CGPA of team 190  is 4.07
# The variance of team 190  is 0.01058
# The standard deviation of team 190  is 0.10288
#
# Team 191
# The mean CGPA of team 191  is 4.08
# The variance of team 191  is 0.00860
# The standard deviation of team 191  is 0.09274
#
# Team 192
# The mean CGPA of team 192  is 4.04
# The variance of team 192  is 0.01380
# The standard deviation of team 192  is 0.11747
#
# Team 193
# The mean CGPA of team 193  is 4.06
# The variance of team 193  is 0.00802
# The standard deviation of team 193  is 0.08957
#
# Team 194
# The mean CGPA of team 194  is 4.11
# The variance of team 194  is 0.00874
# The standard deviation of team 194  is 0.09348
#
# Team 195
# The mean CGPA of team 195  is 4.10
# The variance of team 195  is 0.00388
# The standard deviation of team 195  is 0.06230
#
# Team 196
# The mean CGPA of team 196  is 4.05
# The variance of team 196  is 0.01686
# The standard deviation of team 196  is 0.12985
#
# Team 197
# The mean CGPA of team 197  is 4.08
# The variance of team 197  is 0.01176
# The standard deviation of team 197  is 0.10842
#
# Team 198
# The mean CGPA of team 198  is 4.08
# The variance of team 198  is 0.00613
# The standard deviation of team 198  is 0.07827
#
# Team 199
# The mean CGPA of team 199  is 4.10
# The variance of team 199  is 0.00458
# The standard deviation of team 199  is 0.06770
#
# Team 200
# The mean CGPA of team 200  is 4.09
# The variance of team 200  is 0.00228
# The standard deviation of team 200  is 0.04772
#
# Team 201
# The mean CGPA of team 201  is 4.16
# The variance of team 201  is 0.02488
# The standard deviation of team 201  is 0.15774
#
# Team 202
# The mean CGPA of team 202  is 4.03
# The variance of team 202  is 0.01542
# The standard deviation of team 202  is 0.12418
#
# Team 203
# The mean CGPA of team 203  is 4.08
# The variance of team 203  is 0.01590
# The standard deviation of team 203  is 0.12609
#
# Team 204
# The mean CGPA of team 204  is 4.08
# The variance of team 204  is 0.01307
# The standard deviation of team 204  is 0.11432
#
# Team 205
# The mean CGPA of team 205  is 4.09
# The variance of team 205  is 0.01365
# The standard deviation of team 205  is 0.11683
#
# Team 206
# The mean CGPA of team 206  is 4.12
# The variance of team 206  is 0.00762
# The standard deviation of team 206  is 0.08729
#
# Team 207
# The mean CGPA of team 207  is 4.11
# The variance of team 207  is 0.00508
# The standard deviation of team 207  is 0.07126
#
# Team 208
# The mean CGPA of team 208  is 4.17
# The variance of team 208  is 0.02485
# The standard deviation of team 208  is 0.15764
#
# Team 209
# The mean CGPA of team 209  is 4.04
# The variance of team 209  is 0.01705
# The standard deviation of team 209  is 0.13059
#
# Team 210
# The mean CGPA of team 210  is 4.06
# The variance of team 210  is 0.02055
# The standard deviation of team 210  is 0.14335
#
# Team 211
# The mean CGPA of team 211  is 4.08
# The variance of team 211  is 0.01459
# The standard deviation of team 211  is 0.12080
#
# Team 212
# The mean CGPA of team 212  is 4.10
# The variance of team 212  is 0.01064
# The standard deviation of team 212  is 0.10315
#
# Team 213
# The mean CGPA of team 213  is 4.10
# The variance of team 213  is 0.01428
# The standard deviation of team 213  is 0.11949
#
# Team 214
# The mean CGPA of team 214  is 4.19
# The variance of team 214  is 0.06411
# The standard deviation of team 214  is 0.25320
#
# Team 215
# The mean CGPA of team 215  is 4.12
# The variance of team 215  is 0.00639
# The standard deviation of team 215  is 0.07995
#
# Team 216
# The mean CGPA of team 216  is 4.09
# The variance of team 216  is 0.01176
# The standard deviation of team 216  is 0.10846
#
# Team 217
# The mean CGPA of team 217  is 4.06
# The variance of team 217  is 0.01493
# The standard deviation of team 217  is 0.12221
#
# Team 218
# The mean CGPA of team 218  is 4.09
# The variance of team 218  is 0.00628
# The standard deviation of team 218  is 0.07926
#
# Team 219
# The mean CGPA of team 219  is 4.08
# The variance of team 219  is 0.00666
# The standard deviation of team 219  is 0.08161
#
# Team 220
# The mean CGPA of team 220  is 4.09
# The variance of team 220  is 0.00359
# The standard deviation of team 220  is 0.05993
#
# Team 221
# The mean CGPA of team 221  is 4.09
# The variance of team 221  is 0.00314
# The standard deviation of team 221  is 0.05606
#
# Team 222
# The mean CGPA of team 222  is 4.05
# The variance of team 222  is 0.00838
# The standard deviation of team 222  is 0.09156
#
# Team 223
# The mean CGPA of team 223  is 4.12
# The variance of team 223  is 0.02108
# The standard deviation of team 223  is 0.14518
#
# Team 224
# The mean CGPA of team 224  is 4.14
# The variance of team 224  is 0.03617
# The standard deviation of team 224  is 0.19018
#
# Team 225
# The mean CGPA of team 225  is 4.10
# The variance of team 225  is 0.01194
# The standard deviation of team 225  is 0.10926
#
# Team 226
# The mean CGPA of team 226  is 4.11
# The variance of team 226  is 0.00637
# The standard deviation of team 226  is 0.07980
#
# Team 227
# The mean CGPA of team 227  is 4.11
# The variance of team 227  is 0.00636
# The standard deviation of team 227  is 0.07972
#
# Team 228
# The mean CGPA of team 228  is 4.09
# The variance of team 228  is 0.01054
# The standard deviation of team 228  is 0.10266
#
# Team 229
# The mean CGPA of team 229  is 4.10
# The variance of team 229  is 0.00314
# The standard deviation of team 229  is 0.05602
#
# Team 230
# The mean CGPA of team 230  is 4.12
# The variance of team 230  is 0.03221
# The standard deviation of team 230  is 0.17947
#
# Team 231
# The mean CGPA of team 231  is 4.06
# The variance of team 231  is 0.02185
# The standard deviation of team 231  is 0.14781
#
# Team 232
# The mean CGPA of team 232  is 4.06
# The variance of team 232  is 0.01257
# The standard deviation of team 232  is 0.11210
#
# Team 233
# The mean CGPA of team 233  is 4.07
# The variance of team 233  is 0.01609
# The standard deviation of team 233  is 0.12683
#
# Team 234
# The mean CGPA of team 234  is 4.10
# The variance of team 234  is 0.00839
# The standard deviation of team 234  is 0.09161
#
# Team 235
# The mean CGPA of team 235  is 4.11
# The variance of team 235  is 0.00454
# The standard deviation of team 235  is 0.06737
#
# Team 236
# The mean CGPA of team 236  is 4.11
# The variance of team 236  is 0.00326
# The standard deviation of team 236  is 0.05707
#
# Team 237
# The mean CGPA of team 237  is 4.11
# The variance of team 237  is 0.01700
# The standard deviation of team 237  is 0.13037
#
# Team 238
# The mean CGPA of team 238  is 4.07
# The variance of team 238  is 0.01680
# The standard deviation of team 238  is 0.12960
#
# Team 239
# The mean CGPA of team 239  is 4.11
# The variance of team 239  is 0.00618
# The standard deviation of team 239  is 0.07864
#
# Team 240
# The mean CGPA of team 240  is 4.12
# The variance of team 240  is 0.00579
# The standard deviation of team 240  is 0.07610
#
# Team 241
# The mean CGPA of team 241  is 4.14
# The variance of team 241  is 0.00627
# The standard deviation of team 241  is 0.07918
#
# Team 242
# The mean CGPA of team 242  is 4.09
# The variance of team 242  is 0.01173
# The standard deviation of team 242  is 0.10833
#
# Team 243
# The mean CGPA of team 243  is 4.14
# The variance of team 243  is 0.00477
# The standard deviation of team 243  is 0.06905
#
# Team 244
# The mean CGPA of team 244  is 4.09
# The variance of team 244  is 0.00936
# The standard deviation of team 244  is 0.09675
#
# Team 245
# The mean CGPA of team 245  is 4.05
# The variance of team 245  is 0.02271
# The standard deviation of team 245  is 0.15070
#
# Team 246
# The mean CGPA of team 246  is 4.05
# The variance of team 246  is 0.01300
# The standard deviation of team 246  is 0.11400
#
# Team 247
# The mean CGPA of team 247  is 4.07
# The variance of team 247  is 0.00896
# The standard deviation of team 247  is 0.09463
#
# Team 248
# The mean CGPA of team 248  is 4.09
# The variance of team 248  is 0.01005
# The standard deviation of team 248  is 0.10026
#
# Team 249
# The mean CGPA of team 249  is 4.09
# The variance of team 249  is 0.00230
# The standard deviation of team 249  is 0.04794
#
# Team 250
# The mean CGPA of team 250  is 4.11
# The variance of team 250  is 0.01198
# The standard deviation of team 250  is 0.10947
#
# Team 251
# The mean CGPA of team 251  is 4.07
# The variance of team 251  is 0.01370
# The standard deviation of team 251  is 0.11704
#
# Team 252
# The mean CGPA of team 252  is 4.13
# The variance of team 252  is 0.04227
# The standard deviation of team 252  is 0.20560
#
# Team 253
# The mean CGPA of team 253  is 4.10
# The variance of team 253  is 0.00820
# The standard deviation of team 253  is 0.09055
#
# Team 254
# The mean CGPA of team 254  is 4.10
# The variance of team 254  is 0.00770
# The standard deviation of team 254  is 0.08774
#
# Team 255
# The mean CGPA of team 255  is 4.12
# The variance of team 255  is 0.00471
# The standard deviation of team 255  is 0.06866
#
# Team 256
# The mean CGPA of team 256  is 4.10
# The variance of team 256  is 0.00193
# The standard deviation of team 256  is 0.04389
#
# Team 257
# The mean CGPA of team 257  is 4.13
# The variance of team 257  is 0.03285
# The standard deviation of team 257  is 0.18124
#
# Team 258
# The mean CGPA of team 258  is 4.20
# The variance of team 258  is 0.09405
# The standard deviation of team 258  is 0.30667
#
# Team 259
# The mean CGPA of team 259  is 4.03
# The variance of team 259  is 0.02669
# The standard deviation of team 259  is 0.16336
#
# Team 260
# The mean CGPA of team 260  is 4.07
# The variance of team 260  is 0.01551
# The standard deviation of team 260  is 0.12454
#
# Team 261
# The mean CGPA of team 261  is 4.11
# The variance of team 261  is 0.01348
# The standard deviation of team 261  is 0.11609
#
# Team 262
# The mean CGPA of team 262  is 4.09
# The variance of team 262  is 0.00751
# The standard deviation of team 262  is 0.08666
#
# Team 263
# The mean CGPA of team 263  is 4.10
# The variance of team 263  is 0.00473
# The standard deviation of team 263  is 0.06881
#
# Team 264
# The mean CGPA of team 264  is 4.11
# The variance of team 264  is 0.00385
# The standard deviation of team 264  is 0.06207
#
# Team 265
# The mean CGPA of team 265  is 4.12
# The variance of team 265  is 0.03729
# The standard deviation of team 265  is 0.19310
#
# Team 266
# The mean CGPA of team 266  is 4.06
# The variance of team 266  is 0.01476
# The standard deviation of team 266  is 0.12150
#
# Team 267
# The mean CGPA of team 267  is 4.07
# The variance of team 267  is 0.00622
# The standard deviation of team 267  is 0.07890
#
# Team 268
# The mean CGPA of team 268  is 4.09
# The variance of team 268  is 0.00511
# The standard deviation of team 268  is 0.07149
#
# Team 269
# The mean CGPA of team 269  is 4.08
# The variance of team 269  is 0.00396
# The standard deviation of team 269  is 0.06295
#
# Team 270
# The mean CGPA of team 270  is 4.10
# The variance of team 270  is 0.00322
# The standard deviation of team 270  is 0.05675
#
# Team 271
# The mean CGPA of team 271  is 4.11
# The variance of team 271  is 0.00613
# The standard deviation of team 271  is 0.07827
#
# Team 272
# The mean CGPA of team 272  is 4.03
# The variance of team 272  is 0.02022
# The standard deviation of team 272  is 0.14221
#
# Team 273
# The mean CGPA of team 273  is 4.11
# The variance of team 273  is 0.04320
# The standard deviation of team 273  is 0.20784
#
# Team 274
# The mean CGPA of team 274  is 4.07
# The variance of team 274  is 0.01333
# The standard deviation of team 274  is 0.11548
#
# Team 275
# The mean CGPA of team 275  is 4.09
# The variance of team 275  is 0.00508
# The standard deviation of team 275  is 0.07129
#
# Team 276
# The mean CGPA of team 276  is 4.10
# The variance of team 276  is 0.00393
# The standard deviation of team 276  is 0.06273
#
# Team 277
# The mean CGPA of team 277  is 4.09
# The variance of team 277  is 0.00294
# The standard deviation of team 277  is 0.05421
#
# Team 278
# The mean CGPA of team 278  is 4.09
# The variance of team 278  is 0.00245
# The standard deviation of team 278  is 0.04949
#
# Team 279
# The mean CGPA of team 279  is 4.17
# The variance of team 279  is 0.05269
# The standard deviation of team 279  is 0.22953
#
# Team 280
# The mean CGPA of team 280  is 4.07
# The variance of team 280  is 0.01770
# The standard deviation of team 280  is 0.13303
#
# Team 281
# The mean CGPA of team 281  is 4.09
# The variance of team 281  is 0.01580
# The standard deviation of team 281  is 0.12570
#
# Team 282
# The mean CGPA of team 282  is 4.10
# The variance of team 282  is 0.00787
# The standard deviation of team 282  is 0.08871
#
# Team 283
# The mean CGPA of team 283  is 4.10
# The variance of team 283  is 0.00916
# The standard deviation of team 283  is 0.09568
#
# Team 284
# The mean CGPA of team 284  is 4.08
# The variance of team 284  is 0.01051
# The standard deviation of team 284  is 0.10252
#
# Team 285
# The mean CGPA of team 285  is 4.12
# The variance of team 285  is 0.00225
# The standard deviation of team 285  is 0.04747
#
# Team 286
# The mean CGPA of team 286  is 4.12
# The variance of team 286  is 0.01356
# The standard deviation of team 286  is 0.11646
#
# Team 287
# The mean CGPA of team 287  is 4.09
# The variance of team 287  is 0.04605
# The standard deviation of team 287  is 0.21459
#
# Team 288
# The mean CGPA of team 288  is 4.07
# The variance of team 288  is 0.01736
# The standard deviation of team 288  is 0.13177
#
# Team 289
# The mean CGPA of team 289  is 4.10
# The variance of team 289  is 0.01455
# The standard deviation of team 289  is 0.12062
#
# Team 290
# The mean CGPA of team 290  is 4.11
# The variance of team 290  is 0.00825
# The standard deviation of team 290  is 0.09085
#
# Team 291
# The mean CGPA of team 291  is 4.13
# The variance of team 291  is 0.02805
# The standard deviation of team 291  is 0.16748
#
# Team 292
# The mean CGPA of team 292  is 4.10
# The variance of team 292  is 0.03761
# The standard deviation of team 292  is 0.19394
#
# Team 293
# The mean CGPA of team 293  is 4.07
# The variance of team 293  is 0.01153
# The standard deviation of team 293  is 0.10740
#
# Team 294
# The mean CGPA of team 294  is 4.06
# The variance of team 294  is 0.01185
# The standard deviation of team 294  is 0.10885
#
# Team 295
# The mean CGPA of team 295  is 4.09
# The variance of team 295  is 0.00630
# The standard deviation of team 295  is 0.07936
#
# Team 296
# The mean CGPA of team 296  is 4.08
# The variance of team 296  is 0.00366
# The standard deviation of team 296  is 0.06047
#
# Team 297
# The mean CGPA of team 297  is 4.09
# The variance of team 297  is 0.00362
# The standard deviation of team 297  is 0.06020
#
# Team 298
# The mean CGPA of team 298  is 4.09
# The variance of team 298  is 0.00178
# The standard deviation of team 298  is 0.04223
#
# Team 299
# The mean CGPA of team 299  is 4.09
# The variance of team 299  is 0.00130
# The standard deviation of team 299  is 0.03603
#
# Team 300
# The mean CGPA of team 300  is 4.07
# The variance of team 300  is 0.01347
# The standard deviation of team 300  is 0.11606
#
# Team 301
# The mean CGPA of team 301  is 4.05
# The variance of team 301  is 0.01507
# The standard deviation of team 301  is 0.12277
#
# Team 302
# The mean CGPA of team 302  is 4.09
# The variance of team 302  is 0.00785
# The standard deviation of team 302  is 0.08862
#
# Team 303
# The mean CGPA of team 303  is 4.09
# The variance of team 303  is 0.00671
# The standard deviation of team 303  is 0.08192
#
# Team 304
# The mean CGPA of team 304  is 4.11
# The variance of team 304  is 0.00468
# The standard deviation of team 304  is 0.06839
#
# Team 305
# The mean CGPA of team 305  is 4.11
# The variance of team 305  is 0.00305
# The standard deviation of team 305  is 0.05525
#
# Team 306
# The mean CGPA of team 306  is 4.13
# The variance of team 306  is 0.00151
# The standard deviation of team 306  is 0.03881
#
# Team 307
# The mean CGPA of team 307  is 4.15
# The variance of team 307  is 0.03062
# The standard deviation of team 307  is 0.17499
#
# Team 308
# The mean CGPA of team 308  is 4.04
# The variance of team 308  is 0.01901
# The standard deviation of team 308  is 0.13788
#
# Team 309
# The mean CGPA of team 309  is 4.05
# The variance of team 309  is 0.01511
# The standard deviation of team 309  is 0.12292
#
# Team 310
# The mean CGPA of team 310  is 4.08
# The variance of team 310  is 0.00614
# The standard deviation of team 310  is 0.07835
#
# Team 311
# The mean CGPA of team 311  is 4.07
# The variance of team 311  is 0.00511
# The standard deviation of team 311  is 0.07149
#
# Team 312
# The mean CGPA of team 312  is 4.09
# The variance of team 312  is 0.00365
# The standard deviation of team 312  is 0.06044
#
# Team 313
# The mean CGPA of team 313  is 4.03
# The variance of team 313  is 0.02394
# The standard deviation of team 313  is 0.15473
#
# Team 314
# The mean CGPA of team 314  is 4.08
# The variance of team 314  is 0.00975
# The standard deviation of team 314  is 0.09874
#
# Team 315
# The mean CGPA of team 315  is 4.00
# The variance of team 315  is 0.01769
# The standard deviation of team 315  is 0.13302
#
# Team 316
# The mean CGPA of team 316  is 4.04
# The variance of team 316  is 0.01341
# The standard deviation of team 316  is 0.11581
#
# Team 317
# The mean CGPA of team 317  is 4.04
# The variance of team 317  is 0.01202
# The standard deviation of team 317  is 0.10966
#
# Team 318
# The mean CGPA of team 318  is 4.05
# The variance of team 318  is 0.01093
# The standard deviation of team 318  is 0.10453
#
# Team 319
# The mean CGPA of team 319  is 4.06
# The variance of team 319  is 0.00478
# The standard deviation of team 319  is 0.06916
#
# Team 320
# The mean CGPA of team 320  is 4.19
# The variance of team 320  is 0.11376
# The standard deviation of team 320  is 0.33729
#
# Team 321
# The mean CGPA of team 321  is 4.04
# The variance of team 321  is 0.00891
# The standard deviation of team 321  is 0.09437
#
# Team 322
# The mean CGPA of team 322  is 4.04
# The variance of team 322  is 0.01608
# The standard deviation of team 322  is 0.12680
#
# Team 323
# The mean CGPA of team 323  is 4.05
# The variance of team 323  is 0.01211
# The standard deviation of team 323  is 0.11005
#
# Team 324
# The mean CGPA of team 324  is 4.03
# The variance of team 324  is 0.01453
# The standard deviation of team 324  is 0.12052
#
# Team 325
# The mean CGPA of team 325  is 4.08
# The variance of team 325  is 0.00634
# The standard deviation of team 325  is 0.07962
#
# Team 326
# The mean CGPA of team 326  is 4.07
# The variance of team 326  is 0.00544
# The standard deviation of team 326  is 0.07376
#
# Team 327
# The mean CGPA of team 327  is 4.06
# The variance of team 327  is 0.00236
# The standard deviation of team 327  is 0.04853
#
# Team 328
# The mean CGPA of team 328  is 4.08
# The variance of team 328  is 0.01428
# The standard deviation of team 328  is 0.11949
#
# Team 329
# The mean CGPA of team 329  is 4.08
# The variance of team 329  is 0.01714
# The standard deviation of team 329  is 0.13090
#
# Team 330
# The mean CGPA of team 330  is 4.11
# The variance of team 330  is 0.00857
# The standard deviation of team 330  is 0.09258
#
# Team 331
# The mean CGPA of team 331  is 4.11
# The variance of team 331  is 0.00607
# The standard deviation of team 331  is 0.07791
#
# Team 332
# The mean CGPA of team 332  is 4.10
# The variance of team 332  is 0.01082
# The standard deviation of team 332  is 0.10402
#
# Team 333
# The mean CGPA of team 333  is 4.12
# The variance of team 333  is 0.00313
# The standard deviation of team 333  is 0.05592
#
# Team 334
# The mean CGPA of team 334  is 4.09
# The variance of team 334  is 0.00262
# The standard deviation of team 334  is 0.05119
#
# Team 335
# The mean CGPA of team 335  is 4.20
# The variance of team 335  is 0.07122
# The standard deviation of team 335  is 0.26687
#
# Team 336
# The mean CGPA of team 336  is 4.05
# The variance of team 336  is 0.01634
# The standard deviation of team 336  is 0.12782
#
# Team 337
# The mean CGPA of team 337  is 4.10
# The variance of team 337  is 0.00731
# The standard deviation of team 337  is 0.08548
#
# Team 338
# The mean CGPA of team 338  is 4.09
# The variance of team 338  is 0.00953
# The standard deviation of team 338  is 0.09760
#
# Team 339
# The mean CGPA of team 339  is 4.07
# The variance of team 339  is 0.00203
# The standard deviation of team 339  is 0.04504
#
# Team 340
# The mean CGPA of team 340  is 4.12
# The variance of team 340  is 0.00839
# The standard deviation of team 340  is 0.09161
#
# Team 341
# The mean CGPA of team 341  is 4.09
# The variance of team 341  is 0.00261
# The standard deviation of team 341  is 0.05111
#
# Team 342
# The mean CGPA of team 342  is 4.06
# The variance of team 342  is 0.01564
# The standard deviation of team 342  is 0.12504
#
# Team 343
# The mean CGPA of team 343  is 4.08
# The variance of team 343  is 0.01675
# The standard deviation of team 343  is 0.12942
#
# Team 344
# The mean CGPA of team 344  is 4.11
# The variance of team 344  is 0.00640
# The standard deviation of team 344  is 0.07997
#
# Team 345
# The mean CGPA of team 345  is 4.10
# The variance of team 345  is 0.00522
# The standard deviation of team 345  is 0.07228
#
# Team 346
# The mean CGPA of team 346  is 4.09
# The variance of team 346  is 0.00877
# The standard deviation of team 346  is 0.09363
#
# Team 347
# The mean CGPA of team 347  is 4.11
# The variance of team 347  is 0.00267
# The standard deviation of team 347  is 0.05167
#
# Team 348
# The mean CGPA of team 348  is 4.10
# The variance of team 348  is 0.01028
# The standard deviation of team 348  is 0.10140
#
# Team 349
# The mean CGPA of team 349  is 4.18
# The variance of team 349  is 0.08114
# The standard deviation of team 349  is 0.28485
#
# Team 350
# The mean CGPA of team 350  is 4.07
# The variance of team 350  is 0.01347
# The standard deviation of team 350  is 0.11606
#
# Team 351
# The mean CGPA of team 351  is 4.09
# The variance of team 351  is 0.00785
# The standard deviation of team 351  is 0.08862
#
# Team 352
# The mean CGPA of team 352  is 4.15
# The variance of team 352  is 0.02822
# The standard deviation of team 352  is 0.16799
#
# Team 353
# The mean CGPA of team 353  is 4.08
# The variance of team 353  is 0.00705
# The standard deviation of team 353  is 0.08396
#
# Team 354
# The mean CGPA of team 354  is 4.17
# The variance of team 354  is 0.05662
# The standard deviation of team 354  is 0.23795
#
# Team 355
# The mean CGPA of team 355  is 4.05
# The variance of team 355  is 0.00977
# The standard deviation of team 355  is 0.09885
#
# Team 356
# The mean CGPA of team 356  is 4.12
# The variance of team 356  is 0.02979
# The standard deviation of team 356  is 0.17261
#
# Team 357
# The mean CGPA of team 357  is 4.04
# The variance of team 357  is 0.01833
# The standard deviation of team 357  is 0.13538
#
# Team 358
# The mean CGPA of team 358  is 4.06
# The variance of team 358  is 0.01297
# The standard deviation of team 358  is 0.11389
#
# Team 359
# The mean CGPA of team 359  is 4.06
# The variance of team 359  is 0.01273
# The standard deviation of team 359  is 0.11281
#
# Team 360
# The mean CGPA of team 360  is 4.09
# The variance of team 360  is 0.00719
# The standard deviation of team 360  is 0.08480
#
# Team 361
# The mean CGPA of team 361  is 4.07
# The variance of team 361  is 0.00377
# The standard deviation of team 361  is 0.06138
#
# Team 362
# The mean CGPA of team 362  is 4.14
# The variance of team 362  is 0.02720
# The standard deviation of team 362  is 0.16492
#
# Team 363
# The mean CGPA of team 363  is 4.03
# The variance of team 363  is 0.01219
# The standard deviation of team 363  is 0.11043
#
# Team 364
# The mean CGPA of team 364  is 4.07
# The variance of team 364  is 0.01368
# The standard deviation of team 364  is 0.11695
#
# Team 365
# The mean CGPA of team 365  is 4.06
# The variance of team 365  is 0.01216
# The standard deviation of team 365  is 0.11025
#
# Team 366
# The mean CGPA of team 366  is 4.09
# The variance of team 366  is 0.00444
# The standard deviation of team 366  is 0.06664
#
# Team 367
# The mean CGPA of team 367  is 4.10
# The variance of team 367  is 0.00402
# The standard deviation of team 367  is 0.06341
#
# Team 368
# The mean CGPA of team 368  is 4.11
# The variance of team 368  is 0.00390
# The standard deviation of team 368  is 0.06244
#
# Team 369
# The mean CGPA of team 369  is 4.07
# The variance of team 369  is 0.00847
# The standard deviation of team 369  is 0.09203
#
# Team 370
# The mean CGPA of team 370  is 4.05
# The variance of team 370  is 0.01120
# The standard deviation of team 370  is 0.10581
#
# Team 371
# The mean CGPA of team 371  is 4.08
# The variance of team 371  is 0.02171
# The standard deviation of team 371  is 0.14736
#
# Team 372
# The mean CGPA of team 372  is 4.09
# The variance of team 372  is 0.01030
# The standard deviation of team 372  is 0.10148
#
# Team 373
# The mean CGPA of team 373  is 4.12
# The variance of team 373  is 0.00442
# The standard deviation of team 373  is 0.06649
#
# Team 374
# The mean CGPA of team 374  is 4.12
# The variance of team 374  is 0.00511
# The standard deviation of team 374  is 0.07149
#
# Team 375
# The mean CGPA of team 375  is 4.12
# ...
# The standard deviation of team 717  is 0.06902
#
# Team 718
# The mean CGPA of team 718  is 4.11
# The variance of team 718  is 0.00306
# The standard deviation of team 718  is 0.05529
#
# Team 719
# The mean CGPA of team 719  is 4.14
# The variance of team 719  is 0.00360
# The standard deviation of team 719  is 0.05997
#
# Team 720
# The mean CGPA of team 720  is 4.14
# The variance of team 720  is 0.03148
# The standard deviation of team 720  is 0.17743
#
# Team 721
# The mean CGPA of team 721  is 4.04
# The variance of team 721  is 0.01368
# The standard deviation of team 721  is 0.11697
#
# Team 722
# The mean CGPA of team 722  is 4.06
# The variance of team 722  is 0.00805
# The standard deviation of team 722  is 0.08972
#
# Team 723
# The mean CGPA of team 723  is 4.07
# The variance of team 723  is 0.00622
# The standard deviation of team 723  is 0.07887
#
# Team 724
# The mean CGPA of team 724  is 4.08
# The variance of team 724  is 0.00474
# The standard deviation of team 724  is 0.06887
#
# Team 725
# The mean CGPA of team 725  is 4.09
# The variance of team 725  is 0.00279
# The standard deviation of team 725  is 0.05284
#
# Team 726
# The mean CGPA of team 726  is 4.07
# The variance of team 726  is 0.00105
# The standard deviation of team 726  is 0.03239
#
# Team 727
# The mean CGPA of team 727  is 4.06
# The variance of team 727  is 0.01344
# The standard deviation of team 727  is 0.11591
#
# Team 728
# The mean CGPA of team 728  is 4.06
# The variance of team 728  is 0.02113
# The standard deviation of team 728  is 0.14538
#
# Team 729
# The mean CGPA of team 729  is 4.09
# The variance of team 729  is 0.00996
# The standard deviation of team 729  is 0.09982
#
# Team 730
# The mean CGPA of team 730  is 4.07
# The variance of team 730  is 0.01503
# The standard deviation of team 730  is 0.12258
#
# Team 731
# The mean CGPA of team 731  is 4.10
# The variance of team 731  is 0.00398
# The standard deviation of team 731  is 0.06312
#
# Team 732
# The mean CGPA of team 732  is 4.12
# The variance of team 732  is 0.00399
# The standard deviation of team 732  is 0.06318
#
# Team 733
# The mean CGPA of team 733  is 4.09
# The variance of team 733  is 0.00114
# The standard deviation of team 733  is 0.03375
#
# Team 734
# The mean CGPA of team 734  is 4.12
# The variance of team 734  is 0.01402
# The standard deviation of team 734  is 0.11843
#
# Team 735
# The mean CGPA of team 735  is 4.07
# The variance of team 735  is 0.01344
# The standard deviation of team 735  is 0.11593
#
# Team 736
# The mean CGPA of team 736  is 4.05
# The variance of team 736  is 0.01538
# The standard deviation of team 736  is 0.12403
#
# Team 737
# The mean CGPA of team 737  is 4.07
# The variance of team 737  is 0.00881
# The standard deviation of team 737  is 0.09387
#
# Team 738
# The mean CGPA of team 738  is 4.09
# The variance of team 738  is 0.00781
# The standard deviation of team 738  is 0.08839
#
# Team 739
# The mean CGPA of team 739  is 4.09
# The variance of team 739  is 0.00447
# The standard deviation of team 739  is 0.06685
#
# Team 740
# The mean CGPA of team 740  is 4.14
# The variance of team 740  is 0.02781
# The standard deviation of team 740  is 0.16677
#
# Team 741
# The mean CGPA of team 741  is 4.08
# The variance of team 741  is 0.01202
# The standard deviation of team 741  is 0.10966
#
# Team 742
# The mean CGPA of team 742  is 4.05
# The variance of team 742  is 0.02451
# The standard deviation of team 742  is 0.15654
#
# Team 743
# The mean CGPA of team 743  is 4.05
# The variance of team 743  is 0.02038
# The standard deviation of team 743  is 0.14277
#
# Team 744
# The mean CGPA of team 744  is 4.07
# The variance of team 744  is 0.00945
# The standard deviation of team 744  is 0.09721
#
# Team 745
# The mean CGPA of team 745  is 4.09
# The variance of team 745  is 0.00573
# The standard deviation of team 745  is 0.07573
#
# Team 746
# The mean CGPA of team 746  is 4.09
# The variance of team 746  is 0.00497
# The standard deviation of team 746  is 0.07048
#
# Team 747
# The mean CGPA of team 747  is 4.11
# The variance of team 747  is 0.00519
# The standard deviation of team 747  is 0.07205
#
# Team 748
# The mean CGPA of team 748  is 4.01
# The variance of team 748  is 0.01050
# The standard deviation of team 748  is 0.10247
#
# Team 749
# The mean CGPA of team 749  is 4.08
# The variance of team 749  is 0.03992
# The standard deviation of team 749  is 0.19980
#
# Team 750
# The mean CGPA of team 750  is 4.04
# The variance of team 750  is 0.01671
# The standard deviation of team 750  is 0.12925
#
# Team 751
# The mean CGPA of team 751  is 4.09
# The variance of team 751  is 0.00606
# The standard deviation of team 751  is 0.07783
#
# Team 752
# The mean CGPA of team 752  is 4.08
# The variance of team 752  is 0.00528
# The standard deviation of team 752  is 0.07267
#
# Team 753
# The mean CGPA of team 753  is 4.06
# The variance of team 753  is 0.01507
# The standard deviation of team 753  is 0.12276
#
# Team 754
# The mean CGPA of team 754  is 4.15
# The variance of team 754  is 0.03236
# The standard deviation of team 754  is 0.17988
#
# Team 755
# The mean CGPA of team 755  is 4.08
# The variance of team 755  is 0.00384
# The standard deviation of team 755  is 0.06197
#
# Team 756
# The mean CGPA of team 756  is 4.07
# The variance of team 756  is 0.01960
# The standard deviation of team 756  is 0.13999
#
# Team 757
# The mean CGPA of team 757  is 4.05
# The variance of team 757  is 0.01365
# The standard deviation of team 757  is 0.11683
#
# Team 758
# The mean CGPA of team 758  is 4.10
# The variance of team 758  is 0.01021
# The standard deviation of team 758  is 0.10106
#
# Team 759
# The mean CGPA of team 759  is 4.12
# The variance of team 759  is 0.01156
# The standard deviation of team 759  is 0.10753
#
# Team 760
# The mean CGPA of team 760  is 4.08
# The variance of team 760  is 0.00947
# The standard deviation of team 760  is 0.09731
#
# Team 761
# The mean CGPA of team 761  is 4.06
# The variance of team 761  is 0.01142
# The standard deviation of team 761  is 0.10687
#
# Team 762
# The mean CGPA of team 762  is 4.11
# The variance of team 762  is 0.00502
# The standard deviation of team 762  is 0.07088
#
# Team 763
# The mean CGPA of team 763  is 4.07
# The variance of team 763  is 0.00788
# The standard deviation of team 763  is 0.08876
#
# Team 764
# The mean CGPA of team 764  is 4.08
# The variance of team 764  is 0.00565
# The standard deviation of team 764  is 0.07516
#
# Team 765
# The mean CGPA of team 765  is 4.08
# The variance of team 765  is 0.00456
# The standard deviation of team 765  is 0.06755
#
# Team 766
# The mean CGPA of team 766  is 4.08
# The variance of team 766  is 0.00376
# The standard deviation of team 766  is 0.06135
#
# Team 767
# The mean CGPA of team 767  is 4.08
# The variance of team 767  is 0.00296
# The standard deviation of team 767  is 0.05444
#
# Team 768
# The mean CGPA of team 768  is 4.10
# The variance of team 768  is 0.00717
# The standard deviation of team 768  is 0.08468
#
# Team 769
# The mean CGPA of team 769  is 4.04
# The variance of team 769  is 0.00900
# The standard deviation of team 769  is 0.09486
#
# Team 770
# The mean CGPA of team 770  is 4.02
# The variance of team 770  is 0.02635
# The standard deviation of team 770  is 0.16233
#
# Team 771
# The mean CGPA of team 771  is 4.09
# The variance of team 771  is 0.01984
# The standard deviation of team 771  is 0.14086
#
# Team 772
# The mean CGPA of team 772  is 4.10
# The variance of team 772  is 0.01444
# The standard deviation of team 772  is 0.12017
#
# Team 773
# The mean CGPA of team 773  is 4.09
# The variance of team 773  is 0.00968
# The standard deviation of team 773  is 0.09840
#
# Team 774
# The mean CGPA of team 774  is 4.10
# The variance of team 774  is 0.00442
# The standard deviation of team 774  is 0.06652
#
# Team 775
# The mean CGPA of team 775  is 4.08
# The variance of team 775  is 0.00300
# The standard deviation of team 775  is 0.05473
#
# Team 776
# The mean CGPA of team 776  is 4.14
# The variance of team 776  is 0.04071
# The standard deviation of team 776  is 0.20178
#
# Team 777
# The mean CGPA of team 777  is 4.06
# The variance of team 777  is 0.02096
# The standard deviation of team 777  is 0.14476
#
# Team 778
# The mean CGPA of team 778  is 4.11
# The variance of team 778  is 0.00719
# The standard deviation of team 778  is 0.08480
#
# Team 779
# The mean CGPA of team 779  is 4.12
# The variance of team 779  is 0.00519
# The standard deviation of team 779  is 0.07205
#
# Team 780
# The mean CGPA of team 780  is 4.11
# The variance of team 780  is 0.00462
# The standard deviation of team 780  is 0.06797
#
# Team 781
# The mean CGPA of team 781  is 4.11
# The variance of team 781  is 0.00340
# The standard deviation of team 781  is 0.05827
#
# Team 782
# The mean CGPA of team 782  is 4.08
# The variance of team 782  is 0.00945
# The standard deviation of team 782  is 0.09723
#
# Team 783
# The mean CGPA of team 783  is 4.15
# The variance of team 783  is 0.02984
# The standard deviation of team 783  is 0.17275
#
# Team 784
# The mean CGPA of team 784  is 4.02
# The variance of team 784  is 0.02120
# The standard deviation of team 784  is 0.14560
#
# Team 785
# The mean CGPA of team 785  is 4.04
# The variance of team 785  is 0.01513
# The standard deviation of team 785  is 0.12299
#
# Team 786
# The mean CGPA of team 786  is 4.05
# The variance of team 786  is 0.00902
# The standard deviation of team 786  is 0.09500
#
# Team 787
# The mean CGPA of team 787  is 4.07
# The variance of team 787  is 0.00533
# The standard deviation of team 787  is 0.07298
#
# Team 788
# The mean CGPA of team 788  is 4.08
# The variance of team 788  is 0.00228
# The standard deviation of team 788  is 0.04777
#
# Team 789
# The mean CGPA of team 789  is 4.11
# The variance of team 789  is 0.00990
# The standard deviation of team 789  is 0.09949
#
# Team 790
# The mean CGPA of team 790  is 4.02
# The variance of team 790  is 0.01615
# The standard deviation of team 790  is 0.12708
#
# Team 791
# The mean CGPA of team 791  is 4.06
# The variance of team 791  is 0.01221
# The standard deviation of team 791  is 0.11051
#
# Team 792
# The mean CGPA of team 792  is 4.08
# The variance of team 792  is 0.00696
# The standard deviation of team 792  is 0.08340
#
# Team 793
# The mean CGPA of team 793  is 4.09
# The variance of team 793  is 0.00379
# The standard deviation of team 793  is 0.06158
#
# Team 794
# The mean CGPA of team 794  is 4.10
# The variance of team 794  is 0.00485
# The standard deviation of team 794  is 0.06963
#
# Team 795
# The mean CGPA of team 795  is 4.09
# The variance of team 795  is 0.00413
# The standard deviation of team 795  is 0.06424
#
# Team 796
# The mean CGPA of team 796  is 4.12
# The variance of team 796  is 0.02216
# The standard deviation of team 796  is 0.14887
#
# Team 797
# The mean CGPA of team 797  is 4.10
# The variance of team 797  is 0.03661
# The standard deviation of team 797  is 0.19134
#
# Team 798
# The mean CGPA of team 798  is 4.06
# The variance of team 798  is 0.01577
# The standard deviation of team 798  is 0.12558
#
# Team 799
# The mean CGPA of team 799  is 4.09
# The variance of team 799  is 0.01104
# The standard deviation of team 799  is 0.10508
#
# Team 800
# The mean CGPA of team 800  is 4.11
# The variance of team 800  is 0.00602
# The standard deviation of team 800  is 0.07762
#
# Team 801
# The mean CGPA of team 801  is 4.11
# The variance of team 801  is 0.00665
# The standard deviation of team 801  is 0.08154
#
# Team 802
# The mean CGPA of team 802  is 4.08
# The variance of team 802  is 0.01007
# The standard deviation of team 802  is 0.10037
#
# Team 803
# The mean CGPA of team 803  is 4.12
# The variance of team 803  is 0.00651
# The standard deviation of team 803  is 0.08071
#
# Team 804
# The mean CGPA of team 804  is 4.10
# The variance of team 804  is 0.01208
# The standard deviation of team 804  is 0.10992
#
# Team 805
# The mean CGPA of team 805  is 4.09
# The variance of team 805  is 0.03212
# The standard deviation of team 805  is 0.17922
#
# Team 806
# The mean CGPA of team 806  is 4.10
# The variance of team 806  is 0.01362
# The standard deviation of team 806  is 0.11672
#
# Team 807
# The mean CGPA of team 807  is 4.11
# The variance of team 807  is 0.00924
# The standard deviation of team 807  is 0.09613
#
# Team 808
# The mean CGPA of team 808  is 4.11
# The variance of team 808  is 0.00977
# The standard deviation of team 808  is 0.09885
#
# Team 809
# The mean CGPA of team 809  is 4.11
# The variance of team 809  is 0.00398
# The standard deviation of team 809  is 0.06312
#
# Team 810
# The mean CGPA of team 810  is 4.07
# The variance of team 810  is 0.00882
# The standard deviation of team 810  is 0.09394
#
# Team 811
# The mean CGPA of team 811  is 4.12
# The variance of team 811  is 0.04068
# The standard deviation of team 811  is 0.20170
#
# Team 812
# The mean CGPA of team 812  is 4.08
# The variance of team 812  is 0.01241
# The standard deviation of team 812  is 0.11141
#
# Team 813
# The mean CGPA of team 813  is 4.07
# The variance of team 813  is 0.01176
# The standard deviation of team 813  is 0.10846
#
# Team 814
# The mean CGPA of team 814  is 4.13
# The variance of team 814  is 0.01080
# The standard deviation of team 814  is 0.10390
#
# Team 815
# The mean CGPA of team 815  is 4.11
# The variance of team 815  is 0.00563
# The standard deviation of team 815  is 0.07502
#
# Team 816
# The mean CGPA of team 816  is 4.14
# The variance of team 816  is 0.00742
# The standard deviation of team 816  is 0.08617
#
# Team 817
# The mean CGPA of team 817  is 4.10
# The variance of team 817  is 0.00147
# The standard deviation of team 817  is 0.03833
#
# Team 818
# The mean CGPA of team 818  is 4.12
# The variance of team 818  is 0.06588
# The standard deviation of team 818  is 0.25666
#
# Team 819
# The mean CGPA of team 819  is 4.10
# The variance of team 819  is 0.01627
# The standard deviation of team 819  is 0.12757
#
# Team 820
# The mean CGPA of team 820  is 4.09
# The variance of team 820  is 0.01905
# The standard deviation of team 820  is 0.13803
#
# Team 821
# The mean CGPA of team 821  is 4.10
# The variance of team 821  is 0.00648
# The standard deviation of team 821  is 0.08048
#
# Team 822
# The mean CGPA of team 822  is 4.13
# The variance of team 822  is 0.00842
# The standard deviation of team 822  is 0.09176
#
# Team 823
# The mean CGPA of team 823  is 4.10
# The variance of team 823  is 0.00323
# The standard deviation of team 823  is 0.05682
#
# Team 824
# The mean CGPA of team 824  is 4.05
# The variance of team 824  is 0.00771
# The standard deviation of team 824  is 0.08781
#
# Team 825
# The mean CGPA of team 825  is 4.18
# The variance of team 825  is 0.03702
# The standard deviation of team 825  is 0.19242
#
# Team 826
# The mean CGPA of team 826  is 4.05
# The variance of team 826  is 0.02360
# The standard deviation of team 826  is 0.15361
#
# Team 827
# The mean CGPA of team 827  is 4.11
# The variance of team 827  is 0.00774
# The standard deviation of team 827  is 0.08797
#
# Team 828
# The mean CGPA of team 828  is 4.11
# The variance of team 828  is 0.00425
# The standard deviation of team 828  is 0.06518
#
# Team 829
# The mean CGPA of team 829  is 4.11
# The variance of team 829  is 0.00404
# The standard deviation of team 829  is 0.06357
#
# Team 830
# The mean CGPA of team 830  is 4.11
# The variance of team 830  is 0.00321
# The standard deviation of team 830  is 0.05668
#
# Team 831
# The mean CGPA of team 831  is 4.12
# The variance of team 831  is 0.00157
# The standard deviation of team 831  is 0.03959
#
# Team 832
# The mean CGPA of team 832  is 4.07
# The variance of team 832  is 0.02202
# The standard deviation of team 832  is 0.14839
#
# Team 833
# The mean CGPA of team 833  is 4.08
# The variance of team 833  is 0.00999
# The standard deviation of team 833  is 0.09993
#
# Team 834
# The mean CGPA of team 834  is 4.15
# The variance of team 834  is 0.02751
# The standard deviation of team 834  is 0.16585
#
# Team 835
# The mean CGPA of team 835  is 4.11
# The variance of team 835  is 0.00490
# The standard deviation of team 835  is 0.06999
#
# Team 836
# The mean CGPA of team 836  is 4.12
# The variance of team 836  is 0.00605
# The standard deviation of team 836  is 0.07778
#
# Team 837
# The mean CGPA of team 837  is 4.10
# The variance of team 837  is 0.01193
# The standard deviation of team 837  is 0.10921
#
# Team 838
# The mean CGPA of team 838  is 4.15
# The variance of team 838  is 0.03145
# The standard deviation of team 838  is 0.17734
#
# Team 839
# The mean CGPA of team 839  is 4.15
# The variance of team 839  is 0.02374
# The standard deviation of team 839  is 0.15407
#
# The mean of the population is 4.09
# Population median is: 4.061428571428571
# The standard deviation of the population is 0.03090
# {'m2f5': 98, 'm3f4': 415, 'm4f4': 112, 'm4f3': 205, 'm5f3': 8, 'm5f2': 2}
